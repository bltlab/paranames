# %%
from pathlib import Path

# %%
from rich import print

# %%
from paranames.util import read

# %%
import pandas as pd

# %%
# def read_tsv(path: Path) -> pd.DataFrame:
#     return read(path, "tsv")

# %% [markdown]
# ### Load everything (obsolete)

# %%
# per_with_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER_instance_of_counts.tsv")
# per_without_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/PER_instance_of_counts.tsv")

# %%
# per_with = read_tsv(per_with_path)
# per_without = read_tsv(per_without_path)

# %%
# loc_with_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC_instance_of_counts.tsv")
# loc_without_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/LOC_instance_of_counts.tsv")

# %%
# loc_with = read_tsv(loc_with_path)
# loc_without = read_tsv(loc_without_path)

# %%
# org_with_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/ORG_instance_of_counts.tsv")
# org_without_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/ORG_instance_of_counts.tsv")

# %%
# org_with = read_tsv(org_with_path)
# org_without = read_tsv(org_without_path)

# %%
# with_dfs = [per_with, loc_with]
# with_dfs.append(org_with)

# %%
# without_dfs = [per_without, loc_without]
# without_dfs.append(org_without)

# %%
# conll_types = ["PER", "LOC"]
# conll_types.append("ORG")

# %% [markdown]
# ### How many entities <u>more</u> do we detect by using subclassing?

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-with*subclassing-3col/PER.jsonl
# Out:
#    8726412 /home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/PER.jsonl
#    8730734 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl
#   17457146 total

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-with*subclassing-3col/LOC.jsonl
# Out:
#      2923 /home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/LOC.jsonl
#   3078459 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl
#   3081382 total

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-with*subclassing-3col/ORG.jsonl
# Out:
#     58753 /home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/ORG.jsonl
#   2196303 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/ORG.jsonl
#   2255056 total

# %%
print(f"[PER] Difference = {8730734 - 8726412}")
print(f"[LOC] Difference = {3078459 - 2923}")
print(f"[ORG] Difference = {2196303 - 58753}")
# Out:
# [PER] Difference = 4322
# [LOC] Difference = 3075536
# [ORG] Difference = 2137550

# %% [markdown]
# ### PER

# %% [markdown]
# First let's create a set of all entities that are a subclass of `Q5`:

# %%
from qwikidata.sparql import get_subclasses_of_item

# %%
subclass_of_human = set(get_subclasses_of_item('Q5', return_qids=True))

# %% [markdown]
# Then let's loop through *all* entities categorized as `PER` (but not an instance of `Q5`) and see what makes them `PER`.

# %%
import orjson
from rich.progress import track
from collections import Counter

# %%
import pymongo
client = pymongo.MongoClient(port=27617)
db = client['paranames_db_022822']
coll = db['paranames']

# %%
per_entities_jsonl_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl")

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl
# Out:
# 8730734 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl

# %%
def grab_first_available(label_dict):
    if not label_dict:
        return ''
    first_lang = [l for l in label_dict].pop(0)
    return label_dict[first_lang]

# %%
why_per = {}
with open(per_entities_jsonl_path, 'r', encoding="utf-8") as fin:
    look_up_these = set()
    for ix, line in track(enumerate(fin), total=8730733, description="Checking what makes PER entities PER..."):
        row = orjson.loads(line)
        wid = row['wikidata_id']
        name = row['name']
        instance_of = set(row['instance_of'])
        if "Q5" in instance_of:
            continue
        common = instance_of.intersection(subclass_of_human)
        if len(common) == 0:
            print(f"[{wid}] Entity '{name}' is not an instance of Q5 or any of its subclasses.")
        else:
            look_up_these.update(common)
            why_per[wid] = common
            
# Make the instance-of names human readable
looked_up_names = {
    r['id']: r['name']
    if r['name'] 
    else grab_first_available(r['labels']) 
    for r in coll.find(
        {"id": {"$in": list(look_up_these)}}
    )
}

why_per_human_readable = {}
for wid, inst_of_set in track(why_per.items(), description="Making the IDs human readable..."):
    why_per_human_readable[wid] = {
        (qid, looked_up_names.get(qid))
        for qid in inst_of_set
    }
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# OK, every PER entity is an instance of something that is a subclass of Q5.
#
# Now we can tally why the PER entities that were only detected with subclasses were categorized as such:

# %%
why_per_counts = Counter()
for _, inst_of in why_per_human_readable.items():
    string_labels =  " & ".join([f"{name} ({qid})" or qid for qid, name in inst_of])
    why_per_counts[string_labels] += 1

# %%
why_per_counts.most_common()
# Out:
# [('federally recognized Native American tribe in the United States (Q7840353)',
#   164),
#  ('human fetus (Q26513)', 68),
#  ('hypothetical person (Q75855169)', 51),
#  ('Police and Crime Commissioner (Q58333)', 39),
#  ('minister (Q83307)', 36),
#  ('inhabitant (Q22947)', 32),
#  ('Permanent Secretary (Q57901836)', 28),
#  ('fictional human formerly considered to be historical (Q64520857)', 26),
#  ('Director of Bureau (Q23931359)', 25),
#  ('ambassador to the United States of America (Q19359052)', 24),
#  ('Native Americans in the United States (Q49297)', 24),
#  ('ombudsman (Q169180)', 23),
#  ('civil servant (Q212238)', 23),
#  ('indigenous peoples of the Americas (Q36747)', 22),
#  ('passenger (Q319604)', 20),
#  ("ambassador to the People's Republic of China (Q30064335)", 19),
#  ('prisoner of a Nazi concentration camp (Q1719325) & prisoner (Q1862087)',
#   16),
#  ('board member (Q2824523)', 16),
#  ('Native American tribe (Q12885585)', 13),
#  ('ambassador of the United States of America (Q15726790)', 13),
#  ('judge (Q16533)', 10),
#  ('ambassador of the United Kingdom (Q18115939)', 10),
#  ('coach (Q41583)', 10),
#  ('prosopographical phantom (Q64643615)', 10),
#  ('fictional princess (Q61928601)', 9),
#  ('state-recognized tribe in the United States (Q104904387)', 8),
#  ('indigenous peoples of North America (Q15571255)', 8),
#  ('First Nations (Q392316)', 8),
#  ('tourist (Q5633897)', 8),
#  ('fictional queen (Q16658194)', 7),
#  ('None (Q29898672)', 7),
#  ('High Commissioner of the United Kingdom (Q56760832)', 7),
#  ('male human (Q84048850)', 7),
#  ('Sveriges delegationer (Q108059166)', 6),
#  ('Pharao im Mittleren Reich (Q110550696) & Pharao der 12. Dynastie (Q110550681) & pharaoh (Q37110)',
#   6),
#  ('Indigenous Australians (Q170355)', 6),
#  ('consul (Q207978)', 6),
#  ('Principal Private Secretary (Q665061)', 6),
#  ('chief of staff (Q707492)', 6),
#  ('Permanent Representative to the United Nations (Q7888495)', 5),
#  ('permanent representative (Q19356884)', 5),
#  ('military attaché (Q302691)', 5),
#  ('secretary of state (Q736559)', 5),
#  ('United States Assistant Secretary of State (Q742482)', 5),
#  ('pharaoh (Q37110) & None (Q110552024) & Pharao im Alten Reich (Q110518305)',
#   4),
#  ('State Minister (Q11397947)', 4),
#  ('United Nations Special Rapporteur (Q15143900)', 4),
#  ('Permanent Representative to the European Union (Q18449104)', 4),
#  ('ambassador of Romania (Q30158711)', 4),
#  ('ambassador to the United Kingdom (Q456692)', 4),
#  ('Permanent Representative to the United Nations Organizations in Geneva (Q57833747)',
#   4),
#  ('agriculture minister (Q10540834)', 3),
#  ('permanent representative to the United Nations at Vienna (Q108402412)', 3),
#  ('pharaoh (Q37110) & Pharao der  5. Dynastie (Q110556685) & Pharao im Alten Reich (Q110518305)',
#   3),
#  ('king (Q12097)', 3),
#  ('nomad (Q128393)', 3),
#  ('refugee (Q131572)', 3),
#  ('advocate general (Q1478218)', 3),
#  ('administrator (Q16532929)', 3),
#  ('skateboarder (Q17502714)', 3),
#  ('unidentified decedent (Q18356450)', 3),
#  ('Native Indonesians (Q1945590)', 3),
#  ('police commissioner (Q2101758)', 3),
#  ('stillborn (Q2345820)', 3),
#  ('chief of police (Q2855502)', 3),
#  ('federally recognized Native American tribe in the United States (Q7840353) & indigenous peoples of the Americas (Q36747)',
#   3),
#  ('consul general (Q3734658)', 3),
#  ('consejero autonómico (Q47176183)', 3),
#  ('Hispanic and Latino Americans (Q58669)', 3),
#  ('prosecutor (Q600751)', 3),
#  ('None (Q7614320)', 3),
#  ('honorary consul (Q1075179)', 2),
#  ('African people (Q1075929)', 2),
#  ('minister of state of El Salvador (Q108414874)', 2),
#  ('Amerindian literature in North America (Q109134999)', 2),
#  ('pharaoh (Q37110) & Pharao im Neuen Reich (Q110551384) & Pharao der 18. Dynastie (Q110551377)',
#   2),
#  ('ambassador (Q121998)', 2),
#  ('High Commissioner (Q123695)', 2),
#  ('federally recognized Native American tribe in the United States (Q7840353) & indigenous peoples of North America (Q15571255)',
#   2),
#  ('ambassador-at-large (Q4741053) & ambassador of the United States of America (Q15726790)',
#   2),
#  ('permanent representative (Q19356884) & ambassador of the United States of America (Q15726790)',
#   2),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Burundi (Q38272152)',
#   2),
#  ('Ministry of Government (Q16607736)', 2),
#  ('Italian diaspora (Q1675084)', 2),
#  ('ambassador to the Grand Duchy of Tuscany (Q56850176) & ambassador of the United Kingdom (Q18115939)',
#   2),
#  ('ambassador of the United Kingdom (Q18115939) & Permanent Representative to the Council of Europe (Q57421531)',
#   2),
#  ('Inuit (Q189975)', 2),
#  ('diplomat (Q193391)', 2),
#  ('neighbour (Q1986893)', 2),
#  ('athlete (Q2066131)', 2),
#  ('chief of army staff position (Q2257775)', 2),
#  ('ambassador to Kazakhstan (Q29898858) & Israeli ambassador (Q23902382)', 2),
#  ('Israeli ambassador (Q23902382) & ambassador to Austria (Q29608929)', 2),
#  ('minister of culture (Q2621182)', 2),
#  ('ambassador of South Africa (Q30158578) & ambassador to Canada (Q29607391)',
#   2),
#  ('health minister (Q3273722)', 2),
#  ('indigenous peoples of Mexico (Q3314452)', 2),
#  ('ambassador of Singapore (Q38135159)', 2),
#  ('police officer (Q384593)', 2),
#  ('education minister (Q4018482)', 2),
#  ('federally recognized Native American tribe in the United States (Q7840353) & Native Americans in the United States (Q49297)',
#   2),
#  ('Permanent Representative to the United Nations (Q7888495) & Spanish ambassador (Q6348379)',
#   2),
#  ('queen consort (Q719039)', 2),
#  ('minister (Q83307) & secretary of state (Q736559)', 2),
#  ('Indigenous peoples of California (Q744299)', 2),
#  ('child (Q7569)', 2),
#  ('sports minister (Q7579929)', 2),
#  ('detective (Q842782)', 2),
#  ('ambassador of the Austro-Hungarian Empire (Q100494551) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador of the Austro-Hungarian Empire (Q100494551) & ambassador to Italy (Q21814442)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador of the Austro-Hungarian Empire (Q100494551) & ambassador to the German Reich (Q110694324)',
#   1),
#  ('None (Q29637599) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador to Spain (Q28555544) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('francophones (Q100710385)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to the Solomon Islands (Q56850191)',
#   1),
#  ('ambassador to Morocco (Q29898040) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ("Saudi Arabia ambassador (Q100710470) & ambassador to the People's Republic of China (Q30064335)",
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Indonesia (Q30057149)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to South Korea (Q21814441)',
#   1),
#  ('ambassador to Australia (Q29973167) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Sweden (Q28071226)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & None (Q30057185)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Slovenia (Q29972832)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to the United Arab Emirates (Q30057151)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Afghanistan (Q30056283)',
#   1),
#  ('ambassador to the Czech Republic (Q30057157) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Lebanon (Q30057181) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Pakistan (Q30056349)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to Denmark (Q29971792) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Venezuela (Q30057166)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Somalia (Q30160620)',
#   1),
#  ('ambassador to Portugal (Q29973442) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Norway (Q30057175)',
#   1),
#  ('ambassador to Chile (Q30057141) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Switzerland (Q28071147)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Senegal (Q30056479)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Iran (Q30057171)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Japan (Q29898189)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Kuwait (Q30057130)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Jordan (Q30057132)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Tunisia (Q29970486)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Slovakia (Q30057169)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Ireland (Q29970126)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Bangladesh (Q30057170)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Gabon (Q30249630)', 1),
#  ('ambassador to the United Kingdom (Q456692) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Syria (Q28064704)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Argentina (Q29898752)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Turkmenistan (Q30057187)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Mauritania (Q38135453)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Liechtenstein (Q30249963)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to the European Union (Q101064552)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Nigeria (Q30249268)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Luxembourg (Q29973520)',
#   1),
#  ('ambassador to Sudan (Q37802473) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Egypt (Q30056302)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Fiji (Q38271671)', 1),
#  ('ambassador to Algeria (Q29624028) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Chad (Q30063979)', 1),
#  ('ambassador to Bahrain (Q30057172) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Turkey (Q28038722) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to France (Q19359050)',
#   1),
#  ('None (Q28796675) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to Azerbaijan (Q30057164) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Ghana (Q37803626) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to the Russian Federation (Q29511967) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Nepal (Q30057186)', 1),
#  ('ambassador to Greece (Q29898588) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Austria (Q29608929)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Bulgaria (Q29973348)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Belgium (Q29511906)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Andorra (Q30065101)',
#   1),
#  ('None (Q30057152) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Oman (Q30057135)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Guinea (Q30061429)',
#   1),
#  ('ambassador to the European Union (Q101064552)', 1),
#  ('ambassador to the European Union (Q101064552) & Israeli ambassador (Q23902382)',
#   1),
#  ('Apache (Q102090) & federally recognized Native American tribe in the United States (Q7840353)',
#   1),
#  ('Greeks (Q539051) & Poles (Q1026)', 1),
#  ('None (Q104716993) & conscious collaborator of the State Security (Q104736802)',
#   1),
#  ('state-recognized tribe in the United States (Q104904387) & federally recognized Native American tribe in the United States (Q7840353)',
#   1),
#  ('ambassador to Rwanda (Q29640790)', 1),
#  ('ambassador to Burundi (Q38272152)', 1),
#  ('ambassador to Mozambique (Q30307532)', 1),
#  ('bisexual man (Q105079567)', 1),
#  ('ambassador of Mauritius (Q105138634) & ambassador to France (Q19359050)',
#   1),
#  ("ambassador of Mauritius (Q105138634) & ambassador to the People's Republic of China (Q30064335)",
#   1),
#  ('ambassador of Tajikistan (Q105159301) & ambassador to Kyrgyzstan (Q30057188)',
#   1),
#  ('ambassador of the Central African Republic (Q105337704) & ambassador to the United States of America (Q19359052)',
#   1),
#  ("ambassador of the Central African Republic (Q105337704) & ambassador to the People's Republic of China (Q30064335)",
#   1),
#  ('ambassador to Canada (Q29607391) & ambassador of the Central African Republic (Q105337704)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of the Central African Republic (Q105337704)',
#   1),
#  ('High Commissioner of Mozambique (Q105627328) & ambassador to Kenya (Q38131570)',
#   1),
#  ('High Commissioner of Mozambique (Q105627328) & ambassador to Malawi (Q40771726)',
#   1),
#  ('High Commissioner of Malawi (Q105627331) & ambassador to Mozambique (Q30307532)',
#   1),
#  ('High Commissioner of Kenya (Q105627361) & ambassador to Zimbabwe (Q30057145)',
#   1),
#  ('Mexican American poetry (Q105898065)', 1),
#  ('ambassador to Spain (Q28555544) & ambassador of the Austrian Empire (Q106085599)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & ambassador of the Austrian Empire (Q106085599)',
#   1),
#  ('None (Q29637599) & ambassador of the Austrian Empire (Q106085599)', 1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & Spanish ambassador (Q6348379)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & ambassador of the Russian Empire (Q110634640)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & French ambassador (Q28061729)',
#   1),
#  ('Ambassador of the Imperial China (Q110637743) & ambassador to the United Kingdom of Great Britain and Ireland (Q106086666)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & ambassador of the Ottoman Empire (Q29971375)',
#   1),
#  ('ambassador of Palau (Q106091169) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Palau (Q106091169) & None (Q29970812)', 1),
#  ('ambassador of Palau (Q106091169) & ambassador to Japan (Q29898189)', 1),
#  ('None (Q106204647) & ambassador to Mozambique (Q30307532)', 1),
#  ('ambassador to the United Kingdom (Q456692) & None (Q106204647)', 1),
#  ('ambassador of Myanmar (Q106298798) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the United Kingdom (Q456692) & ambassador of Myanmar (Q106298798)',
#   1),
#  ('ambassador to São Tomé and Príncipe (Q106457780) & ambassador of Romania (Q30158711)',
#   1),
#  ('ambassador of Portugal (Q30061057) & ambassador to São Tomé and Príncipe (Q106457780)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to São Tomé and Príncipe (Q106457780)',
#   1),
#  ('ambassador of Honduras (Q106697436) & Permanent Representative to the United Nations (Q7888495)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Honduras (Q106697436)', 1),
#  ('ambassador of Azerbaijan (Q106834938) & ambassador to Hungary (Q29439727)',
#   1),
#  ('ambassador to Israel (Q30057159) & ambassador of Guinea (Q107022423)', 1),
#  ('ambassador to the Russian Federation (Q29511967) & ambassador of Guinea (Q107022423)',
#   1),
#  ('None (Q107126597) & ambassador to the United States of America (Q19359052)',
#   1),
#  ("None (Q107126597) & ambassador to the People's Republic of China (Q30064335)",
#   1),
#  ("state's attorney (Q10726370)", 1),
#  ('ambassador to Spain (Q28555544) & ambassador of El Salvador (Q107302783)',
#   1),
#  ('honorary consul of Ireland (Q107419604) & honorary consul to Pakistan (Q107427787)',
#   1),
#  ('high commissioner of Maldives (Q107420584) & high commissioner to Sri Lanka (Q107420625)',
#   1),
#  ('honorary consul to Belize (Q107427555) & honorary consul of Barbados (Q107427335)',
#   1),
#  ('honorary consul of Rwanda (Q107427695) & honorary consul to Bangladesh (Q107427726)',
#   1),
#  ('honorary consul to Kazakhstan (Q107427758) & honorary consul of Singapore (Q107427745)',
#   1),
#  ('ambassador of Barbados (Q107500590) & Permanent Representative to the United Nations (Q7888495)',
#   1),
#  ('African people (Q1075929) & Portuguese (Q178630)', 1),
#  ('Sveriges delegationer (Q108059166) & Permanent Representative to the United Nations (Q7888495)',
#   1),
#  ('ambassador of Uganda (Q108392983) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('permanent representative to the United Nations at Vienna (Q108402412) & ambassador of Hungary (Q30161250)',
#   1),
#  ('permanent representative to the United Nations at Vienna (Q108402412) & ambassador of the United Kingdom (Q18115939)',
#   1),
#  ('permanent representative to the United Nations at Vienna (Q108402412) & ambassador of Italy (Q30158595)',
#   1),
#  ('permanent representative to OSCE (Q108411377) & ambassador of the United Kingdom (Q18115939)',
#   1),
#  ('Mexican American politicians (Q108605557)', 1),
#  ('ambassador to the United Kingdom (Q456692) & High Commissioner of Pakistan (Q108737249)',
#   1),
#  ('ambassador of Turkmenistan (Q108865405) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Turkmenistan (Q108865405) & ambassador to Turkey (Q28038722)',
#   1),
#  ("ambassador of Turkmenistan (Q108865405) & ambassador to the People's Republic of China (Q30064335)",
#   1),
#  ('Amerindian men (Q109328851)', 1),
#  ('ambassador to Mexico (Q29511856) & None (Q109465839)', 1),
#  ('Mexican American authors (Q109479668)', 1),
#  ('envoy (Q11051391)', 1),
#  ('pharaoh (Q37110) & None (Q110643371) & Pharao im Alten Reich (Q110518305)',
#   1),
#  ('ambassador to Samoa (Q110598070) & Spanish ambassador (Q6348379)', 1),
#  ('ambassador of the king of Aragon (Q110620436) & ambassador to the king of England (Q40107153)',
#   1),
#  ('ambassador to the king of Castile (Q110620736) & ambassador of the king of Aragon (Q110620436)',
#   1),
#  ('ambassador to the king of England (Q40107153) & Ambassador of the King of Castile (Q110620447)',
#   1),
#  ('ambassador to the king of Aragon (Q110620850) & Ambassador of the King of Castile (Q110620447)',
#   1),
#  ('ambassador of the Kingdom of England (Q110620925) & ambassador to the king of Castile (Q110620736)',
#   1),
#  ('ambassador of the Kingdom of England (Q110620925) & ambassador to the Tsardom of Russia (Q110634957)',
#   1),
#  ('ambassador of the Kingdom of England (Q110620925) & ambassador to the Kingdom of France (Q110795214)',
#   1),
#  ('ambassador of the United Kingdom of Great Britain and Ireland (Q110625897)',
#   1),
#  ('ambassador of the United Kingdom of Great Britain and Ireland (Q110625897) & ambassador to Spain (Q28555544)',
#   1),
#  ('ambassador of the United Kingdom of Great Britain and Ireland (Q110625897) & ambassador to Austria-Hungary (Q56849086)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the United Kingdom of Great Britain and Ireland (Q110625897)',
#   1),
#  ('ambassador of the United Kingdom of Great Britain and Ireland (Q110625897) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('None (Q29637599) & ambassador of the United Kingdom of Great Britain and Ireland (Q110625897)',
#   1),
#  ('ambassador to the Kingdom of Great Britain (Q110626411) & Spanish ambassador (Q6348379)',
#   1),
#  ('ambassador to Austria-Hungary (Q56849086) & ambassador of the Russian Empire (Q110634640)',
#   1),
#  ('ambassador to Spain (Q28555544) & ambassador of the Russian Empire (Q110634640)',
#   1),
#  ('None (Q29637599) & ambassador of the Russian Empire (Q110634640)', 1),
#  ('ambassador to France (Q19359050) & ambassador of the Russian Empire (Q110634640)',
#   1),
#  ('Ambassador to the Republic of China (1912-1949) (Q110638023) & ambassador of the Russian Empire (Q110634640)',
#   1),
#  ('ambassador of the Russian Empire (Q110634640) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('ambassador of the Russian Empire (Q110634640) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the Republic of China (1912-1949) (Q38831326)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & Ambassador of the Imperial China (Q110637743)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the Ottoman Empire (Q29971375)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & Spanish ambassador (Q6348379)',
#   1),
#  ('ambassador of the Tsardom of Russia (Q110634776) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('ambassador to the Tsardom of Russia (Q110634957) & ambassador of the Ottoman Empire (Q29971375)',
#   1),
#  ('ambassador to Spain (Q28555544) & ambassador of the Archduchy of Austria (Q110636598)',
#   1),
#  ('ambassador to the Archduchy of Austria (Q110636867) & Spanish ambassador (Q6348379)',
#   1),
#  ('ambassador of the Ottoman Empire (Q29971375) & ambassador to the Austrian Empire (Q110636887)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Austrian Empire (Q110636887)',
#   1),
#  ('ambassador to the Austrian Empire (Q110636887) & Spanish ambassador (Q6348379)',
#   1),
#  ('ambassador of the Netherlands (Q29970594) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('ambassador of the Kingdom of Italy (Q110788685) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & Spanish ambassador (Q6348379)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('ambassador of Belgium (Q28064761) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & French ambassador (Q28061729)',
#   1),
#  ('ambassador of the German Reich (Q30504670) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('ambassador of Japan (Q29972272) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('Ambassador to the Republic of China (1912-1949) (Q110638023) & ambassador of the Soviet Union (Q40032299)',
#   1),
#  ('Ambassador to the Republic of China (1912-1949) (Q110638023) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('Ambassador to the Republic of China (1912-1949) (Q110638023) & Spanish ambassador (Q6348379)',
#   1),
#  ('Ambassador of the Republic of China (Taiwan) (Q110638065) & ambassador to the Soviet Union (Q38133278)',
#   1),
#  ('Ambassador of the Republic of China (Taiwan) (Q110638065) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('Ambassador of the Republic of China (Taiwan) (Q110638065) & ambassador to Spain (Q28555544)',
#   1),
#  ('Ambassador of the Republic of China (Taiwan) (Q110638065) & ambassador to Nicaragua (Q30158174)',
#   1),
#  ('Ambassador of the Republic of China (Taiwan) (Q110638065) & ambassador to Japan (Q29898189)',
#   1),
#  ('Ambassador of the Republic of China (Taiwan) (Q110638065) & ambassador to the Russian Federation (Q29511967)',
#   1),
#  ('Ambassador of the Republic of China (Taiwan) (Q110638065) & ambassador to Canada (Q29607391)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the German Reich (Q110694324)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Republic of Texas (Q110710372)',
#   1),
#  ('ambassador to Spain (Q28555544) & ambassador of the Kingdom of Portugal (Q110795350)',
#   1),
#  ('ambassador to the Kingdom of Portugal (Q110795474) & Spanish ambassador (Q6348379)',
#   1),
#  ('ambassador of Sweden (Q9149754) & ambassador to Brazil (Q110936963)', 1),
#  ('mixed martial arts fighter (Q11607585)', 1),
#  ('ambassador to Hungary (Q29439727) & ambassador of Denmark (Q11685588)', 1),
#  ('ambassador of Denmark (Q11685588) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United Kingdom (Q456692) & ambassador of Denmark (Q11685588)',
#   1),
#  ('ambassador of Denmark (Q11685588) & ambassador to Italy (Q21814442)', 1),
#  ('ambassador to Iceland (Q30056331) & ambassador of Denmark (Q11685588)', 1),
#  ('None (Q30057152) & ambassador of Denmark (Q11685588)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Denmark (Q11685588)', 1),
#  ('ambassador to Spain (Q28555544) & ambassador of Denmark (Q11685588)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to the Russian Federation (Q29511967)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Finland (Q30065086)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Iceland (Q30056331)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to New Zealand (Q30056446)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Hungary (Q29439727)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Indonesia (Q30057149)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Lithuania (Q30249315)',
#   1),
#  ('ambassador to Latvia (Q30057136) & ambassador of Estonia (Q11685589)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Tajikistan (Q30057161)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Tunisia (Q29970486)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Norway (Q30057175)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to France (Q19359050)', 1),
#  ('ambassador to the United Kingdom (Q456692) & ambassador of Estonia (Q11685589)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Turkmenistan (Q30057187)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Thailand (Q30057174)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Canada (Q29607391)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Austria (Q29608929)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Uzbekistan (Q30057134)',
#   1),
#  ('caveperson (Q1190089)', 1),
#  ('French (Q121842)', 1),
#  ('transport minister (Q12339722)', 1),
#  ('High Commissioner (Q123695) & ambassador to Cyprus (Q30057143) & ambassador of Australia (Q29512058)',
#   1),
#  ('High Commissioner (Q123695) & ambassador of Australia (Q29512058) & ambassador to Bangladesh (Q30057170)',
#   1),
#  ('High Commissioner (Q123695) & ambassador to Brunei (Q30057179) & ambassador of Australia (Q29512058)',
#   1),
#  ('head of mission (Q1251687) & ambassador to Greece (Q29898588) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('head of mission (Q1251687)', 1),
#  ('research minister (Q1266327)', 1),
#  ('professional wrestler (Q13474373)', 1),
#  ('environment minister (Q1449973)', 1),
#  ('Indigenous peoples of South America (Q1479328)', 1),
#  ('ambassador of Uruguay (Q30106715) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Albania (Q29972092)',
#   1),
#  ('ambassador of Canada (Q29511881) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Andorra (Q30080394) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Georgia (Q30082250)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & Spanish ambassador (Q6348379)', 1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Hungary (Q30161250)',
#   1),
#  ('ambassador of Australia (Q29512058) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Colombia (Q29972039) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of East Timor (Q30301586) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of the Republic of Austria (Q29898009) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Iran (Q30055513) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Chile (Q30082431) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Mexico (Q30158640) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of the United Kingdom (Q18115939) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Romania (Q30158711)',
#   1),
#  ('ambassador of Ukraine (Q15992673) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Germany (Q28070952)',
#   1),
#  ('ambassador of Belgium (Q28064761) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Portugal (Q30061057) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Palestine (Q20383035) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of the European Union (Q2092585) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('Israeli ambassador (Q23902382) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Switzerland (Q38152482) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of the Philippines (Q29933415) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Iceland (Q29971738)',
#   1),
#  ('ambassador of Argentina (Q30158666) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Kenya (Q38243929) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('attorney general (Q1501926)', 1),
#  ('high school student (Q15360275)', 1),
#  ('governor (Q1540323)', 1),
#  ('None (Q29970812) & apostolic nuncio (Q157037)', 1),
#  ('ambassador to Libya (Q30056069) & apostolic nuncio (Q157037)', 1),
#  ('permanent representative (Q19356884) & apostolic nuncio (Q157037)', 1),
#  ('ambassador to Israel (Q30057159) & apostolic nuncio (Q157037)', 1),
#  ('apostolic nuncio (Q157037)', 1),
#  ('ambassador to Kuwait (Q30057130) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('None (Q28796675) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Peru (Q29970158)',
#   1),
#  ('ambassador to Armenia (Q30057137) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Pakistan (Q30056349) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Libya (Q30056069)',
#   1),
#  ('ambassador to the Bahamas (Q37773919) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Bahrain (Q30057172) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Malawi (Q40771726) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Nauru (Q38271924) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Venezuela (Q30057166)',
#   1),
#  ('ambassador to Brazil (Q29973306) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Cuba (Q30061268)',
#   1),
#  ('ambassador to Mauritius (Q37770046) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Monaco (Q30063875) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Niger (Q30056959) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Antigua and Barbuda (Q30301630)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to East Germany (Q30106718)',
#   1),
#  ('ambassador to Iran (Q30057171) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Spain (Q28555544) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Afghanistan (Q30056283)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Bulgaria (Q29973348)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to South Sudan (Q30061448)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Tunisia (Q29970486)',
#   1),
#  ('ambassador to Albania (Q29971890) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Eritrea (Q30250001)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Sweden (Q28071226)',
#   1),
#  ('ambassador to Argentina (Q29898752) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Latvia (Q30057136) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Indonesia (Q30057149)',
#   1),
#  ('None (Q30057152) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Estonia (Q29970877)',
#   1),
#  ('ambassador to East Timor (Q30301646) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Jamaica (Q30250132)',
#   1),
#  ('ambassador to Somalia (Q30160620) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Equatorial Guinea (Q30061428)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Nepal (Q30057186)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Mauritania (Q38135453)',
#   1),
#  ('ambassador to Sierra Leone (Q38280710) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Senegal (Q30056479) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('None (Q29637599) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('None (Q30063950) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Australia (Q29973167) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Angola (Q30303350)',
#   1),
#  ('ambassador to Georgia (Q30057156) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Luxembourg (Q29973520) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Guinea (Q30061429)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Cape Verde (Q40240177)',
#   1),
#  ('ambassador to Rwanda (Q29640790) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to El Salvador (Q30057163)',
#   1),
#  ('ambassador to Gabon (Q30249630) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Kiribati (Q30061431)',
#   1),
#  ('ambassador to Papua New Guinea (Q38716711) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Tajikistan (Q30057161) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Laos (Q30057144)',
#   1),
#  ('ambassador to San Marino (Q48828900) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Philippines (Q30057182)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Egypt (Q30056302)',
#   1),
#  ("ambassador of the United States of America (Q15726790) & ambassador to the People's Republic of China (Q30064335)",
#   1),
#  ('ambassador to the Republic of the Congo (Q38134453) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Zimbabwe (Q30057145)',
#   1),
#  ('ambassador to Morocco (Q29898040) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Yemen (Q30249188) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Ukraine (Q29917636) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to South Vietnam (Q30056117) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Cambodia (Q30057155) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Uganda (Q30057148) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Italy (Q21814442)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q30249889)',
#   1),
#  ('ambassador to Iceland (Q30056331) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to North Macedonia (Q30151243) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Tuvalu (Q38272056)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Japan (Q29898189)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Fiji (Q38271671)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Liechtenstein (Q30249963) & ambassador to Switzerland (Q28071147)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Bangladesh (Q30057170)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Iraq (Q30055990)',
#   1),
#  ('ambassador to Kazakhstan (Q29898858) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Yugoslavia (Q30159125) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to the Seychelles (Q30249587) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Kosovo (Q38272297)',
#   1),
#  ('ambassador to Vanuatu (Q38135935) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Uruguay (Q30057139) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Oman (Q30057135)',
#   1),
#  ('ambassador to Colombia (Q30063921) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Cameroon (Q37770827) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the United Arab Emirates (Q30057151)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Slovakia (Q30057169)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Palau (Q40243457)',
#   1),
#  ('ambassador to Belarus (Q30081888) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to the Democratic Republic of Congo (Q38134585) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Denmark (Q29971792) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Ghana (Q37803626) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Belize (Q56850184) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Chile (Q30057141) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Ecuador (Q30057184)',
#   1),
#  ('ambassador to Brunei (Q30057179) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Panama (Q30063931)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Czechoslovakia (Q30159256)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Syria (Q28064704)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q30105055)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Canada (Q29607391)',
#   1),
#  ('ambassador to the Czech Republic (Q30057157) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q29970812)',
#   1),
#  ('ambassador to Israel (Q30057159) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Kyrgyzstan (Q30057188) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to India (Q30056023) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Paraguay (Q30158196)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Singapore (Q30057178)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Burkina Faso (Q4741151)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Montenegro (Q30105252)',
#   1),
#  ('ambassador to Hungary (Q29439727) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Malta (Q29575417) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Lebanon (Q30057181) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to South Africa (Q29986627)',
#   1),
#  ('ambassador to the Netherlands (Q29898619) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Madagascar (Q30035798) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q56850189)',
#   1),
#  ('ambassador to Moldova (Q30159284) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Korea (Q38133909) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to the Russian Federation (Q29511967) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Turkmenistan (Q30057187)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Austria (Q29608929)',
#   1),
#  ('ambassador to Djibouti (Q38288666) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Bosnia and Herzegovina (Q30057131)',
#   1),
#  ('ambassador to Guatemala (Q30057173) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Slovenia (Q29972832) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Romania (Q30056294)',
#   1),
#  ('ambassador to Turkey (Q28038722) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Poland (Q28071176) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to South Yemen (Q30249471) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Saudi Arabia (Q30057165)',
#   1),
#  ('ambassador to Nigeria (Q30249268) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to New Zealand (Q30056446)',
#   1),
#  ('ambassador to Serbia (Q30249223) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Benin (Q30062766)',
#   1),
#  ('ambassador to the Gambia (Q30249893) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Tanzania (Q30249429) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Chad (Q30063979) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Barbados (Q38288681) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Central African Republic (Q38271520)',
#   1),
#  ('ambassador to Croatia (Q30104588) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Bolivia (Q30057160) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Suriname (Q40333148)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Ireland (Q29970126)',
#   1),
#  ('ambassador to Portugal (Q29973442) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Qatar (Q30056203) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Liberia (Q37772375) & ambassador of the United States of America (Q15726790)',
#   1),
#  ("ambassador of the United States of America (Q15726790) & ambassador to Côte d'Ivoire (Q29641344)",
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Finland (Q30065086)',
#   1),
#  ('ambassador to Cyprus (Q30057143) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Algeria (Q29624028) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Austria-Hungary (Q56849086)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Zambia (Q30056458)',
#   1),
#  ('ambassador to Azerbaijan (Q30057164) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Belgium (Q29511906)',
#   1),
#  ('ambassador to Uzbekistan (Q30057134) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Lesotho (Q30249612) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Myanmar (Q30057154) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q40244299)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Mongolia (Q30057167)',
#   1),
#  ('ambassador to Trinidad and Tobago (Q38271385) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Mali (Q30064049)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Kenya (Q38131570)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to South Korea (Q21814441)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q30057185)',
#   1),
#  ('None (Q40240399) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Norway (Q30057175)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Honduras (Q30057177)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to North Yemen (Q30249202)',
#   1),
# ...
#   1),
#  ('ambassador to Uzbekistan (Q30057134) & ambassador of the United Kingdom (Q18115939)',
#   1),
#  ('ambassador to Guatemala (Q30057173) & ambassador of the United Kingdom (Q18115939)',
#   1),
#  ('ambassador to Persia (Q56850168) & ambassador of the United Kingdom (Q18115939)',
#   1),
#  ('ambassador of the United Kingdom (Q18115939) & ambassador to Finland (Q30065086)',
#   1),
#  ('ambassador of the Republic of Austria (Q29898009) & Permanent Representative to the European Union (Q18449104)',
#   1),
#  ('Permanent Representative to the European Union (Q18449104) & ambassador of Germany (Q28070952)',
#   1),
#  ('Lithuanians (Q186192)', 1),
#  ('Kapo (Q702997) & prisoner (Q1862087)', 1),
#  ('prison officer (Q311396) & prisoner (Q1862087) & police officer (Q384593)',
#   1),
#  ('cosplayer (Q18810049)', 1),
#  ('wife (Q188830)', 1),
#  ('migrant (Q1932461)', 1),
#  ('minister of the Netherlands (Q19334526)', 1),
#  ('permanent representative (Q19356884) & ambassador of Hungary (Q30161250)',
#   1),
#  ('permanent representative (Q19356884) & French ambassador (Q28061729)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Germany (Q28070952)', 1),
#  ('ambassador to France (Q19359050) & Israeli ambassador (Q23902382)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Tunisia (Q29646039)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Kenya (Q38243929)', 1),
#  ('ambassador of Lithuania (Q30064875) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Lebanon (Q30076709)', 1),
#  ('ambassador of Bolivia (Q30158606) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Sri Lanka (Q30068647)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Sweden (Q9149754)', 1),
#  ('ambassador of the Republic of Austria (Q29898009) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador of Bahrain (Q40554294) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of India (Q30061036)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Romania (Q30158711)', 1),
#  ('ambassador to France (Q19359050) & None (Q29898672)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Ivory Coast (Q29971577)',
#   1),
#  ('ambassador to France (Q19359050) & Spanish ambassador (Q6348379)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Cuba (Q30158616)', 1),
#  ('ambassador to France (Q19359050) & ambassador of the Soviet Union (Q40032299)',
#   1),
#  ('ambassador to France (Q19359050) & Venezuelan ambassador (Q30158724)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Albania (Q29972092)', 1),
#  ('ambassador to France (Q19359050) & ambassador of the Russian Federation (Q28038712)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Montenegro (Q30061165)',
#   1),
#  ('ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Pakistan (Q30158743)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Guatemala (Q30076857)', 1),
#  ('ambassador of Serbia (Q38152244) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Libya (Q38288651)', 1),
#  ('ambassador of Canada (Q29511881) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Armenia (Q30249655) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Uruguay (Q30106715)', 1),
#  ('ambassador to France (Q19359050) & ambassador of New-Zealand (Q30055488)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Poland (Q30064617)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Jordan (Q30076785)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Argentina (Q30158666)', 1),
#  ('ambassador of Czechoslovakia (Q40453861) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Iceland (Q29971738)', 1),
#  ('ambassador of the Netherlands (Q29970594) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of the Republic of the Congo (Q29899026)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Malaysia (Q38288600)', 1),
#  ('ambassador to France (Q19359050) & Equatorial Guinea ambassador (Q28555512)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Burkina Faso (Q38258039)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Hungary (Q30161250)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Switzerland (Q38152482)',
#   1),
#  ('ambassador of Ghana (Q95567639) & ambassador to France (Q19359050)', 1),
#  ('ambassador of the Czech Republic (Q60038322) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Andorra (Q30080394)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Turkey (Q29971416)', 1),
#  ('ambassador of Portugal (Q30061057) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Egypt (Q30068618)', 1),
#  ('ambassador to France (Q19359050) & ambassador of South Korea (Q29970783)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Morocco (Q29971182)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Greece (Q30161199)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Slovakia (Q30249299)', 1),
#  ('ambassador of Peru (Q29970009) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Norway (Q30158720)', 1),
#  ('ambassador to France (Q19359050) & None (Q2841895)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Belgium (Q28064761)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Monaco (Q30105179)', 1),
#  ('ambassador to France (Q19359050) & Burundian Ambassador (Q30076608)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Japan (Q29972272)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Cyprus (Q55593891)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Malawi (Q90404048)', 1),
#  ('ambassador of Nigeria (Q30301734) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Angola (Q40455712)', 1),
#  ('ambassador of Syria (Q29971465) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Sri Lanka (Q30068647) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('None (Q2841895) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Guyana (Q38154664) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Comoros (Q40455770) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Croatia (Q30104607) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Dominica (Q30105087) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Cape Verde (Q40455673) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Colombia (Q29972039) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('Cambodian ambassador (Q38155268) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Kyrgyzstan (Q40455660) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Czech Republic (Q60038322) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Eritrea (Q30250016) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Gabon (Q40339224)',
#   1),
#  ('ambassador of Vietnam (Q40543107) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Serbia (Q38152244) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Sudan (Q40455758) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Sweden (Q9149754) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Greece (Q30161199) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Angola (Q40455712) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Turkey (Q29971416) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Kazakhstan (Q30105218) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the German Reich (Q30504670) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Jordan (Q30076785) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Armenia (Q30249655) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Paraguay (Q30158675) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Qatar (Q38717123) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Bahrain (Q40554294) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Bulgaria (Q38281228) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Djibouti (Q40455648) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Moldova (Q38272559) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Mauritania (Q38135561) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Hungary (Q30161250) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of South Korea (Q29970783) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Pakistan (Q30158743) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of New-Zealand (Q30055488) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Russian Federation (Q28038712) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Montenegro (Q30061165) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Uruguay (Q30106715) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Bangladesh (Q30076076) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of São Tomé and Príncipe (Q40455722) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Singapore (Q38135159) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & Ambassador of Zambia (Q38281863)',
#   1),
#  ('ambassador of Romania (Q30158711) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Brazil (Q30081331) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of North Macedonia (Q30151218)',
#   1),
#  ('ambassador of the Maldives (Q30076753) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Republic of Austria (Q29898009) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Botswana (Q37773129) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Lebanon (Q30076709) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Bosnia and Herzegovina (Q39664395) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Tunisia (Q29646039) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & Yemeni ambassador (Q38281623)',
#   1),
#  ('ambassador of Cuba (Q30158616) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Bolivia (Q30158606) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of South Africa (Q30158578) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Rwanda (Q30064661) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Bahamas (Q30158655)',
#   1),
#  ('ambassador of Nauru (Q38271782) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Chad (Q40455783) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Uzbekistan (Q38715811) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Slovakia (Q30249299) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Brunei (Q38288637) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Egypt (Q30068618) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('Israeli ambassador (Q23902382) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Iran (Q30055513) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Peru (Q29970009) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & None (Q29898672)',
#   1),
#  ('French ambassador (Q28061729) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Netherlands (Q29970594) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('Burundian Ambassador (Q30076608) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Liberia (Q37772652) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('Equatorial Guinea ambassador (Q28555512) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Mexico (Q30158640) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Kenya (Q38243929) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of South Sudan (Q40455798) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Finland (Q40651705) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Switzerland (Q38152482) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Argentina (Q30158666) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Mozambique (Q38244903) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('Gambian ambassador (Q30249960) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Fiji (Q92116627) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Monaco (Q30105179) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Kuwait (Q40455744) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Madagascar (Q40455808) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Slovenia (Q64547173) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Namibia (Q38715599) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Seychelles (Q38134865) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Soviet Union (Q40032299) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of India (Q30061036) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Luxembourg (Q30161428) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Canada (Q29511881) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Ottoman Empire (Q29971375) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('None (Q39662504) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Australia (Q29512058) & ambassador to the United States of America (Q19359052)',
#   1),
#  ...]

# %% [markdown]
# ### Where do these weird inheritance hierarchies come from?
#
# This will be infeasible to analyze for everything but here are a few examples:
#
# For example, `Quechan people` is an instance of `indigenous peoples of the Americas ` (Q36747).

# %%
# %%bash
#
# rg "Q36747" /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl | head -n 1 | jq
# Out:
# {
#   "wikidata_id": "Q1754503",
#   "name": "Quechan people",
#   "type": "PER",
#   "instance_of": [
#     "Q7840353",
#     "Q36747",
#     "Q133311"
#   ]
# }

# %% [markdown]
# We can check what it's an instance of with human-readable names:

# %%
why_per_human_readable["Q1754503"]
# Out:
# {('Q36747', 'indigenous peoples of the Americas'),
#  ('Q7840353',
#   'federally recognized Native American tribe in the United States')}

# %% [markdown]
# Looking at [`indigenous peoples of the Americas`](https://www.wikidata.org/wiki/Q36747), we can see that it is a subclass of [`Americans`](https://www.wikidata.org/wiki/Q2384959), which in turn is a subclass of [`inhabitant`](https://www.wikidata.org/wiki/Q22947), which itself is a subclass of [`human`](https://www.wikidata.org/wiki/Q5).
#
# This implies that anything that is an instance of `indigenous peoples of the Americas` is also an instance of `human`.

# %% [markdown]
# A second example: [`Louise Victoria, Princess of Grão-Pará`](https://www.wikidata.org/wiki/Q51883211):

# %%
# %%bash
#
# rg "Q26513" /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl | head -n 2 | tail -n1 | jq
# Out:
# {
#   "wikidata_id": "Q51883211",
#   "name": "Louise Victoria, Princess of Grão-Pará",
#   "type": "PER",
#   "instance_of": [
#     "Q26513"
#   ]
# }

# %% [markdown]
# is an instance of [`human fetus`](https://www.wikidata.org/wiki/Q26513).
#
# [`human fetus`](https://www.wikidata.org/wiki/Q26513) is an instance of [`prenate`](https://www.wikidata.org/wiki/Q63177820) which is a subclass of [`human`](https://www.wikidata.org/wiki/Q5).
#
# Thus, `Louise Victoria, Princess of Grão-Pará` is PER.

# %% [markdown]
# Third example: [`Marcus Horatius`](https://www.wikidata.org/wiki/Q55463614)

# %%
# %%bash
#
# rg "Q75855169" /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl | head -n 1 | jq
# Out:
# {
#   "wikidata_id": "Q55463614",
#   "name": "Marcus Horatius",
#   "type": "PER",
#   "instance_of": [
#     "Q75855169"
#   ]
# }

# %% [markdown]
# is an instance of [`hypothetical person (Q75855169)`](https://www.wikidata.org/wiki/Q75855169) which is a subclass of `human` and thus `Marcus Horatius` is also a PER.

# %% [markdown]
# ### LOC

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl
# Out:
# 3078459 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl

# %%
loc_entities_jsonl_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl")
subclass_of_geographic_region = get_subclasses_of_item("Q82794")

# %%
why_loc = {}
with open(loc_entities_jsonl_path, 'r', encoding="utf-8") as fin:
    look_up_these_loc = set()
    for ix, line in track(enumerate(fin), total=3078459, description="Checking what makes LOC entities LOC..."):
        row = orjson.loads(line)
        wid = row['wikidata_id']
        name = row['name']
        instance_of = set(row['instance_of'])
        if "Q82794" in instance_of:
            continue
        common = instance_of.intersection(subclass_of_geographic_region)
        if len(common) == 0:
            look_up_these_org.update(inst_of)
            why_loc[wid] = inst_of
        else:
            look_up_these_loc.update(common)
            why_loc[wid] = common
            
# Make the instance-of names human readable
looked_up_loc = {
    r['id']: r['name']
    if r['name'] 
    else grab_first_available(r['labels']) 
    for r in coll.find(
        {"id": {"$in": list(look_up_these_loc)}}
    )
}

why_loc_human_readable = {}
for wid, inst_of_set in track(why_loc.items(), description="Making the IDs human readable..."):
    why_loc_human_readable[wid] = {
        (qid, looked_up_loc.get(qid))
        for qid in inst_of_set
    }
# Out:
# Output()

# %%
why_loc_counts = Counter()
for _, inst_of in why_loc_human_readable.items():
    string_labels =  " & ".join([f"{name} ({qid})" if name else qid for qid, name in inst_of])
    why_loc_counts[string_labels] += 1

# %%
why_loc_counts.most_common()

# %% [markdown]
# Some examples:
#
# TODO

# %% [markdown]
# ### ORG

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/ORG.jsonl

# %%
org_entities_jsonl_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/ORG.jsonl")
subclass_of_organization = get_subclasses_of_item("Q43229")

# %%
why_org = {}
with open(org_entities_jsonl_path, 'r', encoding="utf-8") as fin:
    look_up_these_org = set()
    for ix, line in track(enumerate(fin), total=2196302, description="Checking what makes ORG entities ORG..."):
        row = orjson.loads(line)
        wid = row['wikidata_id']
        name = row['name']
        instance_of = set(row['instance_of'])
        if "Q43229" in instance_of:
            continue
        common = instance_of.intersection(subclass_of_geographic_region)
        why_org_value = common if len(common) > 0 else inst_of
        look_up_these_org.update(why_org_value)
        why_org[wid] = why_org_value
# Make the instance-of names human readable
looked_up_org = {
    r['id']: r['name']
    if r['name'] 
    else grab_first_available(r['labels']) 
    for r in coll.find(
        {"id": {"$in": list(look_up_these_org)}}
    )
}

why_org_human_readable = {}
for wid, inst_of_set in track(why_org.items(), description="Making the IDs human readable..."):
    why_org_human_readable[wid] = {
        (qid, looked_up_org.get(qid))
        for qid in inst_of_set
    }

# %%
why_org_counts = Counter()
for _, inst_of in why_org_human_readable.items():
    string_labels =  " & ".join([f"{name} ({qid})" or qid for qid, name in inst_of])
    why_org_counts[string_labels] += 1

# %%
why_org_counts.most_common()

# %% [markdown]
# Some examples:
#
# TODO
