# %%
from pathlib import Path
from rich import print
import pandas as pd

# %% [markdown]
# ### How many entities <u>more</u> do we detect by using subclassing?

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-with*subclassing-3col/PER.jsonl
# Out:
#    8726412 /home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/PER.jsonl
#    8730734 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl
#   17457146 total

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-with*subclassing-3col/LOC.jsonl
# Out:
#      2923 /home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/LOC.jsonl
#   3078459 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl
#   3081382 total

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-with*subclassing-3col/ORG.jsonl
# Out:
#     58753 /home/jonne/datasets/paranames/analyze-instance-ofs-withoutsubclassing-3col/ORG.jsonl
#   2196303 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/ORG.jsonl
#   2255056 total

# %%
print(f"[PER] Difference = {8730734 - 8726412}")
print(f"[LOC] Difference = {3078459 - 2923}")
print(f"[ORG] Difference = {2196303 - 58753}")
# Out:
# [PER] Difference = 4322
# [LOC] Difference = 3075536
# [ORG] Difference = 2137550

# %% [markdown]
# ### PER

# %% [markdown]
# First let's create a set of all entities that are a subclass of `Q5`:

# %%
from qwikidata.sparql import get_subclasses_of_item

# %%
subclass_of_human = set(get_subclasses_of_item('Q5', return_qids=True))

# %% [markdown]
# Then let's loop through *all* entities categorized as `PER` (but not an instance of `Q5`) and see what makes them `PER`.

# %%
import orjson
from rich.progress import track
from collections import Counter

# %%
import pymongo
client = pymongo.MongoClient(port=27617)
db = client['paranames_db_022822']
coll = db['paranames']

# %%
per_entities_jsonl_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl")

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl
# Out:
# 8730734 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl

# %%
def grab_first_available(label_dict):
    if not label_dict:
        return ''
    first_lang = [l for l in label_dict].pop(0)
    return label_dict[first_lang]

# %%
why_per = {}
with open(per_entities_jsonl_path, 'r', encoding="utf-8") as fin:
    look_up_these = set()
    for ix, line in track(enumerate(fin), total=8730733, description="Checking what makes PER entities PER..."):
        row = orjson.loads(line)
        wid = row['wikidata_id']
        name = row['name']
        instance_of = set(row['instance_of'])
        if "Q5" in instance_of:
            continue
        common = instance_of.intersection(subclass_of_human)
        if len(common) == 0:
            print(f"[{wid}] Entity '{name}' is not an instance of Q5 or any of its subclasses.")
        else:
            look_up_these.update(common)
            why_per[wid] = common
            
# Make the instance-of names human readable
looked_up_names = {
    r['id']: r['name']
    if r['name'] 
    else grab_first_available(r['labels']) 
    for r in coll.find(
        {"id": {"$in": list(look_up_these)}}
    )
}

why_per_human_readable = {}
for wid, inst_of_set in track(why_per.items(), description="Making the IDs human readable..."):
    why_per_human_readable[wid] = {
        (qid, looked_up_names.get(qid))
        for qid in inst_of_set
    }
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# OK, every PER entity is an instance of something that is a subclass of Q5.
#
# Now we can tally why the PER entities that were only detected with subclasses were categorized as such:

# %%
why_per_counts = Counter()
for _, inst_of in why_per_human_readable.items():
    string_labels =  " & ".join([f"{name} ({qid})" or qid for qid, name in inst_of])
    why_per_counts[string_labels] += 1

# %%
why_per_counts.most_common()
# Out:
# [('federally recognized Native American tribe in the United States (Q7840353)',
#   164),
#  ('human fetus (Q26513)', 68),
#  ('hypothetical person (Q75855169)', 51),
#  ('Police and Crime Commissioner (Q58333)', 39),
#  ('minister (Q83307)', 36),
#  ('inhabitant (Q22947)', 32),
#  ('Permanent Secretary (Q57901836)', 28),
#  ('fictional human formerly considered to be historical (Q64520857)', 26),
#  ('Director of Bureau (Q23931359)', 25),
#  ('ambassador to the United States of America (Q19359052)', 24),
#  ('Native Americans in the United States (Q49297)', 24),
#  ('ombudsman (Q169180)', 23),
#  ('civil servant (Q212238)', 23),
#  ('indigenous peoples of the Americas (Q36747)', 22),
#  ('passenger (Q319604)', 20),
#  ("ambassador to the People's Republic of China (Q30064335)", 19),
#  ('prisoner (Q1862087) & prisoner of a Nazi concentration camp (Q1719325)',
#   16),
#  ('board member (Q2824523)', 16),
#  ('Native American tribe (Q12885585)', 13),
#  ('ambassador of the United States of America (Q15726790)', 13),
#  ('judge (Q16533)', 10),
#  ('ambassador of the United Kingdom (Q18115939)', 10),
#  ('coach (Q41583)', 10),
#  ('prosopographical phantom (Q64643615)', 10),
#  ('fictional princess (Q61928601)', 9),
#  ('state-recognized tribe in the United States (Q104904387)', 8),
#  ('indigenous peoples of North America (Q15571255)', 8),
#  ('First Nations (Q392316)', 8),
#  ('tourist (Q5633897)', 8),
#  ('fictional queen (Q16658194)', 7),
#  ('None (Q29898672)', 7),
#  ('High Commissioner of the United Kingdom (Q56760832)', 7),
#  ('male human (Q84048850)', 7),
#  ('Sveriges delegationer (Q108059166)', 6),
#  ('Pharao im Mittleren Reich (Q110550696) & Pharao der 12. Dynastie (Q110550681) & pharaoh (Q37110)',
#   6),
#  ('Indigenous Australians (Q170355)', 6),
#  ('consul (Q207978)', 6),
#  ('Principal Private Secretary (Q665061)', 6),
#  ('chief of staff (Q707492)', 6),
#  ('Permanent Representative to the United Nations (Q7888495)', 5),
#  ('permanent representative (Q19356884)', 5),
#  ('military attaché (Q302691)', 5),
#  ('secretary of state (Q736559)', 5),
#  ('United States Assistant Secretary of State (Q742482)', 5),
#  ('pharaoh (Q37110) & Pharao im Alten Reich (Q110518305) & None (Q110552024)',
#   4),
#  ('State Minister (Q11397947)', 4),
#  ('United Nations Special Rapporteur (Q15143900)', 4),
#  ('Permanent Representative to the European Union (Q18449104)', 4),
#  ('ambassador of Romania (Q30158711)', 4),
#  ('ambassador to the United Kingdom (Q456692)', 4),
#  ('Permanent Representative to the United Nations Organizations in Geneva (Q57833747)',
#   4),
#  ('agriculture minister (Q10540834)', 3),
#  ('permanent representative to the United Nations at Vienna (Q108402412)', 3),
#  ('Pharao im Alten Reich (Q110518305) & Pharao der  5. Dynastie (Q110556685) & pharaoh (Q37110)',
#   3),
#  ('king (Q12097)', 3),
#  ('nomad (Q128393)', 3),
#  ('refugee (Q131572)', 3),
#  ('advocate general (Q1478218)', 3),
#  ('administrator (Q16532929)', 3),
#  ('skateboarder (Q17502714)', 3),
#  ('unidentified decedent (Q18356450)', 3),
#  ('Native Indonesians (Q1945590)', 3),
#  ('police commissioner (Q2101758)', 3),
#  ('stillborn (Q2345820)', 3),
#  ('chief of police (Q2855502)', 3),
#  ('federally recognized Native American tribe in the United States (Q7840353) & indigenous peoples of the Americas (Q36747)',
#   3),
#  ('consul general (Q3734658)', 3),
#  ('consejero autonómico (Q47176183)', 3),
#  ('Hispanic and Latino Americans (Q58669)', 3),
#  ('prosecutor (Q600751)', 3),
#  ('None (Q7614320)', 3),
#  ('honorary consul (Q1075179)', 2),
#  ('African people (Q1075929)', 2),
#  ('minister of state of El Salvador (Q108414874)', 2),
#  ('Amerindian literature in North America (Q109134999)', 2),
#  ('Pharao der 18. Dynastie (Q110551377) & Pharao im Neuen Reich (Q110551384) & pharaoh (Q37110)',
#   2),
#  ('ambassador (Q121998)', 2),
#  ('High Commissioner (Q123695)', 2),
#  ('federally recognized Native American tribe in the United States (Q7840353) & indigenous peoples of North America (Q15571255)',
#   2),
#  ('ambassador of the United States of America (Q15726790) & ambassador-at-large (Q4741053)',
#   2),
#  ('permanent representative (Q19356884) & ambassador of the United States of America (Q15726790)',
#   2),
#  ('ambassador to Burundi (Q38272152) & ambassador of the United States of America (Q15726790)',
#   2),
#  ('Ministry of Government (Q16607736)', 2),
#  ('Italian diaspora (Q1675084)', 2),
#  ('ambassador to the Grand Duchy of Tuscany (Q56850176) & ambassador of the United Kingdom (Q18115939)',
#   2),
#  ('ambassador of the United Kingdom (Q18115939) & Permanent Representative to the Council of Europe (Q57421531)',
#   2),
#  ('Inuit (Q189975)', 2),
#  ('diplomat (Q193391)', 2),
#  ('neighbour (Q1986893)', 2),
#  ('athlete (Q2066131)', 2),
#  ('chief of army staff position (Q2257775)', 2),
#  ('Israeli ambassador (Q23902382) & ambassador to Kazakhstan (Q29898858)', 2),
#  ('Israeli ambassador (Q23902382) & ambassador to Austria (Q29608929)', 2),
#  ('minister of culture (Q2621182)', 2),
#  ('ambassador of South Africa (Q30158578) & ambassador to Canada (Q29607391)',
#   2),
#  ('health minister (Q3273722)', 2),
#  ('indigenous peoples of Mexico (Q3314452)', 2),
#  ('ambassador of Singapore (Q38135159)', 2),
#  ('police officer (Q384593)', 2),
#  ('education minister (Q4018482)', 2),
#  ('federally recognized Native American tribe in the United States (Q7840353) & Native Americans in the United States (Q49297)',
#   2),
#  ('Spanish ambassador (Q6348379) & Permanent Representative to the United Nations (Q7888495)',
#   2),
#  ('queen consort (Q719039)', 2),
#  ('minister (Q83307) & secretary of state (Q736559)', 2),
#  ('Indigenous peoples of California (Q744299)', 2),
#  ('child (Q7569)', 2),
#  ('sports minister (Q7579929)', 2),
#  ('detective (Q842782)', 2),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador of the Austro-Hungarian Empire (Q100494551) & ambassador to Italy (Q21814442)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador of the Austro-Hungarian Empire (Q100494551) & ambassador to the German Reich (Q110694324)',
#   1),
#  ('None (Q29637599) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('ambassador to Spain (Q28555544) & ambassador of the Austro-Hungarian Empire (Q100494551)',
#   1),
#  ('francophones (Q100710385)', 1),
#  ('ambassador to the Solomon Islands (Q56850191) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Morocco (Q29898040) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ("ambassador to the People's Republic of China (Q30064335) & Saudi Arabia ambassador (Q100710470)",
#   1),
#  ('ambassador to Indonesia (Q30057149) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to South Korea (Q21814441) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Australia (Q29973167) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Sweden (Q28071226) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('None (Q30057185) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to Slovenia (Q29972832) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to the United Arab Emirates (Q30057151) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Afghanistan (Q30056283) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to the Czech Republic (Q30057157)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Lebanon (Q30057181)',
#   1),
#  ('ambassador to Pakistan (Q30056349) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Denmark (Q29971792) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Venezuela (Q30057166) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Somalia (Q30160620) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Portugal (Q29973442) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Norway (Q30057175) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Chile (Q30057141) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to Switzerland (Q28071147) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Senegal (Q30056479) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Iran (Q30057171)', 1),
#  ('ambassador to Japan (Q29898189) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Kuwait (Q30057130)',
#   1),
#  ('ambassador to Jordan (Q30057132) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Tunisia (Q29970486) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Slovakia (Q30057169) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Ireland (Q29970126) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Bangladesh (Q30057170) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Gabon (Q30249630) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to the United Kingdom (Q456692) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Syria (Q28064704) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Argentina (Q29898752)',
#   1),
#  ('ambassador to Turkmenistan (Q30057187) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Mauritania (Q38135453) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Liechtenstein (Q30249963) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to the European Union (Q101064552) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Nigeria (Q30249268)',
#   1),
#  ('ambassador to Luxembourg (Q29973520) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Sudan (Q37802473) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to Egypt (Q30056302) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Fiji (Q38271671)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Algeria (Q29624028)',
#   1),
#  ('ambassador to Chad (Q30063979) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to Bahrain (Q30057172) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Turkey (Q28038722) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to France (Q19359050) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('None (Q28796675) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to Azerbaijan (Q30057164) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Ghana (Q37803626) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to the Russian Federation (Q29511967) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Nepal (Q30057186)', 1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Greece (Q29898588)',
#   1),
#  ('ambassador to Austria (Q29608929) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to Bulgaria (Q29973348) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('Saudi Arabia ambassador (Q100710470) & ambassador to Belgium (Q29511906)',
#   1),
#  ('ambassador to Andorra (Q30065101) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('None (Q30057152) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to Oman (Q30057135) & Saudi Arabia ambassador (Q100710470)', 1),
#  ('ambassador to Guinea (Q30061429) & Saudi Arabia ambassador (Q100710470)',
#   1),
#  ('ambassador to the European Union (Q101064552)', 1),
#  ('ambassador to the European Union (Q101064552) & Israeli ambassador (Q23902382)',
#   1),
#  ('federally recognized Native American tribe in the United States (Q7840353) & Apache (Q102090)',
#   1),
#  ('Greeks (Q539051) & Poles (Q1026)', 1),
#  ('conscious collaborator of the State Security (Q104736802) & None (Q104716993)',
#   1),
#  ('federally recognized Native American tribe in the United States (Q7840353) & state-recognized tribe in the United States (Q104904387)',
#   1),
#  ('ambassador to Rwanda (Q29640790)', 1),
#  ('ambassador to Burundi (Q38272152)', 1),
#  ('ambassador to Mozambique (Q30307532)', 1),
#  ('bisexual man (Q105079567)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Mauritius (Q105138634)',
#   1),
#  ("ambassador to the People's Republic of China (Q30064335) & ambassador of Mauritius (Q105138634)",
#   1),
#  ('ambassador to Kyrgyzstan (Q30057188) & ambassador of Tajikistan (Q105159301)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Central African Republic (Q105337704)',
#   1),
#  ("ambassador to the People's Republic of China (Q30064335) & ambassador of the Central African Republic (Q105337704)",
#   1),
#  ('ambassador to Canada (Q29607391) & ambassador of the Central African Republic (Q105337704)',
#   1),
#  ('ambassador of the Central African Republic (Q105337704) & ambassador to France (Q19359050)',
#   1),
#  ('High Commissioner of Mozambique (Q105627328) & ambassador to Kenya (Q38131570)',
#   1),
#  ('ambassador to Malawi (Q40771726) & High Commissioner of Mozambique (Q105627328)',
#   1),
#  ('ambassador to Mozambique (Q30307532) & High Commissioner of Malawi (Q105627331)',
#   1),
#  ('High Commissioner of Kenya (Q105627361) & ambassador to Zimbabwe (Q30057145)',
#   1),
#  ('Mexican American poetry (Q105898065)', 1),
#  ('ambassador to Spain (Q28555544) & ambassador of the Austrian Empire (Q106085599)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & ambassador of the Austrian Empire (Q106085599)',
#   1),
#  ('None (Q29637599) & ambassador of the Austrian Empire (Q106085599)', 1),
#  ('Spanish ambassador (Q6348379) & ambassador to the United Kingdom of Great Britain and Ireland (Q106086666)',
#   1),
#  ('ambassador of the Russian Empire (Q110634640) & ambassador to the United Kingdom of Great Britain and Ireland (Q106086666)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & French ambassador (Q28061729)',
#   1),
#  ('Ambassador of the Imperial China (Q110637743) & ambassador to the United Kingdom of Great Britain and Ireland (Q106086666)',
#   1),
#  ('ambassador to the United Kingdom of Great Britain and Ireland (Q106086666) & ambassador of the Ottoman Empire (Q29971375)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Palau (Q106091169)',
#   1),
#  ('ambassador of Palau (Q106091169) & None (Q29970812)', 1),
#  ('ambassador to Japan (Q29898189) & ambassador of Palau (Q106091169)', 1),
#  ('None (Q106204647) & ambassador to Mozambique (Q30307532)', 1),
#  ('None (Q106204647) & ambassador to the United Kingdom (Q456692)', 1),
#  ('ambassador of Myanmar (Q106298798) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Myanmar (Q106298798) & ambassador to the United Kingdom (Q456692)',
#   1),
#  ('ambassador to São Tomé and Príncipe (Q106457780) & ambassador of Romania (Q30158711)',
#   1),
#  ('ambassador of Portugal (Q30061057) & ambassador to São Tomé and Príncipe (Q106457780)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to São Tomé and Príncipe (Q106457780)',
#   1),
#  ('ambassador of Honduras (Q106697436) & Permanent Representative to the United Nations (Q7888495)',
#   1),
#  ('ambassador of Honduras (Q106697436) & ambassador to France (Q19359050)', 1),
#  ('ambassador to Hungary (Q29439727) & ambassador of Azerbaijan (Q106834938)',
#   1),
#  ('ambassador of Guinea (Q107022423) & ambassador to Israel (Q30057159)', 1),
#  ('ambassador to the Russian Federation (Q29511967) & ambassador of Guinea (Q107022423)',
#   1),
#  ('None (Q107126597) & ambassador to the United States of America (Q19359052)',
#   1),
#  ("ambassador to the People's Republic of China (Q30064335) & None (Q107126597)",
#   1),
#  ("state's attorney (Q10726370)", 1),
#  ('ambassador to Spain (Q28555544) & ambassador of El Salvador (Q107302783)',
#   1),
#  ('honorary consul of Ireland (Q107419604) & honorary consul to Pakistan (Q107427787)',
#   1),
#  ('high commissioner of Maldives (Q107420584) & high commissioner to Sri Lanka (Q107420625)',
#   1),
#  ('honorary consul to Belize (Q107427555) & honorary consul of Barbados (Q107427335)',
#   1),
#  ('honorary consul of Rwanda (Q107427695) & honorary consul to Bangladesh (Q107427726)',
#   1),
#  ('honorary consul to Kazakhstan (Q107427758) & honorary consul of Singapore (Q107427745)',
#   1),
#  ('Permanent Representative to the United Nations (Q7888495) & ambassador of Barbados (Q107500590)',
#   1),
#  ('Portuguese (Q178630) & African people (Q1075929)', 1),
#  ('Sveriges delegationer (Q108059166) & Permanent Representative to the United Nations (Q7888495)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Uganda (Q108392983)',
#   1),
#  ('permanent representative to the United Nations at Vienna (Q108402412) & ambassador of Hungary (Q30161250)',
#   1),
#  ('permanent representative to the United Nations at Vienna (Q108402412) & ambassador of the United Kingdom (Q18115939)',
#   1),
#  ('permanent representative to the United Nations at Vienna (Q108402412) & ambassador of Italy (Q30158595)',
#   1),
#  ('permanent representative to OSCE (Q108411377) & ambassador of the United Kingdom (Q18115939)',
#   1),
#  ('Mexican American politicians (Q108605557)', 1),
#  ('High Commissioner of Pakistan (Q108737249) & ambassador to the United Kingdom (Q456692)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Turkmenistan (Q108865405)',
#   1),
#  ('ambassador to Turkey (Q28038722) & ambassador of Turkmenistan (Q108865405)',
#   1),
#  ("ambassador to the People's Republic of China (Q30064335) & ambassador of Turkmenistan (Q108865405)",
#   1),
#  ('Amerindian men (Q109328851)', 1),
#  ('None (Q109465839) & ambassador to Mexico (Q29511856)', 1),
#  ('Mexican American authors (Q109479668)', 1),
#  ('envoy (Q11051391)', 1),
#  ('None (Q110643371) & Pharao im Alten Reich (Q110518305) & pharaoh (Q37110)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to Samoa (Q110598070)', 1),
#  ('ambassador of the king of Aragon (Q110620436) & ambassador to the king of England (Q40107153)',
#   1),
#  ('ambassador of the king of Aragon (Q110620436) & ambassador to the king of Castile (Q110620736)',
#   1),
#  ('ambassador to the king of England (Q40107153) & Ambassador of the King of Castile (Q110620447)',
#   1),
#  ('ambassador to the king of Aragon (Q110620850) & Ambassador of the King of Castile (Q110620447)',
#   1),
#  ('ambassador of the Kingdom of England (Q110620925) & ambassador to the king of Castile (Q110620736)',
#   1),
#  ('ambassador of the Kingdom of England (Q110620925) & ambassador to the Tsardom of Russia (Q110634957)',
#   1),
#  ('ambassador of the Kingdom of England (Q110620925) & ambassador to the Kingdom of France (Q110795214)',
#   1),
#  ('ambassador of the United Kingdom of Great Britain and Ireland (Q110625897)',
#   1),
#  ('ambassador to Spain (Q28555544) & ambassador of the United Kingdom of Great Britain and Ireland (Q110625897)',
#   1),
#  ('ambassador of the United Kingdom of Great Britain and Ireland (Q110625897) & ambassador to Austria-Hungary (Q56849086)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the United Kingdom of Great Britain and Ireland (Q110625897)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the United Kingdom of Great Britain and Ireland (Q110625897)',
#   1),
#  ('None (Q29637599) & ambassador of the United Kingdom of Great Britain and Ireland (Q110625897)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the Kingdom of Great Britain (Q110626411)',
#   1),
#  ('ambassador of the Russian Empire (Q110634640) & ambassador to Austria-Hungary (Q56849086)',
#   1),
#  ('ambassador of the Russian Empire (Q110634640) & ambassador to Spain (Q28555544)',
#   1),
#  ('None (Q29637599) & ambassador of the Russian Empire (Q110634640)', 1),
#  ('ambassador of the Russian Empire (Q110634640) & ambassador to France (Q19359050)',
#   1),
#  ('Ambassador to the Republic of China (1912-1949) (Q110638023) & ambassador of the Russian Empire (Q110634640)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of the Russian Empire (Q110634640)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Russian Empire (Q110634640)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Russian Empire (Q110634739)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the Republic of China (1912-1949) (Q38831326)',
#   1),
#  ('Ambassador of the Imperial China (Q110637743) & ambassador to the Russian Empire (Q110634739)',
#   1),
#  ('ambassador to the Russian Empire (Q110634739) & ambassador of the Ottoman Empire (Q29971375)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the Russian Empire (Q110634739)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of the Tsardom of Russia (Q110634776)',
#   1),
#  ('ambassador of the Ottoman Empire (Q29971375) & ambassador to the Tsardom of Russia (Q110634957)',
#   1),
#  ('ambassador of the Archduchy of Austria (Q110636598) & ambassador to Spain (Q28555544)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the Archduchy of Austria (Q110636867)',
#   1),
#  ('ambassador to the Austrian Empire (Q110636887) & ambassador of the Ottoman Empire (Q29971375)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Austrian Empire (Q110636887)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the Austrian Empire (Q110636887)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of the Netherlands (Q29970594)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of the Kingdom of Italy (Q110788685)',
#   1),
#  ('Spanish ambassador (Q6348379) & Ambassador to the Imperial China (Q110637772)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of Belgium (Q28064761)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & French ambassador (Q28061729)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of the German Reich (Q30504670)',
#   1),
#  ('Ambassador to the Imperial China (Q110637772) & ambassador of Japan (Q29972272)',
#   1),
#  ('ambassador of the Soviet Union (Q40032299) & Ambassador to the Republic of China (1912-1949) (Q110638023)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & Ambassador to the Republic of China (1912-1949) (Q110638023)',
#   1),
#  ('Spanish ambassador (Q6348379) & Ambassador to the Republic of China (1912-1949) (Q110638023)',
#   1),
#  ('ambassador to the Soviet Union (Q38133278) & Ambassador of the Republic of China (Taiwan) (Q110638065)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & Ambassador of the Republic of China (Taiwan) (Q110638065)',
#   1),
#  ('ambassador to Spain (Q28555544) & Ambassador of the Republic of China (Taiwan) (Q110638065)',
#   1),
#  ('ambassador to Nicaragua (Q30158174) & Ambassador of the Republic of China (Taiwan) (Q110638065)',
#   1),
#  ('ambassador to Japan (Q29898189) & Ambassador of the Republic of China (Taiwan) (Q110638065)',
#   1),
#  ('ambassador to the Russian Federation (Q29511967) & Ambassador of the Republic of China (Taiwan) (Q110638065)',
#   1),
#  ('ambassador to Canada (Q29607391) & Ambassador of the Republic of China (Taiwan) (Q110638065)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the German Reich (Q110694324)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Republic of Texas (Q110710372)',
#   1),
#  ('ambassador to Spain (Q28555544) & ambassador of the Kingdom of Portugal (Q110795350)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the Kingdom of Portugal (Q110795474)',
#   1),
#  ('ambassador to Brazil (Q110936963) & ambassador of Sweden (Q9149754)', 1),
#  ('mixed martial arts fighter (Q11607585)', 1),
#  ('ambassador to Hungary (Q29439727) & ambassador of Denmark (Q11685588)', 1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Denmark (Q11685588)',
#   1),
#  ('ambassador to the United Kingdom (Q456692) & ambassador of Denmark (Q11685588)',
#   1),
#  ('ambassador of Denmark (Q11685588) & ambassador to Italy (Q21814442)', 1),
#  ('ambassador to Iceland (Q30056331) & ambassador of Denmark (Q11685588)', 1),
#  ('None (Q30057152) & ambassador of Denmark (Q11685588)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Denmark (Q11685588)', 1),
#  ('ambassador to Spain (Q28555544) & ambassador of Denmark (Q11685588)', 1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Estonia (Q11685589)',
#   1),
#  ('ambassador to the Russian Federation (Q29511967) & ambassador of Estonia (Q11685589)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Finland (Q30065086)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Iceland (Q30056331)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to New Zealand (Q30056446)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Hungary (Q29439727)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Indonesia (Q30057149)',
#   1),
#  ('ambassador to Lithuania (Q30249315) & ambassador of Estonia (Q11685589)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Latvia (Q30057136)', 1),
#  ('ambassador to Tajikistan (Q30057161) & ambassador of Estonia (Q11685589)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Tunisia (Q29970486)', 1),
#  ('ambassador to Norway (Q30057175) & ambassador of Estonia (Q11685589)', 1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Estonia (Q11685589)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to the United Kingdom (Q456692)',
#   1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Turkmenistan (Q30057187)',
#   1),
#  ('ambassador to Thailand (Q30057174) & ambassador of Estonia (Q11685589)', 1),
#  ('ambassador to Canada (Q29607391) & ambassador of Estonia (Q11685589)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Austria (Q29608929)', 1),
#  ('ambassador of Estonia (Q11685589) & ambassador to Uzbekistan (Q30057134)',
#   1),
#  ('caveperson (Q1190089)', 1),
#  ('French (Q121842)', 1),
#  ('transport minister (Q12339722)', 1),
#  ('ambassador of Australia (Q29512058) & ambassador to Cyprus (Q30057143) & High Commissioner (Q123695)',
#   1),
#  ('ambassador of Australia (Q29512058) & ambassador to Bangladesh (Q30057170) & High Commissioner (Q123695)',
#   1),
#  ('ambassador of Australia (Q29512058) & ambassador to Brunei (Q30057179) & High Commissioner (Q123695)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & head of mission (Q1251687) & ambassador to Greece (Q29898588)',
#   1),
#  ('head of mission (Q1251687)', 1),
#  ('research minister (Q1266327)', 1),
#  ('professional wrestler (Q13474373)', 1),
#  ('environment minister (Q1449973)', 1),
#  ('Indigenous peoples of South America (Q1479328)', 1),
#  ('ambassador of Uruguay (Q30106715) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of Albania (Q29972092) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Canada (Q29511881)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Andorra (Q30080394)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Georgia (Q30082250)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the Holy See (Q14917731)', 1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Hungary (Q30161250)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Australia (Q29512058)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Colombia (Q29972039)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of East Timor (Q30301586) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador of the Republic of Austria (Q29898009) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Iran (Q30055513)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Chile (Q30082431)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Mexico (Q30158640)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of the United Kingdom (Q18115939)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Romania (Q30158711)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Ukraine (Q15992673)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Germany (Q28070952)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Belgium (Q28064761)',
#   1),
#  ('ambassador of Portugal (Q30061057) & ambassador to the Holy See (Q14917731)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Palestine (Q20383035)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of the European Union (Q2092585)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & Israeli ambassador (Q23902382)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Switzerland (Q38152482)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of the Philippines (Q29933415)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Iceland (Q29971738)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Argentina (Q30158666)',
#   1),
#  ('ambassador to the Holy See (Q14917731) & ambassador of Kenya (Q38243929)',
#   1),
#  ('attorney general (Q1501926)', 1),
#  ('high school student (Q15360275)', 1),
#  ('governor (Q1540323)', 1),
#  ('apostolic nuncio (Q157037) & None (Q29970812)', 1),
#  ('apostolic nuncio (Q157037) & ambassador to Libya (Q30056069)', 1),
#  ('permanent representative (Q19356884) & apostolic nuncio (Q157037)', 1),
#  ('apostolic nuncio (Q157037) & ambassador to Israel (Q30057159)', 1),
#  ('apostolic nuncio (Q157037)', 1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Kuwait (Q30057130)',
#   1),
#  ('None (Q28796675) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Peru (Q29970158)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Armenia (Q30057137)',
#   1),
#  ('ambassador to Pakistan (Q30056349) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Libya (Q30056069)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Bahamas (Q37773919)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Bahrain (Q30057172)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Malawi (Q40771726)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Nauru (Q38271924)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Venezuela (Q30057166)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Brazil (Q29973306)',
#   1),
#  ('ambassador to Cuba (Q30061268) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Mauritius (Q37770046)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Monaco (Q30063875)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Niger (Q30056959)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Antigua and Barbuda (Q30301630)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to East Germany (Q30106718)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Iran (Q30057171)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Spain (Q28555544)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Afghanistan (Q30056283)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Bulgaria (Q29973348)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to South Sudan (Q30061448)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Tunisia (Q29970486)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Albania (Q29971890)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Eritrea (Q30250001)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Sweden (Q28071226)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Argentina (Q29898752)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Latvia (Q30057136)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Indonesia (Q30057149)',
#   1),
#  ('None (Q30057152) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Estonia (Q29970877)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to East Timor (Q30301646)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Jamaica (Q30250132)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Somalia (Q30160620)',
#   1),
#  ('ambassador to Equatorial Guinea (Q30061428) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Nepal (Q30057186)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Mauritania (Q38135453)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Sierra Leone (Q38280710)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Senegal (Q30056479)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q29637599)',
#   1),
#  ('None (Q30063950) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Australia (Q29973167)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Angola (Q30303350)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Georgia (Q30057156)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Luxembourg (Q29973520)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Guinea (Q30061429)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Cape Verde (Q40240177)',
#   1),
#  ('ambassador to Rwanda (Q29640790) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to El Salvador (Q30057163)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Gabon (Q30249630)',
#   1),
#  ('ambassador to Kiribati (Q30061431) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Papua New Guinea (Q38716711)',
#   1),
#  ('ambassador to Tajikistan (Q30057161) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Laos (Q30057144)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to San Marino (Q48828900)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Philippines (Q30057182)',
#   1),
#  ('ambassador to Egypt (Q30056302) & ambassador of the United States of America (Q15726790)',
#   1),
#  ("ambassador to the People's Republic of China (Q30064335) & ambassador of the United States of America (Q15726790)",
#   1),
#  ('ambassador to the Republic of the Congo (Q38134453) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Zimbabwe (Q30057145)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Morocco (Q29898040)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Yemen (Q30249188)',
#   1),
#  ('ambassador to Ukraine (Q29917636) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to South Vietnam (Q30056117)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Cambodia (Q30057155)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Uganda (Q30057148)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Italy (Q21814442)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q30249889)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Iceland (Q30056331)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to North Macedonia (Q30151243)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Tuvalu (Q38272056)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Japan (Q29898189)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Fiji (Q38271671)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Liechtenstein (Q30249963) & ambassador to Switzerland (Q28071147)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Bangladesh (Q30057170)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Iraq (Q30055990)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Kazakhstan (Q29898858)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Yugoslavia (Q30159125)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Seychelles (Q30249587)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Kosovo (Q38272297)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Vanuatu (Q38135935)',
#   1),
#  ('ambassador to Uruguay (Q30057139) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Oman (Q30057135)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Colombia (Q30063921)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Cameroon (Q37770827)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the United Arab Emirates (Q30057151)',
#   1),
#  ('ambassador to Slovakia (Q30057169) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Palau (Q40243457)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Belarus (Q30081888)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Democratic Republic of Congo (Q38134585)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Denmark (Q29971792)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Ghana (Q37803626)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Belize (Q56850184)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Chile (Q30057141)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Ecuador (Q30057184)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Brunei (Q30057179)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Panama (Q30063931)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Czechoslovakia (Q30159256)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Syria (Q28064704)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q30105055)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Canada (Q29607391)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Czech Republic (Q30057157)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q29970812)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Israel (Q30057159)',
#   1),
#  ('ambassador to Kyrgyzstan (Q30057188) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to India (Q30056023)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Paraguay (Q30158196)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Singapore (Q30057178)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Burkina Faso (Q4741151)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Montenegro (Q30105252)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Hungary (Q29439727)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Malta (Q29575417)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Lebanon (Q30057181)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to South Africa (Q29986627)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Netherlands (Q29898619)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Madagascar (Q30035798)',
#   1),
#  ('None (Q56850189) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Moldova (Q30159284)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Korea (Q38133909)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Russian Federation (Q29511967)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Turkmenistan (Q30057187)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Austria (Q29608929)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Djibouti (Q38288666)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Bosnia and Herzegovina (Q30057131)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Guatemala (Q30057173)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Slovenia (Q29972832)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Romania (Q30056294)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Turkey (Q28038722)',
#   1),
#  ('ambassador to Poland (Q28071176) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to South Yemen (Q30249471) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Saudi Arabia (Q30057165)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Nigeria (Q30249268)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to New Zealand (Q30056446)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Serbia (Q30249223)',
#   1),
#  ('ambassador to Benin (Q30062766) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to the Gambia (Q30249893) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Tanzania (Q30249429)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Chad (Q30063979)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Barbados (Q38288681)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to the Central African Republic (Q38271520)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Croatia (Q30104588)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Bolivia (Q30057160)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Suriname (Q40333148)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Ireland (Q29970126)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Portugal (Q29973442)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Qatar (Q30056203)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Liberia (Q37772375)',
#   1),
#  ("ambassador to Côte d'Ivoire (Q29641344) & ambassador of the United States of America (Q15726790)",
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Finland (Q30065086)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Cyprus (Q30057143)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Algeria (Q29624028)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Austria-Hungary (Q56849086)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Zambia (Q30056458)',
#   1),
#  ('ambassador to Azerbaijan (Q30057164) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Belgium (Q29511906)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Uzbekistan (Q30057134)',
#   1),
#  ('ambassador to Lesotho (Q30249612) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador to Myanmar (Q30057154) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q40244299)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Mongolia (Q30057167)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Trinidad and Tobago (Q38271385)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Mali (Q30064049)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Kenya (Q38131570)',
#   1),
#  ('ambassador to South Korea (Q21814441) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q30057185)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & None (Q40240399)',
#   1),
#  ('ambassador to Norway (Q30057175) & ambassador of the United States of America (Q15726790)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to Honduras (Q30057177)',
#   1),
#  ('ambassador of the United States of America (Q15726790) & ambassador to North Yemen (Q30249202)',
#   1),
# ...
#   1),
#  ('ambassador of the United Kingdom (Q18115939) & ambassador to Uzbekistan (Q30057134)',
#   1),
#  ('ambassador of the United Kingdom (Q18115939) & ambassador to Guatemala (Q30057173)',
#   1),
#  ('ambassador of the United Kingdom (Q18115939) & ambassador to Persia (Q56850168)',
#   1),
#  ('ambassador of the United Kingdom (Q18115939) & ambassador to Finland (Q30065086)',
#   1),
#  ('Permanent Representative to the European Union (Q18449104) & ambassador of the Republic of Austria (Q29898009)',
#   1),
#  ('Permanent Representative to the European Union (Q18449104) & ambassador of Germany (Q28070952)',
#   1),
#  ('Lithuanians (Q186192)', 1),
#  ('prisoner (Q1862087) & Kapo (Q702997)', 1),
#  ('prisoner (Q1862087) & police officer (Q384593) & prison officer (Q311396)',
#   1),
#  ('cosplayer (Q18810049)', 1),
#  ('wife (Q188830)', 1),
#  ('migrant (Q1932461)', 1),
#  ('minister of the Netherlands (Q19334526)', 1),
#  ('permanent representative (Q19356884) & ambassador of Hungary (Q30161250)',
#   1),
#  ('permanent representative (Q19356884) & French ambassador (Q28061729)', 1),
#  ('ambassador of Germany (Q28070952) & ambassador to France (Q19359050)', 1),
#  ('Israeli ambassador (Q23902382) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Tunisia (Q29646039)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Kenya (Q38243929)', 1),
#  ('ambassador of Lithuania (Q30064875) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Lebanon (Q30076709)', 1),
#  ('ambassador of Bolivia (Q30158606) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Sri Lanka (Q30068647) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Sweden (Q9149754)', 1),
#  ('ambassador of the Republic of Austria (Q29898009) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador of Bahrain (Q40554294) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of India (Q30061036)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Romania (Q30158711)', 1),
#  ('None (Q29898672) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Ivory Coast (Q29971577)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Cuba (Q30158616)', 1),
#  ('ambassador of the Soviet Union (Q40032299) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador to France (Q19359050) & Venezuelan ambassador (Q30158724)', 1),
#  ('ambassador of Albania (Q29972092) & ambassador to France (Q19359050)', 1),
#  ('ambassador of the Russian Federation (Q28038712) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Montenegro (Q30061165)',
#   1),
#  ('ambassador to France (Q19359050)', 1),
#  ('ambassador of Pakistan (Q30158743) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Guatemala (Q30076857)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Serbia (Q38152244)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Libya (Q38288651)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Canada (Q29511881)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Armenia (Q30249655)', 1),
#  ('ambassador of Uruguay (Q30106715) & ambassador to France (Q19359050)', 1),
#  ('ambassador of New-Zealand (Q30055488) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador of Poland (Q30064617) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Jordan (Q30076785)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Argentina (Q30158666)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Czechoslovakia (Q40453861)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Iceland (Q29971738)', 1),
#  ('ambassador to France (Q19359050) & ambassador of the Netherlands (Q29970594)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of the Republic of the Congo (Q29899026)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Malaysia (Q38288600)', 1),
#  ('Equatorial Guinea ambassador (Q28555512) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Burkina Faso (Q38258039)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Hungary (Q30161250)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Switzerland (Q38152482)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Ghana (Q95567639)', 1),
#  ('ambassador of the Czech Republic (Q60038322) & ambassador to France (Q19359050)',
#   1),
#  ('ambassador to France (Q19359050) & ambassador of Andorra (Q30080394)', 1),
#  ('ambassador of Turkey (Q29971416) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Portugal (Q30061057) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Egypt (Q30068618) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of South Korea (Q29970783)',
#   1),
#  ('ambassador of Morocco (Q29971182) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Greece (Q30161199)', 1),
#  ('ambassador of Slovakia (Q30249299) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Peru (Q29970009) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Norway (Q30158720)', 1),
#  ('None (Q2841895) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Belgium (Q28064761) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Monaco (Q30105179) & ambassador to France (Q19359050)', 1),
#  ('Burundian Ambassador (Q30076608) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Japan (Q29972272) & ambassador to France (Q19359050)', 1),
#  ('ambassador of Cyprus (Q55593891) & ambassador to France (Q19359050)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Malawi (Q90404048)', 1),
#  ('ambassador to France (Q19359050) & ambassador of Nigeria (Q30301734)', 1),
#  ('ambassador of Angola (Q40455712) & ambassador to France (Q19359050)', 1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Syria (Q29971465)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Sri Lanka (Q30068647)',
#   1),
#  ('None (Q2841895) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Guyana (Q38154664) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('Spanish ambassador (Q6348379) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Comoros (Q40455770) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Croatia (Q30104607)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Dominica (Q30105087)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Cape Verde (Q40455673)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Colombia (Q29972039)',
#   1),
#  ('Cambodian ambassador (Q38155268) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Kyrgyzstan (Q40455660) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Czech Republic (Q60038322)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Eritrea (Q30250016)',
#   1),
#  ('ambassador of Gabon (Q40339224) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Vietnam (Q40543107)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Serbia (Q38152244)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Sudan (Q40455758)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Sweden (Q9149754)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Greece (Q30161199)',
#   1),
#  ('ambassador of Angola (Q40455712) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Turkey (Q29971416)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Kazakhstan (Q30105218)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the German Reich (Q30504670)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Jordan (Q30076785)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Armenia (Q30249655)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Paraguay (Q30158675)',
#   1),
#  ('ambassador of Qatar (Q38717123) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of Bahrain (Q40554294) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Bulgaria (Q38281228)',
#   1),
#  ('ambassador of Djibouti (Q40455648) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Moldova (Q38272559)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Mauritania (Q38135561)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Hungary (Q30161250)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of South Korea (Q29970783)',
#   1),
#  ('ambassador of Pakistan (Q30158743) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of New-Zealand (Q30055488) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador of the Russian Federation (Q28038712) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Montenegro (Q30061165)',
#   1),
#  ('ambassador of Uruguay (Q30106715) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Bangladesh (Q30076076)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of São Tomé and Príncipe (Q40455722)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Singapore (Q38135159)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & Ambassador of Zambia (Q38281863)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Romania (Q30158711)',
#   1),
#  ('ambassador of Brazil (Q30081331) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of North Macedonia (Q30151218)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Maldives (Q30076753)',
#   1),
#  ('ambassador of the Republic of Austria (Q29898009) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Botswana (Q37773129)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Lebanon (Q30076709)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Bosnia and Herzegovina (Q39664395)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Tunisia (Q29646039)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & Yemeni ambassador (Q38281623)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Cuba (Q30158616)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Bolivia (Q30158606)',
#   1),
#  ('ambassador of South Africa (Q30158578) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Rwanda (Q30064661)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Bahamas (Q30158655)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Nauru (Q38271782)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Chad (Q40455783)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Uzbekistan (Q38715811)',
#   1),
#  ('ambassador of Slovakia (Q30249299) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Brunei (Q38288637)',
#   1),
#  ('ambassador of Egypt (Q30068618) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('Israeli ambassador (Q23902382) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Iran (Q30055513)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Peru (Q29970009)',
#   1),
#  ('None (Q29898672) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & French ambassador (Q28061729)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Netherlands (Q29970594)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & Burundian Ambassador (Q30076608)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Liberia (Q37772652)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & Equatorial Guinea ambassador (Q28555512)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Mexico (Q30158640)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Kenya (Q38243929)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of South Sudan (Q40455798)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Finland (Q40651705)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Switzerland (Q38152482)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Argentina (Q30158666)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Mozambique (Q38244903)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & Gambian ambassador (Q30249960)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Fiji (Q92116627)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Monaco (Q30105179)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Kuwait (Q40455744)',
#   1),
#  ('ambassador of Madagascar (Q40455808) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Slovenia (Q64547173)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Namibia (Q38715599)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Seychelles (Q38134865)',
#   1),
#  ('ambassador of the Soviet Union (Q40032299) & ambassador to the United States of America (Q19359052)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of India (Q30061036)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Luxembourg (Q30161428)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of Canada (Q29511881)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & ambassador of the Ottoman Empire (Q29971375)',
#   1),
#  ('ambassador to the United States of America (Q19359052) & None (Q39662504)',
#   1),
#  ('ambassador of Australia (Q29512058) & ambassador to the United States of America (Q19359052)',
#   1),
#  ...]

# %% [markdown]
# ### Where do these weird inheritance hierarchies come from?
#
# This will be infeasible to analyze for everything but here are a few examples:
#
# For example, `Quechan people` is an instance of `indigenous peoples of the Americas ` (Q36747).

# %%
# %%bash
#
# rg "Q36747" /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl | head -n 1 | jq
# Out:
# {
#   "wikidata_id": "Q1754503",
#   "name": "Quechan people",
#   "type": "PER",
#   "instance_of": [
#     "Q7840353",
#     "Q36747",
#     "Q133311"
#   ]
# }

# %% [markdown]
# We can check what it's an instance of with human-readable names:

# %%
why_per_human_readable["Q1754503"]
# Out:
# {('Q36747', 'indigenous peoples of the Americas'),
#  ('Q7840353',
#   'federally recognized Native American tribe in the United States')}

# %% [markdown]
# Looking at [`indigenous peoples of the Americas`](https://www.wikidata.org/wiki/Q36747), we can see that it is a subclass of [`Americans`](https://www.wikidata.org/wiki/Q2384959), which in turn is a subclass of [`inhabitant`](https://www.wikidata.org/wiki/Q22947), which itself is a subclass of [`human`](https://www.wikidata.org/wiki/Q5).
#
# This implies that anything that is an instance of `indigenous peoples of the Americas` is also an instance of `human`.

# %% [markdown]
# A second example: [`Louise Victoria, Princess of Grão-Pará`](https://www.wikidata.org/wiki/Q51883211):

# %%
# %%bash
#
# rg "Q26513" /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl | head -n 2 | tail -n1 | jq
# Out:
# {
#   "wikidata_id": "Q51883211",
#   "name": "Louise Victoria, Princess of Grão-Pará",
#   "type": "PER",
#   "instance_of": [
#     "Q26513"
#   ]
# }

# %% [markdown]
# is an instance of [`human fetus`](https://www.wikidata.org/wiki/Q26513).
#
# [`human fetus`](https://www.wikidata.org/wiki/Q26513) is an instance of [`prenate`](https://www.wikidata.org/wiki/Q63177820) which is a subclass of [`human`](https://www.wikidata.org/wiki/Q5).
#
# Thus, `Louise Victoria, Princess of Grão-Pará` is PER.

# %% [markdown]
# Third example: [`Marcus Horatius`](https://www.wikidata.org/wiki/Q55463614)

# %%
# %%bash
#
# rg "Q75855169" /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/PER.jsonl | head -n 1 | jq
# Out:
# {
#   "wikidata_id": "Q55463614",
#   "name": "Marcus Horatius",
#   "type": "PER",
#   "instance_of": [
#     "Q75855169"
#   ]
# }

# %% [markdown]
# is an instance of [`hypothetical person (Q75855169)`](https://www.wikidata.org/wiki/Q75855169) which is a subclass of `human` and thus `Marcus Horatius` is also a PER.

# %% [markdown]
# ### LOC

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl
# Out:
# 3078459 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl

# %%
loc_entities_jsonl_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl")
subclass_of_geographic_region = get_subclasses_of_item("Q82794")

# %%
why_loc = {}
with open(loc_entities_jsonl_path, 'r', encoding="utf-8") as fin:
    look_up_these_loc = set()
    for ix, line in track(enumerate(fin), total=3078459, description="Checking what makes LOC entities LOC..."):
        row = orjson.loads(line)
        wid = row['wikidata_id']
        name = row['name']
        instance_of = set(row['instance_of'])
        if "Q82794" in instance_of:
            continue
        common = instance_of.intersection(subclass_of_geographic_region)
        why_loc_value = common if len(common) > 0 else instance_of
        assert all(type(thing) == str for thing in why_loc_value), row
        look_up_these_loc.update(why_loc_value)
        why_loc[wid] = why_loc_value
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# Make the instance-of names human readable
looked_up_loc = {
    r['id']: r['name']
    if r['name'] 
    else grab_first_available(r['labels']) 
    for r in coll.find(
        {"id": {"$in": list(look_up_these_loc)}}
    )
}

# %%
looked_up_loc
# Out:
# {'Q10007123': 'Griqua state',
#  'Q1000858': 'region of the Faroe Islands',
#  'Q100154387': 'national military park',
#  'Q100205512': 'administrative territorial entity of ancient Rome',
#  'Q100222740': 'National Battlefield Park',
#  'Q100252623': 'pakihi',
#  'Q100268926': 'iberian settlement',
#  'Q1002812': 'metropolitan borough',
#  'Q100319996': 'resource conservation district',
#  'Q1003207': 'photovoltaic power station',
#  'Q1004435': 'athletics track',
#  'Q1004887': 'thermal bath',
#  'Q100503226': 'town of the United Kingdom',
#  'Q100590008': 'notary district',
#  'Q1005901': 'federal level',
#  'Q100606393': 'Union of States',
#  'Q1006357': 'hanging valley',
#  'Q100649': 'blackwater river',
#  'Q1006733': 'grassland',
#  'Q1006835': 'Main Street',
#  'Q1006876': 'borough in the United Kingdom',
#  'Q100689072': 'quarter of La Spezia',
#  'Q100701580': 'quarter of Cagliari',
#  'Q100705184': 'Quarter of Catania',
#  'Q1007870': 'art gallery',
#  'Q100900880': 'crater lake',
#  'Q1009249': 'national waterways in Germany',
#  'Q100936765': 'hornatina',
#  'Q100996875': 'wakeboarding resort',
#  'Q100997915': 'steenhouwerij',
#  'Q100998087': 'myriarchy',
#  'Q101006941': 'district of Isfahan',
#  'Q101008619': 'rescue excavation',
#  'Q101057139': 'county of Razavi Khorasan Province',
#  'Q101061294': 'handcraft shop',
#  'Q101063310': 'Jewish community',
#  'Q101068465': 'deserted historic site',
#  'Q101085149': 'former Gram Panchayat',
#  'Q101217256': 'medium-sized electoral district of the House of Representatives of Japan',
#  'Q101224664': 'settlement house',
#  'Q101244826': 'skittle alley',
#  'Q101418016': 'historical regions of Belarus',
#  'Q101434824': 'United States senate seat (Class 1)',
#  'Q101434854': 'United States senate seat (Class 2)',
#  'Q101434877': 'United States senate seat (Class 3)',
#  'Q10145': 'milestone',
#  'Q1014817': 'castle well',
#  'Q101500100': 'district of Lohja',
#  'Q101502735': 'lock pond',
#  'Q1015644': 'Burgstall',
#  'Q101659': 'dolmen',
#  'Q1016714': 'burn',
#  'Q1016853': 'burnt mound',
#  'Q101998': 'biome',
#  'Q102104752': 'city of Bosnia and Herzegovina',
#  'Q1021096': 'civic community',
#  'Q1021106': 'town house',
#  'Q1021233': 'Bürgermeisterei',
#  'Q1021290': 'music school',
#  'Q102131920': 'Thikana',
#  'Q1021404': 'Бюргершафт',
#  'Q1021645': 'office building',
#  'Q1021711': 'seaside resort',
#  'Q102201947': 'Samian Ware Kilnregion',
#  'Q102202026': 'Samian Ware Production centre',
#  'Q102202066': 'Samian Ware Discovery Site',
#  'Q102240431': 'Chinese village',
#  'Q1022469': 'regional council of Israel',
#  'Q102307360': 'cycling route',
#  'Q102335849': 'comarca agraria',
#  'Q102496': 'parish',
#  'Q1025116': 'province of the Solomon Islands',
#  'Q1025961': 'capital of Japan',
#  'Q10262936': 'municipal chamber in Brazil',
#  'Q10267322': 'state district of Brazil',
#  'Q10267336': 'neighborhood of Madrid',
#  'Q10270157': 'new town',
#  'Q10273457': 'equipment',
#  'Q10277595': 'Estância Turística',
#  'Q102782189': 'former Block Panchayat',
#  'Q102786': 'abbreviation',
#  'Q10280357': 'favela in São Paulo',
#  'Q10283556': 'motive power depot',
#  'Q102854139': 'former parish in Denmark',
#  'Q1028645': 'dead mall',
#  'Q1028869': 'sidewalk cafe',
#  'Q1029013': 'Megaregions of the United States',
#  'Q10296503': 'Župa',
#  'Q10300916': 'cultural heritage of China',
#  'Q1030097': 'campagne',
#  'Q10301251': 'Ilhas Adjacentes',
#  'Q1030403': 'navigable aqueduct',
#  'Q10313934': 'intermittent lake',
#  'Q1032372': 'hackerspace',
#  'Q103355610': 'quarantine area',
#  'Q1033904': 'cantref',
#  'Q10358838': 'region of Paraguay',
#  'Q10359762': 'Biological reserve in Brazil',
#  'Q10359778': 'Sustainable Development Reserve',
#  'Q103683243': 'tribal national park',
#  'Q10373548': 'whisky distillery',
#  'Q10373565': 'waterworks',
#  'Q10374485': 'Sub-bairro',
#  'Q10374527': 'administrative territorial entity of Grenada',
#  'Q10374536': 'administrative territorial entity of Brazil',
#  'Q10374547': 'administrative territorial entity of Paraguay',
#  'Q10376531': 'geological site',
#  'Q103800433': 'housing complex',
#  'Q103910131': 'part of city or town or population centre',
#  'Q103910177': 'city or town or population centre',
#  'Q103910453': 'village or neigbourhood',
#  'Q1039325': 'Janapada',
#  'Q10395987': 'Environmental Protection Area in Brazil',
#  'Q10395989': 'Area of Significant Ecological Interest',
#  'Q104117291': 'region of Spain',
#  'Q104146934': 'United States of America State-level electoral district',
#  'Q104157': 'city of the Philippines',
#  'Q10416961': 'working life museum',
#  'Q104172772': 'freguesia',
#  'Q104200053': 'woolen mill',
#  'Q104216506': 'Water powered sawmill',
#  'Q1042490': 'trail blazing',
#  'Q104251': 'county of Albania',
#  'Q10425989': 'indoor bandy venue',
#  'Q104347069': 'lake system',
#  'Q10436265': 'bruk',
#  'Q10436273': '直隸州',
#  'Q1043639': 'gay bar',
#  'Q10436455': 'brunnsort',
#  'Q10436913': 'lumber yard',
#  'Q10438274': 'byråd',
#  'Q1043939': 'Carnegie library',
#  'Q104417590': 'sports venue under construction',
#  'Q1044181': 'state of Palau',
#  'Q1044204': 'gusuku',
#  'Q104442652': 'Territory of a tribe',
#  'Q104454065': 'Pieve milanese',
#  'Q104471354': 'senhorio',
#  'Q1044880': 'subprefecture-level city',
#  'Q104488513': 'proposed city',
#  'Q104527265': 'planning area of Singapore',
#  'Q104540757': 'senhorio de juro e herdade',
#  'Q1045593': 'county-controlled district',
#  'Q1045608': 'prefecture',
#  'Q10460934': 'artificial hill',
#  'Q104628993': 'electoral circumscription of Romania',
#  'Q104630835': 'Scottish county of city',
#  'Q104632385': 'Scottish health board area',
#  'Q104641871': 'taajaman osa',
#  'Q104649845': 'film organization',
#  'Q10466612': 'Danmarks län',
#  'Q104684704': 'wine subregion',
#  'Q104694724': 'public college',
#  'Q10475839': 'judicial district',
#  'Q104764681': 'interfaith organization',
#  'Q104774075': 'urbanized area',
#  'Q104774089': 'urban cluster',
#  'Q104774336': 'dune landscape',
#  'Q104782082': 'territory outside RCM',
#  'Q104804750': 'réserve naturelle reconnue',
#  'Q104805859': 'Jewish organization',
#  'Q10480682': 'agricultural structure',
#  'Q1048194': 'tropical forest',
#  'Q10482023': 'electricity plant',
#  'Q1048337': 'underground lake',
#  'Q104836794': 'Líderes Villa 14 de Septiembre',
#  'Q104841013': 'hromada',
#  'Q104843': 'cruiser',
#  'Q1048525': 'golf course',
#  'Q1048652': 'autonomous oblast',
#  'Q104865988': 'COVID-19 vaccination center in France',
#  'Q104870786': 'amber deposit site',
#  'Q104879310': 'bio-secure bubble',
#  'Q1048835': 'political territorial entity',
#  'Q104889030': 'district of the Society of St. Pius X',
#  'Q104905143': 'Washington state wildlife area',
#  'Q104907523': 'Washington Natural Area Preserve System',
#  'Q10491460': 'Europeiska unionens befogenhetsområden',
#  'Q10492745': 'event arena',
#  'Q1049540': 'administrative territorial entity of Northern Ireland',
#  'Q104964763': 'archdiocese not metropolitan',
#  'Q1049757': 'multi-purpose stadium',
#  'Q1049792': 'rolling mill',
#  'Q10498262': 'relict field system',
#  'Q10498305': 'Indoor football arena',
#  'Q104999170': 'county office of education in California',
#  'Q1050126': "sub-provincial district of the People's Republic of China",
#  'Q10501612': 'Defence district',
#  'Q105027504': 'Republic of Korea Marine Corps unit',
#  'Q105029714': 'integrated solar combined-cycle power plant',
#  'Q1050303': 'downtown',
#  'Q105036777': 'pedestrian tunnel',
#  'Q10504641': 'rifle factory',
#  'Q105046919': 'сядзібна-паркавы комплекс',
#  'Q105071161': 'Republic of Korea Military Training unit',
#  'Q105072138': 'catholic archdiocese',
#  'Q105072162': 'Catholic archdiocese not metropolitan',
#  'Q105080952': 'tidal flat',
#  'Q10508453': 'grave and settlement area',
#  'Q10509765': 'border forest',
#  'Q105098259': 'peat bog',
#  'Q1051067': 'pre-dreadnought battleship',
#  'Q10512405': 'guest harbor',
#  'Q1051411': 'province of São Tomé and Príncipe',
#  'Q10514237': 'Indigenous Protected Area',
#  'Q105190': 'levee',
#  'Q10521078': 'megalithic tomb',
#  'Q105224099': 'group of valleys',
#  'Q105254117': 'Ortschaft (Baden-Württemberg)',
#  'Q10526681': 'court chapel / court capella',
#  'Q1052743': 'region of Ghana',
#  'Q105322523': 'United States Signals Brigade',
#  'Q1053448': 'census county division',
#  'Q1053463': 'census geographic unit of Canada',
#  'Q10535394': 'informellt område',
#  'Q105360141': 'kyselka',
#  'Q105360482': 'motocross circuit',
#  'Q10536097': 'institutionsteater',
#  'Q1053630': 'province of Papua New Guinea',
#  'Q105365845': 'Republic of Korea Wing',
#  'Q105370186': 'tourism region of Slovakia',
#  'Q105388829': 'Roman Catholic diocese',
#  'Q105389481': 'catholic eparchy',
#  'Q105406193': 'Roman Catholic archdiocese',
#  'Q105419665': 'Roman Catholic archdiocese not metropolitan',
#  'Q105420623': 'Washington Natural Resources Conservation Area',
#  'Q105431749': 'aldeia of East Timor',
#  'Q105437266': 'United States Army Engineer Brigade',
#  'Q105438538': 'United States Army Air Defense Artillery Brigade',
#  'Q1054403': 'region of Guinea-Bissau',
#  'Q10545864': 'kism',
#  'Q10546851': 'Kobbe',
#  'Q10547557': 'conference facility',
#  'Q10547643': 'concert hall',
#  'Q1054813': 'municipality of Japan',
#  'Q10549487': 'Kronoholme islands',
#  'Q1054949': 'Ceresbrunnen',
#  'Q10550024': 'cultural reserve',
#  'Q10551473': 'parish union',
#  'Q10551482': 'church library district',
#  'Q105522978': 'rural district council',
#  'Q105523003': 'urban district council',
#  'Q105535509': 'curling venue',
#  'Q105537790': 'Republic of Korea Fighter Wing',
#  'Q105538253': 'online shop',
#  'Q10554290': 'lappstad',
#  'Q105582114': 'Scottish Regional Council',
#  'Q105587861': 'kolonie rodinných domů',
#  'Q105588854': 'nouzová kolonie',
#  'Q105626471': 'subdistrict of India',
#  'Q10564300': 'copper mine',
#  'Q10564515': 'monzenmachi',
#  'Q105658132': 'district of Legnano',
#  'Q10565932': 'reijō',
#  'Q105671369': 'marine command',
#  'Q105672858': 'Alla hopp!-Anlage',
#  'Q105686546': 'bindery',
#  'Q10571400': 'köping',
#  'Q10571947': 'county museum',
#  'Q10571983': 'länsteater',
#  'Q10572388': 'läroverk',
#  'Q105728095': 'former congressional district of the Philippines',
#  'Q105731': 'lock',
#  'Q105742562': 'canal estate',
#  'Q1057504': 'region of Ethiopia',
#  'Q105755419': 'football pitch',
#  'Q105758208': 'power plant complex',
#  'Q10577447': 'maritime command',
#  'Q10577534': 'markaz of Egypt',
#  'Q105819240': 'former constituency of the Kerala Legislative Assembly',
#  'Q105835744': 'regional cultural heritage site in Russia',
#  'Q1058387': 'district of Malawi',
#  'Q10585329': 'militärförsamlingar',
#  'Q1058792': 'fluctus',
#  'Q1058828': 'Off-Broadway',
#  'Q1059407': 'shingle beach',
#  'Q1059478': 'town of Japan',
#  'Q10594812': 'national city park',
#  'Q10594991': 'nature area',
#  'Q10595016': 'nature conservation area',
#  'Q105955498': 'proposed power station',
#  'Q105957588': 'university sports venue',
#  'Q105999': 'cargo ship',
#  'Q106006806': 'lordship',
#  'Q106036321': 'former district of Indonesia',
#  'Q106071004': 'town of New York',
#  'Q106071744': 'former town',
#  'Q106072002': '中華民國原住民族委員會核定部落',
#  'Q106072745': 'coterminous town-village of New York',
#  'Q106078286': 'component city',
#  'Q10607894': 'sacrificial spring',
#  'Q10607896': 'offering site',
#  'Q106079704': 'independent component city',
#  'Q1060829': 'concert hall',
#  'Q1060846': 'yūkaku',
#  'Q106114863': 'electoral district in Turkey',
#  'Q1061151': 'massif',
#  'Q1062177': 'capital region',
#  'Q106237397': 'high school district',
#  'Q1062445': 'administrative territorial entity of Fiji',
#  'Q10624527': 'biographical museum',
#  'Q106248118': 'Carpathian protected areas in Ukraine',
#  'Q106256482': 'registration sub-district',
#  'Q106259': 'polder',
#  'Q1062593': 'province of Bolivia',
#  'Q1062710': 'municipality of Bolivia',
#  'Q1062780': 'forum',
#  'Q106357527': 'asum',
#  'Q10638782': 'primary area',
#  'Q106389302': 'city in Russia',
#  'Q106435710': 'cave monastery',
#  'Q106464977': 'Built-up area',
#  'Q106468588': 'Jewish settlement in the land of Israel',
#  'Q106469607': 'desert in Afghanistan',
#  'Q106491277': 'Bronze Age settlement',
#  'Q106491314': 'community district of Manhattan',
#  'Q106491323': 'community district of the Bronx',
#  'Q106491329': 'community district of Brooklyn',
#  'Q106491334': 'community district of Queens',
#  'Q106491339': 'Neolithic settlement',
#  'Q106491341': 'community district of Staten Island',
#  'Q106491386': 'Freilandstation des Mesolithikums',
#  'Q106492558': 'Settlement of prehistoric times',
#  'Q106504960': 'Siedlung der Urnenfelderzeit',
#  'Q106504971': 'Stone Age settlement',
#  'Q106505016': 'Settlement of the La Tene period',
#  'Q106505035': 'Siedlung des Mittelalters',
#  'Q106505045': 'Siedlung der Linearbandkeramik',
#  'Q106505070': 'Settlement of protohistoric times',
#  'Q1065118': 'district of China',
#  'Q1065252': 'pension',
#  'Q106528203': 'state constituency of Malaysia',
#  'Q106533981': 'district',
#  'Q1065367': 'hutong',
#  'Q1065592': 'desert island',
#  'Q1065656': 'health club',
#  'Q106571205': 'stewardship area',
#  'Q106581364': 'polo field',
#  'Q106614007': 'Orang Asli post',
#  'Q106625831': 'Secular humanist center',
#  'Q106626840': 'historical settlement',
#  'Q106643841': 'федеральные территории России',
#  'Q1066538': 'National Central City',
#  'Q106658': 'district',
#  'Q106698210': 'arrondissement of Cameroon',
#  'Q1066984': 'financial centre',
#  'Q106704006': 'Enercon E-138',
#  'Q1067107': 'small hydro',
#  'Q1067116': 'region of Guinea',
#  'Q10671645': 'Slottslän',
#  'Q10672946': 'societetshus',
#  'Q1067316': 'parterre',
#  'Q106765618': 'abandoned architectural structure',
#  'Q106769806': 'United States Forest Service region',
#  'Q10677154': 'Stadsdelsnämndsområde',
#  'Q1067867': 'Sestiere of Venice',
#  'Q1068071': 'chasma',
#  'Q106809346': 'fraction de commune',
#  'Q106833943': 'vereda',
#  'Q1068623': 'transmitter mast',
#  'Q1068842': 'footbridge',
#  'Q106889447': 'ardiaconate',
#  'Q1069042': 'Regions of Eswatini',
#  'Q106908136': 'wildlife management area of Michigan',
#  'Q10692700': 'indoor tennis venue',
#  'Q106935957': 'obszar Miejskiego Systemu Informacji w Warszawie',
#  'Q106967636': 'parkland',
#  'Q106978421': 'караїмський цвинтар',
#  'Q10701315': 'transport vessel',
#  'Q1070167': 'district of Samoa',
#  'Q107017449': 'benedettine',
#  'Q107024302': 'county of Iceland',
#  'Q1070290': 'prisoner-of-war camp',
#  'Q107035337': 'parament workshop',
#  'Q1070912': 'Zhou',
#  'Q1070942': 'commune-level town of Vietnam',
#  'Q107095300': 'tegelbakkerij',
#  'Q1070990': 'county-level city',
#  'Q107105851': 'transitional metropolitan council',
#  'Q107105862': 'transitional metropolitan substructure',
#  'Q10713454': 'water source',
#  'Q107141943': 'Former municipality of Iceland',
#  'Q1071482': 'National parks of Japan',
#  'Q10715540': 'Residential Zone',
#  'Q107189301': 'studio collective',
#  'Q10726579': 'steam-powered sawmill',
#  'Q107293007': 'citrus orchard',
#  'Q107297907': 'quadrant of Albuquerque, New Mexico',
#  'Q10729872': 'medical association',
#  'Q10729920': 'monastery houses of refuge',
#  'Q107299310': 'community centre (Flanders)',
#  'Q107364881': 'memorial plaza',
#  'Q107370269': 'wild forest',
#  'Q107390': 'federated state',
#  'Q107393743': 'fire lookout station',
#  'Q107405241': 'balsa de riego',
#  'Q107413232': 'moated site',
#  'Q10742': 'autonomous community of Spain',
#  'Q107425': 'landscape',
#  'Q1074523': 'planned community',
#  'Q107457306': 'poor farm',
#  'Q1075310': 'sailboat',
#  'Q107534256': 'puppeteer theater',
#  'Q107539354': 'MEOW marine realm',
#  'Q107539355': 'MEOW marine province',
#  'Q107539356': 'MEOW marine ecoregion',
#  'Q1075520': 'province of Costa Rica',
#  'Q107557544': 'Minnesota state forest',
#  'Q107565488': 'allotment',
#  'Q1075664': 'port of entry',
#  'Q107599282': 'shipping channel',
#  'Q1076291': 'retaining wall',
#  'Q1076486': 'sports venue',
#  'Q107661781': 'Conquest Group',
#  'Q107663115': 'constituency of the House of Assembly of St Lucia',
#  'Q107663145': 'Former Region of Ghana',
#  'Q107674020': 'butter factory',
#  'Q107679': 'cliff',
#  'Q107684042': 'parish cemetery',
#  'Q107684057': 'municipal cemetery',
#  'Q107684101': 'private cemetery',
#  'Q107684421': 'civil cemetery',
#  'Q107685861': 'Christian cemetery',
#  'Q107689510': 'tourist home',
#  'Q107690138': 'ES93 Site of scientific interest',
#  'Q107690211': 'Area of regional interest',
#  'Q107690225': 'Paratge natural municipal',
#  'Q107690284': 'Nature Reserve (Integral)',
#  'Q107690900': 'Nature Place',
#  'Q107691378': 'Protected Landscape',
#  'Q107691492': 'Periurban Protected Area',
#  'Q107691525': 'Rural Park',
#  'Q107691544': 'Special Nature Reserve',
#  'Q107691554': 'ES96 Natura 2000',
#  'Q107691783': 'Regional Park',
#  'Q107691830': 'Marine Reserve',
#  'Q107692021': 'Espacio Natural Protegido',
#  'Q10769552': 'motu',
#  'Q1077097': 'tambon',
#  'Q1077135': 'wildlife crossing',
#  'Q107715905': 'main campus',
#  'Q10771871': 'independent school district',
#  'Q107719234': 'Nature Reserve',
#  'Q107724136': 'wedding venue',
#  'Q1077333': 'administrative territorial entity of Thailand',
#  'Q107774068': 'harmoniumfabrik',
#  'Q107782629': 'leather bar',
#  'Q107791087': 'district of Prague (1949)',
#  'Q107816032': 'neighborhood in Somerville',
#  'Q1078374': 'tenement',
#  'Q107986538': 'orgelfabrik',
#  'Q107989230': 'Singular tree',
#  'Q107989541': 'Animal Refuge',
#  'Q107990772': 'Integral Reserve',
#  'Q107990774': 'Marine Protected Area',
#  'Q107990776': 'Nature Reserve (Wildlife)',
#  'Q107990777': 'Nature Reserve (Parcial)',
#  'Q107990779': 'Periurban Park',
#  'Q107990781': 'Nature enclave',
#  'Q107990784': 'Natural Monument (National Interest)',
#  'Q107990786': 'Natural Area (recreational)',
#  'Q107990791': 'Nature Reserve (Management)',
#  'Q107990793': 'Biosphere Reserve',
#  'Q107990794': 'Protected Wetland',
#  'Q107990796': 'Natural Area of Special Interest',
#  'Q107990799': 'Natural Area (singular)',
#  'Q107990801': 'Protection Plan',
#  'Q107990805': 'ES48 Natura 2000',
#  'Q107990807': 'Wetland Site',
#  'Q107990809': 'Cave',
#  'Q107990812': 'Ecocultural corridor',
#  'Q107990814': 'Private Area (Ecological interest)',
#  'Q107990816': 'Protected Biotop',
#  'Q107990817': 'Fluvial Reserve',
#  'Q107990818': 'Ecological corridor',
#  'Q107992620': 'ES46 Natura 2000',
#  'Q107992622': 'Natura 2000',
#  'Q108000498': 'part of municipality in Czechoslovakia',
#  'Q1080224': 'state electoral district',
#  'Q108047890': 'national park',
#  'Q108051693': 'national park',
#  'Q108052911': 'regional park',
#  'Q108059517': 'national park',
#  'Q108060568': 'national park',
#  'Q108060572': 'nature park',
#  'Q108060573': 'natural monument',
#  'Q108061330': 'strict nature reserve',
#  'Q108065099': 'state hiking area',
#  'Q108067982': 'městiště',
#  'Q1080794': 'state school',
#  'Q1081138': 'historic site',
#  'Q108133535': 'Jesuit Estancia',
#  'Q108178728': 'national capital',
#  'Q108184582': 'fortified farm',
#  'Q108263503': 'buried watercourse',
#  'Q108292096': 'autobusové stanoviště',
#  'Q10831626': 'Province (South Vietnam)',
#  'Q108319959': 'district of Vaasa',
#  'Q108321096': 'major district of Vaasa',
#  'Q108325': 'chapel',
#  'Q10832530': 'ironworks',
#  'Q108369092': 'City region',
#  'Q108377790': 'Slave plantation',
#  'Q108379543': 'Fauna and Flora Sanctuary',
#  'Q10840661': 'urban area of Vietnam',
#  'Q10840669': 'Class V town',
#  'Q108415733': 'comprehensive community college',
#  'Q108415987': 'community college in Alberta',
#  'Q108423454': 'polytechnic institution',
#  'Q108423628': 'specialized arts and cultural institution',
#  'Q108426987': 'private career college in Alberta',
#  'Q108427071': 'First Nations college',
#  'Q108427122': 'First Nations college in Alberta',
#  'Q108431000': 'private college in Alberta',
#  'Q108441897': 'syro-malabar metropolitan archdiocese',
#  'Q108454666': 'big city of South Korea',
#  'Q108454687': 'half million city',
#  'Q108460023': 'demountable venue',
#  'Q108514403': 'sbor Jednoty bratrské',
#  'Q108515152': 'sbor Církve bratrské',
#  'Q108532108': 'orthodox parish',
#  'Q108532703': 'sbor Bratrské jednoty baptistů',
#  'Q10854310': 'administrative territorial entity below municipality in Spain',
#  'Q10855061': 'archaeological find',
#  'Q10855239': 'kyōteijō',
#  'Q108569710': 'city of Ohio',
#  'Q108569739': 'village of Ohio',
#  'Q10860609': 'country in Czechoslovakia',
#  'Q10864048': 'first-level administrative country subdivision',
#  'Q108669285': 'cooperage',
#  'Q108683897': 'hydraulic power station',
#  'Q10868922': 'Region (Beijing)',
#  'Q108696': 'horse stud farm',
#  'Q108722037': 'district of Bari',
#  'Q108723311': 'municipality of Bari',
#  'Q108740514': 'woodland garden',
#  'Q10874708': 'Chinese salvationist religions',
#  'Q1087624': 'nahiyah',
#  'Q108800505': 'municipality of Saudi Arabia',
#  'Q108800512': 'community of Saudi Arabia',
#  'Q108803036': 'enclosed settlement',
#  'Q108804646': '都市公園',
#  'Q108822337': '公共施設',
#  'Q108822533': 'border river',
#  'Q108822885': 'Catholic Metropolitan Archieparchy',
#  'Q108822950': 'Catholic Archieparchy',
#  'Q10882966': 'exchange building',
#  'Q1088391': 'rump state',
#  'Q10884': 'tree',
#  'Q108840288': 'palisaded enclosure',
#  'Q1088552': 'Catholic church building',
#  'Q108861021': 'folk art museum',
#  'Q108862123': 'office plaza',
#  'Q108871638': 'Hispanic American neighborhood',
#  'Q108921116': "aire d'attraction d'une ville",
#  'Q10904438': 'Twelve Vassals',
#  'Q10910840': '厅 (清朝)',
#  'Q10911436': '厦门市文物保护单位',
#  'Q10915529': 'administrative division of Taiwan under Japanese rule',
#  'Q10922837': 'administrative territorial entity of the Tang dynasty',
#  'Q109229401': 'protestant cemetery',
#  'Q109235260': 'presbyterian cemetery',
#  'Q109235270': 'quaker cemetery',
#  'Q109235481': 'buddhist cemetery',
#  'Q109239160': 'Latin Rite Catholic cemetery',
#  'Q109254256': 'country park',
#  'Q109264881': 'Stichkanal',
#  'Q1092661': 'moorland',
#  'Q10926815': 'National Forest Recreation Area (Republic of China)',
#  'Q10926872': 'National Garden',
#  'Q109269920': 'tile factory',
#  'Q109279933': 'municipality of Jordan',
#  'Q1092993': 'barque',
#  'Q109329953': 'state city of Latvia',
#  'Q1093720': 'real union',
#  'Q1093829': 'city of the United States',
#  'Q109392731': 'city quarter of Copenhagen',
#  'Q1094397': 'autonomous city',
#  'Q109445423': 'high-speed railway tunnel',
#  'Q1094545': 'Civitas',
#  'Q10952797': 'anchorage',
#  'Q109539289': 'SEPTA fare zone',
#  'Q109540666': 'DPR-D electoral district',
#  'Q109547607': 'gleibakkerij',
#  'Q109554780': 'jesuit province',
#  'Q109562558': 'salesian province',
#  'Q109586943': 'Capuchin province',
#  'Q109587150': 'Conventual Franciscan province',
#  'Q109593182': 'province of the Order of Preachers',
#  'Q109607': 'ruins',
#  'Q109612062': 'territorial demarcation of the Pious Schools',
#  'Q109612325': 'vice-province',
#  'Q109658711': 'convent of Discalced Carmelite nuns',
#  'Q109662605': 'lightvessel station',
#  'Q109670141': 'Discalced Carmelite Fathers Convent',
#  'Q109670594': 'carmel',
#  'Q10977433': 'protected area of Ukraine',
#  'Q10982631': 'Sabinar',
#  'Q109828360': 'Canadian Senate division',
#  'Q109882149': 'climbing gym',
#  'Q109930432': 'underwater area',
#  'Q110009901': 'postcode area',
#  'Q110010174': 'automobile engine plant',
#  'Q110010218': 'motor vehicle assembly plant',
#  'Q110071194': 'city of Illinois',
#  'Q110071217': 'village of Illinois',
#  'Q110071230': 'incorporated town of Illinois',
#  'Q110155206': 'zone de météorologie marine',
#  'Q110164525': 'alberca',
#  'Q110203714': 'municipal arts centre',
#  'Q110207144': 'tanguería',
#  'Q110211119': 'former municipality of Latvia',
#  'Q110227148': 'lavadero de mineral',
#  'Q110231728': 'neighbourhood in Egypt',
#  'Q1102346': 'Clos',
#  'Q110249999': 'sewer district of Ohio',
#  'Q110256042': 'police-administered area',
#  'Q110256333': 'new city of Egypt',
#  'Q110256876': 'town of Pennsylvania',
#  'Q110265745': 'incorporated district of Pennsylvania',
#  'Q110265747': 'road district of Pennsylvania',
#  'Q110266204': 'optional charter municipality of Pennsylvania',
#  'Q110266206': 'optional plan municipality of Pennsylvania',
#  'Q110266209': 'home rule county of Pennsylvania',
#  'Q110270421': 'climbing hall',
#  'Q110276341': 'oplevelsescenter',
#  'Q110292213': 'Grand principality',
#  'Q1103285': 'clubhouse',
#  'Q1103736': 'Clyde tomb',
#  'Q1103796': 'vernal pool',
#  'Q110415260': 'unitary authority area',
#  'Q110416322': 'unitary authority in Wales',
#  'Q110417190': 'non-metropolitan county council',
#  'Q110420735': 'Edificación singular',
#  'Q110451841': 'sponge park',
#  'Q110484135': 'cigarette factory',
#  'Q1104922': 'Group Representation Constituency',
#  'Q110645724': 'købstadskommune i Danmark',
#  'Q110654987': 'unibertsitate',
#  'Q110655230': 'komunitate',
#  'Q11066155': 'distillery',
#  'Q11066204': 'Poll',
#  'Q110693369': 'yardna',
#  'Q110706912': 'Islamic organization',
#  'Q110710943': 'locality of Leipzig, Germany',
#  'Q11071191': 'udun',
#  'Q110712535': 'district of Leipzig, Germany',
#  'Q1107167': 'cohousing',
#  'Q110736820': 'proposed voivodeship of Poland',
#  'Q110761618': 'Brauereigasthof',
#  'Q11076354': '承宣布政使司',
#  'Q1107656': 'garden',
#  'Q11078915': 'Free Life Pond',
#  'Q110798863': 'neighborhood of Pittsburgh',
#  'Q110804671': 'intelligent world ocean',
#  'Q110804788': 'zone van Curaçao',
#  'Q110811156': 'festival hall',
#  'Q110812103': 'Zemlja (feudal Balkans)',
#  'Q11081619': 'land',
#  'Q110835114': 'former parish of Latvia',
#  'Q110897622': 'Ogham Stones Cluster Region',
#  'Q1109069': 'ski jumping hill',
#  'Q110929992': 'classis',
#  'Q1109432': 'hispanism',
#  'Q110949247': 'citizen lab',
#  'Q1109500': 'collier',
#  'Q110951231': 'Macedonian tomb',
#  'Q110969408': 'granite yard',
#  'Q110976965': 'Sub-regions of Uganda',
#  'Q110977342': 'town council of Uganda',
#  'Q110977362': 'municipal division of Uganda',
#  'Q110977456': 'municipality of Uganda',
#  'Q110978806': 'mankomunitate',
#  'Q1110056': 'CEGEP',
#  'Q111010342': 'yard gate',
#  'Q111031767': 'hamlet of Ohio',
#  'Q11111030': 'boardwalk',
#  'Q11127777': 'administrative regency of Indonesia',
#  'Q11142797': 'Basque trinquete',
#  'Q11152450': 'Biskupstvo',
#  'Q1115575': 'civil parish',
#  'Q11157301': 'shoreline lake',
#  'Q11166097': 'drawing room',
#  'Q11166728': 'TV tower',
#  'Q11177275': 'riparian forest',
#  'Q11183017': 'open-air theatre',
#  'Q11183787': 'Ortschaft',
#  'Q1118400': 'balsamic vinegar factory',
#  'Q112099': 'island nation',
#  'Q1121471': 'paddle steamer',
#  'Q1122846': 'district of Japan',
#  'Q1123813': 'concept store',
#  'Q1125269': 'national park of India',
#  'Q1125776': 'wing',
#  'Q11266550': 'kodomonokuni',
#  'Q11269813': 'cave with prehistoric art',
#  'Q11271241': 'administrative division of the Joseon dynasty',
#  'Q11271835': 'state capital',
#  'Q11272590': 'branch domain',
#  'Q11277308': 'furusatomura',
#  'Q11278157': 'maimaizu well',
#  'Q11279146': 'Minato Oasis',
#  'Q11279677': 'special self-governing province of South Korea',
#  'Q1128397': 'convent',
#  'Q1128482': 'container village',
#  'Q11285599': 'sea area',
#  'Q112865': 'administrative territorial entity of Mexico',
#  'Q112876': 'pine barrens',
#  'Q1128906': 'medina quarter',
#  'Q11290050': 'Bodia Spa Cambodian Cocoon',
#  'Q1129142': 'NRHP contributing property',
#  'Q11292': 'coral reef',
#  'Q1129474': 'cultural landscape',
#  'Q1129743': 'filial church',
#  'Q11298806': 'bear park',
#  'Q11302190': 'kotan',
#  'Q11303': 'skyscraper',
#  'Q11304027': 'cycling terminal',
#  'Q1130491': 'Sloboda',
#  'Q1131296': 'freguesia of Portugal',
#  'Q1131329': 'grotto',
#  'Q11315': 'shopping center',
#  'Q11322155': 'training gym',
#  'Q1132248': 'ice field',
#  'Q1132300': 'metropolitan region in Germany',
#  'Q11323781': 'National Training Center',
#  'Q11325969': 'ハイウェイオアシス',
#  'Q1132998': 'National Recreation Area',
#  'Q11330931': 'Vivre',
#  'Q11331347': 'calvary hill',
#  'Q1133195': 'scree',
#  'Q11331980': 'fashion building',
#  'Q11334401': 'beech forest',
#  'Q11335963': 'play park',
#  'Q11338578': 'boxing gym',
#  'Q1133961': 'commercial district',
#  'Q11342368': 'Mini theater',
#  'Q1134686': 'frazione',
#  'Q11349558': 'soda lake',
#  'Q11349822': 'retro themed park',
#  'Q1135180': 'geodesic dome',
#  'Q11353': 'district of Iran',
#  'Q113574': 'water garden',
#  'Q1135802': 'art film',
#  'Q11363644': 'central wholesale market',
#  'Q1136601': 'unitary authority area in England',
#  'Q11371756': 'Class B river system',
#  'Q1137210': 'country club',
#  'Q1137365': 'entrance',
#  'Q11374182': 'Kagai of Kyoto',
#  'Q1137441': 'yawl',
#  'Q1137691': 'Regions of Somaliland',
#  'Q11377548': 'Buddhist archaeological site',
#  'Q1137809': 'courthouse',
#  'Q1137833': 'core city of Japan',
#  'Q11381457': 'tenmachō',
#  'Q1138251': 'fairway',
#  'Q1138279': 'associated state',
#  'Q1138414': 'hermitage',
#  'Q1138494': 'historic county of England',
#  'Q11385595': 'erosional valley',
#  'Q11388812': '児童遊園',
#  'Q11394721': 'Inland city',
#  'Q11396118': 'divided country',
#  'Q11396180': 'library branch',
#  'Q11396226': '切通し',
#  'Q11396960': 'production company',
#  'Q11400575': '勤労者福祉施設',
#  'Q1140140': 'mainland',
#  'Q1140229': 'political union',
#  'Q1140316': 'penal colony',
#  'Q1140332': 'Military district in the Soviet Union',
#  'Q1140477': 'subglacial lake',
#  'Q1140845': 'subterranean river',
#  'Q11408869': 'tanjun onsen',
#  'Q11410074': '原野',
#  'Q11411019': 'kofungun',
#  'Q1141231': 'rockery',
#  'Q11414752': 'Place of Scenic Beauty of Japan',
#  'Q11416420': '含アルミニウム泉',
#  'Q1141653': 'Prowincja',
#  'Q11418825': '問屋街',
#  'Q11419632': '48 waterfalls',
#  'Q11420231': 'Japanese strolling garden',
#  'Q11422368': 'city for international conferences and tourism',
#  'Q11427941': 'Depositional plain',
#  'Q11428612': '塩化物泉',
#  'Q11429564': 'voice actor training center',
#  'Q11430357': 'foreign settlement in Japan',
#  'Q1143046': 'odeon',
#  'Q11433351': 'daimyo garden',
#  'Q11434268': '大学校 (旧制)',
#  'Q11439934': 'hanamachi in Osaka',
#  'Q1144345': 'volcanic plateau',
#  'Q11445527': '奏楽堂',
#  'Q11446': 'ship',
#  'Q1144661': 'amusement ride',
#  'Q1145005': 'province of Sierra Leone',
#  'Q1145012': 'special city of Japan',
#  'Q11452094': '官営模範工場',
#  'Q11452119': 'kanshōfu-shō',
#  'Q11458051': 'jisha',
#  'Q11458389': 'feudal state',
#  'Q11458819': 'Little Kyoto',
#  'Q11459155': 'small theater',
#  'Q1146001': 'light source',
#  'Q11462226': 'Koedo',
#  'Q1146429': 'canton of Luxembourg',
#  'Q11464930': 'Buddhist nunnery',
#  'Q11465701': '屋敷林',
#  'Q1147274': 'Apostolic see',
#  'Q114768': 'granary',
#  'Q1147753': 'cyclorama',
#  'Q11479807': 'giant tree',
#  'Q11480697': '市街地',
#  'Q11481119': 'divisional district',
#  'Q11481639': 'broadleaf evergreen forest',
#  'Q11483816': 'annual event',
#  'Q11484330': 'kouiki chimei',
#  'Q11486287': 'former Buddhist temple',
#  'Q11487113': 'kyūdōjō',
#  'Q11488831': 'mikuriya',
#  'Q1149061': 'Sprachraum',
#  'Q11495971': 'war ruins',
#  'Q1149621': 'district of Seychelles',
#  'Q1149652': 'district of India',
#  'Q1149783': 'In commendam',
#  'Q11498934': '放射能泉',
#  'Q1149964': 'regional park of Germany',
#  'Q11500': 'area',
#  'Q11505291': 'one-day onsen facility',
#  'Q11505677': 'new town in Japan',
#  'Q11505825': 'national forest of Japan',
#  'Q11506008': 'Japanese port settlement',
#  'Q11511006': '旧国名',
#  'Q11513034': 'association under the French law of 1901',
#  'Q1151405': 'client state',
#  'Q11514315': 'historical period',
#  'Q1151616': 'stateless nation',
#  'Q1152199': 'midden',
#  'Q11524038': 'hanamachi in Tokyo',
#  'Q11527003': 'Tokyu Plaza',
#  'Q115291': 'province of Cuba',
#  'Q1153108': 'multiplex',
#  'Q1153408': 'province of Chile',
#  'Q1154445': 'federal electoral district of Mexico',
#  'Q11546861': '歴史公園',
#  'Q1154710': 'association football venue',
#  'Q11548891': '水泳場',
#  'Q11549275': '水運',
#  'Q11556488': 'Diluvial upland',
#  'Q11556819': 'Pure Land garden',
#  'Q11558822': '海堡',
#  'Q11559043': 'seaside park',
#  'Q11562971': 'onsenkyō',
#  'Q11563256': '湖沼',
#  'Q11566792': 'nada',
#  'Q1156696': 'roof garden',
#  'Q11567142': '炭酸水素塩泉',
#  'Q1156831': 'umbrella organization',
#  'Q1157068': 'Instituta clericalia',
#  'Q11573504': '球技場',
#  'Q11578893': '疏水',
#  'Q11580291': 'shiraito falls',
#  'Q11581043': 'imperial property',
#  'Q11582564': 'civil college',
#  'Q11582670': '県民の森',
#  'Q1158712': 'administrative region of the Federal District',
#  'Q11587674': 'sulphur spring',
#  'Q11587679': '硫黄泉',
#  'Q11588123': 'coral reef lagoon',
#  'Q1158818': 'steam-electric power station',
#  'Q11598565': 'keirin racing track',
#  'Q11599236': 'bamboo grove',
#  'Q1161185': 'high island',
#  'Q11618417': 'LAU 2',
#  'Q11625999': 'Branch Secretariat',
#  'Q11626783': 'urami waterfall',
#  'Q11626975': 'commercial complex',
#  'Q1162817': 'geographical small region of Hungary',
#  'Q1162835': 'district of Hungary',
#  'Q11635': 'theatre',
#  'Q1163630': 'Fronhof',
#  'Q11637995': 'agricultural park',
#  'Q11643523': '都城',
#  'Q11643712': '都心等拠点地区',
#  'Q11644442': '酸性泉',
#  'Q11645813': '野湯',
#  'Q11647353': 'hanamachi in Kanazawa',
#  'Q11651158': 'chinju no mori',
#  'Q11658180': "jin'yamachi",
#  'Q1165822': 'meromictic lake',
#  'Q1165999': 'lake freighter',
#  'Q11660439': '電気街',
#  'Q11660666': '震災復興公園',
#  'Q11660700': 'reien',
#  'Q11665557': 'scenic park',
#  'Q1166574': 'drying house',
#  'Q11666832': 'youseishisetsu',
#  'Q11668222': '駅路',
#  'Q11672694': 'higher normal school',
#  'Q11679959': 'Outskirt (Al-Andalus)',
#  'Q11687019': 'external territory of Australia',
#  'Q11688146': 'oligotrophic lake',
#  'Q11689547': 'cement plant',
#  'Q11691318': 'cultural heritage monument in Germany',
#  'Q11695632': 'Districts of Split',
#  'Q11696869': 'vénda',
#  'Q1169748': 'cascina a corte',
#  'Q1169870': 'educational trail',
#  'Q11698842': 'sender de petit recorregut',
#  'Q11702690': 'undersea ridge',
#  'Q11703715': 'federal electoral district of Germany',
#  'Q11703950': 'constituency of the London Assembly',
#  'Q11707': 'restaurant',
#  'Q11722303': 'rural municipality of Sweden and Finland',
#  'Q11723820': 'jednostka osadnicza',
#  'Q1172599': 'inlet',
#  'Q11726974': 'epishelf lake',
#  'Q1172788': 'merindad',
#  'Q1172903': 'loch',
#  'Q11732217': 'Flecken',
#  'Q11734477': 'memorial stone',
#  'Q11741382': 'Holy Trinity column',
#  'Q1175512': 'county town',
#  'Q1175519': 'megyei város',
#  'Q1175522': 'County city (council system)',
#  'Q11755880': 'residential building',
#  'Q11755959': 'multi-storey urban building',
#  'Q11762356': 'valley glacier',
#  'Q11774062': 'county of Arkansas',
#  'Q11774149': 'county of Iowa',
#  'Q11774263': 'Vidhan Sabha constituency',
#  'Q11774771': 'county of Nova Scotia',
#  'Q11781066': 'microregion',
#  'Q11784935': 'Orthodox monastery\u200e',
#  'Q11789735': 'national natural monument',
#  'Q11797473': 'electoral constituency of the Sejm of the Republic of Poland',
#  'Q1180029': 'Sambadrome',
#  'Q11802343': 'historic ocean',
#  'Q11812346': 'county of Illinois',
#  'Q11812394': 'theatre company',
#  'Q1181413': 'palace of culture',
#  'Q11822917': 'horse racing venue',
#  'Q11828004': 'province of Canada',
#  'Q1182952': 'dehesa',
#  'Q11832860': 'quasi-national park of Japan',
#  'Q11836709': 'dvorec',
#  'Q1184072': 'delegation',
#  'Q1184788': 'suburbicarian diocese',
#  'Q1185274': 'marine park',
#  'Q1185562': 'light aircraft carrier',
#  'Q1185892': 'geological massif',
#  'Q11859145': 'Evangelic-Lutheran congregation',
#  'Q11862829': 'academic discipline',
#  'Q11863339': 'Dům dětí a mládeže',
#  'Q11863468': 'Village Heritage Site',
#  'Q11868379': 'fjard of a lake',
#  'Q11874654': 'Lapinraunio',
#  'Q11875312': 'herb rich forest reserve',
#  'Q11875349': 'playground',
#  'Q1187580': 'non-metropolitan district',
#  'Q11876497': 'national park',
#  'Q11877099': 'ubytovna',
#  'Q1187811': 'college town',
#  'Q11879302': 'Czech teacher training institute',
#  'Q11881845': 'city',
#  'Q1188223': 'dance hall',
#  'Q1188480': 'fish market',
#  'Q11884969': 'vesnická památková zóna',
#  'Q1188673': 'subway',
#  'Q11888579': 'polttokenttäkalmisto',
#  'Q11890619': 'hiking area',
#  'Q11900212': 'photography centre',
#  'Q11901695': 'ancient county of Estonian region',
#  'Q11912920': 'casal',
#  'Q11914069': 'cattle corral',
#  'Q11914866': 'comarca of Ciudad Real Province',
#  'Q11914869': 'comarca of Valladolid Province',
#  'Q1191622': 'Special Area of Conservation',
#  'Q11917457': 'administrative territorial entity of Catalonia',
#  'Q1191753': 'bus depot',
#  'Q11919713': 'escar',
#  'Q11920609': "espai d'interès natural",
#  'Q1192284': 'food court',
#  'Q1192403': 'concession',
#  'Q11926102': 'Old Hospital',
#  'Q11933503': 'Lloc',
#  'Q1193438': 'bullring',
#  'Q1193753': 'stone row',
#  'Q11938128': 'Mutasarrıf',
#  'Q1194093': 'international non-governmental organization',
#  'Q1194269': 'harness racing',
#  'Q1194379': 'volcanic belt',
#  'Q11944166': 'quadra',
#  'Q11948177': 'sender local',
#  'Q1194951': 'national sports team',
#  'Q1195098': 'ward',
#  'Q11954567': 'veïnat',
#  'Q1195942': 'fire station',
#  ...}

# %%
why_loc_human_readable = {}
for wid, inst_of_set in track(why_loc.items(), description="Making the IDs human readable..."):
    why_loc_human_readable[wid] = {
        (qid, looked_up_loc.get(qid))
        for qid in inst_of_set
    }
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
why_loc_counts = Counter()
for _, inst_of in why_loc_human_readable.items():
    string_labels =  " & ".join([f"{name} ({qid})" if name else qid for qid, name in inst_of])
    why_loc_counts[string_labels] += 1

# %%
why_loc_counts.most_common()
# Out:
# [('river (Q4022)', 273845),
#  ('village (Q532)', 124843),
#  ('stream (Q47521)', 103941),
#  ('lake (Q23397)', 95057),
#  ('island (Q23442)', 86427),
#  ('watercourse (Q355304)', 79873),
#  ('village in India (Q56436498)', 71708),
#  ('park (Q22698)', 70824),
#  ('valley (Q39816)', 70018),
#  ('townland (Q2151232)', 57931),
#  ('protected area (Q473972)', 53469),
#  ('natural watercourse (Q55659167)', 53350),
#  ('spring (Q124714)', 50063),
#  ('village of Poland (Q3558970)', 49645),
#  ('commune of France (Q484170)', 39855),
#  ('canal (Q12284)', 37270),
#  ('wadi (Q187971)', 35350),
#  ('point (Q24529780)', 34000),
#  ('village (Q532) & fourth-level administrative division in Indonesia (Q2225692)',
#   33927),
#  ('movie theater (Q41253)', 29663),
#  ('cemetery (Q39614)', 26815),
#  ('desa (Q26211545)', 25079),
#  ('ward (Q1195098)', 24995),
#  ('village of Ukraine (Q21672098)', 24982),
#  ('college (Q189004)', 24016),
#  ('Q104093746', 23327),
#  ('Ortsteil (Q253019)', 23046),
#  ('archaeological site (Q839954)', 22993),
#  ('bay (Q39594)', 22532),
#  ('bodendenkmal (Q22969563)', 20654),
#  ('marsh (Q30198)', 20605),
#  ('manor estate (Q2116450)', 17874),
#  ('village in Turkey (Q1529096)', 17760),
#  ('frazione (Q1134686)', 15949),
#  ('bight (Q17018380)', 15081),
#  ('forest (Q4421)', 15080),
#  ('peninsula (Q34763)', 14900),
#  ('ridge (Q740445)', 14790),
#  ('ship (Q11446) & shipwreck (Q852190)', 14168),
#  ('reservoir (Q131681)', 14148),
#  ('Gram panchayat (Q2732840)', 14019),
#  ('neighborhood (Q123705)', 13993),
#  ('desa (Q26211545) & fourth-level administrative division in Indonesia (Q2225692)',
#   13450),
#  ('destroyed building or structure (Q19860854) & movie theater (Q41253)',
#   13302),
#  ('swamp (Q166735)', 13005),
#  ('dissolved municipality of Japan (Q18663566)', 12764),
#  ('square (Q174782)', 11811),
#  ('lagoon (Q187223)', 11383),
#  ('islet (Q207524)', 10454),
#  ('Q1516079', 9318),
#  ('reef (Q184358)', 9183),
#  ('rural commune of Vietnam (Q2389082)', 9179),
#  ('gromada of Poland (Q479053)', 9147),
#  ('village in Belarus (Q65661087)', 9102),
#  ('waterfall (Q34038)', 9091),
#  ('village-level division in China (Q13100073)', 9052),
#  ('historic district (Q15243209)', 8972),
#  ('town (Q3957)', 8585),
#  ('nature reserve (Q179049)', 8572),
#  ('mahalle (Q17051044)', 8161),
#  ('village (Q532) & civil parish (Q1115575)', 8109),
#  ('Landschaftsschutzgebiet (Q21503788) & protected area (Q473972)', 7726),
#  ('municipality of Germany (Q262166)', 7666),
#  ('pond (Q3253281)', 7568),
#  ('glacier (Q35666)', 7506),
#  ('city of the United States (Q1093829)', 7415),
#  ('commune of Italy (Q747074)', 7393),
#  ('town in China (Q735428)', 7322),
#  ('census-designated place (Q498162)', 7252),
#  ('village of Taiwan (Q7930614)', 7249),
#  ('protected area (Q473972) & Naturschutzgebiet (Q759421)', 7130),
#  ('parish of New South Wales (Q28931760)', 7109),
#  ('river (Q4022) & watercourse (Q355304)', 6982),
#  ('tambon (Q1077097)', 6971),
#  ('plain (Q160091)', 6921),
#  ('Q104093746 & lake (Q23397)', 6640),
#  ('Q131596', 6188),
#  ('municipality of Spain (Q2074737)', 6115),
#  ('fourth-level administrative division in Indonesia (Q2225692) & gampong (Q4285979)',
#   6089),
#  ('school district (Q398141)', 6081),
#  ('kecamatan (Q3700011)', 5845),
#  ('monastery (Q44613)', 5738),
#  ('channel (Q1210950)', 5723),
#  ('sports venue (Q1076486)', 5558),
#  ('oil field (Q211748)', 5555),
#  ('bodendenkmal (Q22969563) & human settlement (Q486972)', 5357),
#  ('architectural ensemble (Q1497375)', 5321),
#  ('theatre (Q24354)', 5269),
#  ('stadium (Q483110)', 5213),
#  ('municipality of the Czech Republic (Q5153359)', 5146),
#  ('Q3184121', 5009),
#  ('shopping center (Q11315)', 4855),
#  ('bodendenkmal (Q22969563) & Settlement of protohistoric times (Q106505070) & human settlement (Q486972)',
#   4761),
#  ('fourth-level administrative division in Indonesia (Q2225692) & kelurahan (Q965568)',
#   4754),
#  ('town of the United States (Q15127012)', 4708),
#  ('milestone (Q10145)', 4661),
#  ('United States of America State-level electoral district (Q104146934)',
#   4568),
#  ('cadastral area in the Czech Republic (Q20871353) & part of municipality in the Czech Republic (Q61089180)',
#   4462),
#  ('posyolok (Q2514025)', 4401),
#  ('village in Estonia (Q51049922)', 4256),
#  ('raised bog (Q3240227)', 4171),
#  ("residential community of the People's Republic of China (Q985488)", 3902),
#  ('hydroelectric power station (Q15911738)', 3840),
#  ('single entity of population (Q3055118)', 3720),
#  ('human settlement (Q486972) & archaeological site (Q839954)', 3708),
#  ('archaeological site (Q839954) & Samian Ware Discovery Site (Q102202066)',
#   3700),
#  ('kelurahan (Q965568)', 3695),
#  ('part of municipality in the Czech Republic (Q61089180)', 3627),
#  ('Special Area of Conservation (Q1191622)', 3445),
#  ('bodendenkmal (Q22969563) & cemetery (Q39614)', 3412),
#  ('Q56061', 3334),
#  ('rural settlement of Russia (Q634099)', 3312),
#  ('Q2500304', 3302),
#  ('barangay (Q61878)', 3299),
#  ('Station of the Cross (Q98094425)', 3292),
#  ('Q515', 3288),
#  ('fourth-level administrative country subdivision (Q14757767)', 3275),
#  ('destroyed building or structure (Q19860854) & movie theater (Q41253) & drive-in theater (Q786922)',
#   3234),
#  ('electoral district (Q192611)', 3150),
#  ('historic site (Q1081138)', 3050),
#  ('landmark (Q2319498)', 3043),
#  ('village development committee of Nepal (Q1530705)', 3006),
#  ('village of Bulgaria (Q15630849) & kmetstvo of Bulgaria (Q4224624)', 2981),
#  ('Tibetan Buddhist monastery (Q54074585)', 2952),
#  ('well (Q43483)', 2890),
#  ('ward of Nigeria (Q60169073)', 2854),
#  ('canton of France (until 2015) (Q184188)', 2849),
#  ('village (Q532) & subdivisions of Russia (Q192287)', 2782),
#  ('urban park (Q22746)', 2775),
#  ('subdistrict of China (Q986065)', 2763),
#  ('village (Q532) & seat of the local council (Q34841063)', 2737),
#  ('parish (Q102496)', 2735),
#  ('commune of Romania (Q659103)', 2722),
#  ("township of the People's Republic of China (Q1500350)", 2711),
#  ('locality (Q3257686) & cadastral municipality of Austria (Q17376095)', 2699),
#  ('freguesia of Portugal (Q1131296)', 2671),
#  ('municipality of Hungary (Q2590631)', 2668),
#  ('village of Burkina Faso (Q23012917)', 2664),
#  ('dolmen (Q101659)', 2663),
#  ('township in the United States (Q28111)', 2646),
#  ('municipality of Slovakia (Q6784672)', 2614),
#  ('minor locality in Sweden (Q14839548)', 2587),
#  ('chōchō (Q5327369)', 2527),
#  ('brook (Q63565252)', 2460),
#  ('civil parishes of Ireland (Q3910694)', 2428),
#  ('registration district in Sweden (Q18333556)', 2413),
#  ('parish council (Q7137435)', 2391),
#  ('ghost town (Q74047)', 2385),
#  ('distributary (Q591942)', 2356),
#  ('village in the United States (Q751708)', 2332),
#  ('village (Q532) & hamlet (Q5084)', 2326),
#  ('rural district of Iran (Q15125752)', 2276),
#  ('tjern / tjärn (Q87193797)', 2272),
#  ('delegated commune (Q21869758) & commune of France (Q484170)', 2250),
#  ('civil parish (Q1115575)', 2217),
#  ('unincorporated community in the United States (Q17343829) & census-designated place (Q498162)',
#   2210),
#  ('canyon (Q150784)', 2176),
#  ('ward of Tanzania (Q18691601)', 2154),
#  ('constituency of the House of Commons (Q27971968)', 2148),
#  ('desert (Q8514)', 2101),
#  ('Jewish cemetery (Q846659)', 2094),
#  ('association football venue (Q1154710)', 2062),
#  ('municipality of Mexico (Q1952852)', 2058),
#  ('stone grave (Q15120977)', 2052),
#  ('factory (Q83405)', 2041),
#  ('parish of Denmark (Q814648)', 2039),
#  ('campus (Q209465)', 1995),
#  ('Settlement of prehistoric times (Q106492558) & human settlement (Q486972) & bodendenkmal (Q22969563)',
#   1971),
#  ('canton of France (Q18524218)', 1965),
#  ('human-geographic territorial entity (Q15642541)', 1940),
#  ('village (Q532) & Ortsteil (Q253019)', 1926),
#  ('parish of Victoria (Q28930084)', 1921),
#  ('third-level administrative country subdivision in Indonesia (Q26262476) & kecamatan (Q3700011)',
#   1912),
#  ('abandoned village (Q350895)', 1897),
#  ('quarter (Q2983893)', 1878),
#  ('municipality of Switzerland (Q70208)', 1854),
#  ('parish of Galicia (Q12397176)', 1826),
#  ('diocese of the Catholic Church (Q3146899)', 1810),
#  ('plantation (Q188913)', 1805),
#  ('brewery (Q131734)', 1792),
#  ('sound (Q491713)', 1775),
#  ('botanical garden (Q167346)', 1767),
#  ('ward or electoral division of the United Kingdom (Q589282)', 1764),
#  ('district of Peru (Q2179958)', 1762),
#  ('village of Bulgaria (Q15630849)', 1760),
#  ('Roman villa (Q918230)', 1747),
#  ('urban area in Sweden (Q12813115)', 1722),
#  ('bodendenkmal (Q22969563) & Burgstall (Q1015644)', 1715),
#  ('Naturschutzgebiet (Q759421)', 1713),
#  ('locality (Q3257686) & freguesia of Portugal (Q1131296)', 1693),
#  ('ward of Vietnam (Q687188)', 1660),
#  ('nature reserve (Q179049) & protected area (Q473972)', 1651),
#  ('shipwreck (Q852190) & steamship (Q12859788)', 1650),
#  ('khutor (Q2023000)', 1641),
#  ('municipality section (Q2785216)', 1633),
#  ('sloop (Q210223) & shipwreck (Q852190)', 1625),
#  ('mountain chain (Q2624046)', 1612),
#  ('township of Minnesota (Q42211429)', 1601),
#  ('locality of Mexico (Q20202352)', 1598),
#  ('building complex (Q1497364)', 1584),
#  ('convent (Q1128397)', 1579),
#  ('abbey (Q160742)', 1564),
#  ('contour fort (Q28045079)', 1564),
#  ('venue (Q17350442)', 1553),
#  ('uzlah (Q12225020)', 1548),
#  ('quarter/commune of Cambodia (Q5154047)', 1536),
#  ('Indian reservation of Canada (Q155239)', 1535),
#  ('wetland (Q170321)', 1527),
#  ('tribal area (Q55463514)', 1525),
#  ('zoo (Q43501)', 1493),
#  ('scenic reserve (Q63248569)', 1492),
#  ('township of Pennsylvania (Q9035798)', 1476),
#  ('geographic township of Quebec (Q23019040)', 1475),
#  ('rural municipality of Poland (Q3504085)', 1468),
#  ('bodendenkmal (Q22969563) & Neolithic settlement (Q106491339) & human settlement (Q486972)',
#   1454),
#  ('movie theater (Q41253) & drive-in theater (Q786922)', 1450),
#  ('municipal district (Q2198484)', 1443),
#  ('strait (Q37901)', 1436),
#  ('municipality of the Philippines (Q24764)', 1434),
#  ('commune of Algeria (Q2989398)', 1409),
#  ('arena (Q641226)', 1401),
#  ('protected area (Q473972) & natural monument in the Czech Republic (Q21100463)',
#   1399),
#  ('union council of Bangladesh (Q3812392)', 1386),
#  ('second-level administrative country subdivision (Q13220204)', 1365),
#  ('rescue excavation (Q101008619)', 1359),
#  ('group of structures or buildings (Q18247357)', 1350),
#  ('promontory (Q1245089)', 1347),
#  ('township of Kansas (Q17205735)', 1343),
#  ('dong of South Korea (Q490329)', 1341),
#  ('outdoor gym (Q692630)', 1339),
#  ('provincial park of Canada (Q2006279)', 1338),
#  ('municipality (Q15284)', 1321),
#  ('third-level administrative country subdivision (Q13221722)', 1320),
#  ('Q6270791', 1315),
#  ('civil parish (Q4976993) & parish of Galicia (Q12397176)', 1310),
#  ('township of Iowa (Q17205621)', 1291),
#  ('garden (Q1107656)', 1286),
#  ('village (Q532) & human settlement (Q486972)', 1282),
#  ('cadastral area in the Czech Republic (Q20871353)', 1269),
#  ('fourth-level administrative division in Indonesia (Q2225692)', 1268),
#  ('titular see (Q15217609)', 1258),
#  ('county of China (Q1289426)', 1254),
#  ('navigation channel (Q41982239)', 1248),
#  ('township of Ohio (Q17198620)', 1238),
#  ('township of Arkansas (Q24027556)', 1231),
#  ('estate (Q12292478)', 1216),
#  ('fjord (Q45776)', 1205),
#  ('national park (Q46169)', 1192),
#  ('commune of Madagascar (Q3192808)', 1183),
#  ('municipality of Austria (Q667509) & rural municipality of Austria (Q1802801)',
#   1181),
#  ('agrotown (Q1989945)', 1161),
#  ('kampung of Papua (Q12488913) & fourth-level administrative division in Indonesia (Q2225692)',
#   1150),
#  ('ghetto in Nazi-occupied Europe (Q2583015)', 1146),
#  ('Site of Special Scientific Interest (Q422211)', 1144),
#  ('subdivisions of Russia (Q192287) & hamlet (Q5084)', 1142),
#  ('farmstead (Q72030539)', 1112),
#  ('promontory fort (Q92086)', 1106),
#  ('waterhole (Q3177968)', 1102),
#  ('plateau (Q75520)', 1101),
#  ('city of Iran (Q56557504)', 1101),
#  ('public reserve (Q62059246)', 1099),
#  ('hiking trail (Q2143825)', 1083),
#  ('historical country (Q3024240)', 1081),
#  ('art gallery (Q1007870)', 1080),
#  ('township of Illinois (Q17198545)', 1077),
#  ('Q1187691', 1070),
#  ('Q615980', 1065),
#  ('river (Q4022) & stream (Q47521)', 1064),
#  ('group of lakes (Q5926864)', 1062),
#  ('township of Michigan (Q17205774)', 1055),
#  ('priory (Q2750108)', 1051),
#  ('water tower (Q274153)', 1048),
#  ('ancient city (Q15661340)', 1047),
#  ('proposed site of community importance (Q60534895) & site of community importance (Q796174) & Special Area of Conservation (Q1191622)',
#   1039),
#  ('municipality of Colombia (Q2555896)', 1021),
#  ('yard gate (Q111010342)', 1016),
#  ('pen (Q858177)', 1011),
#  ('ski resort (Q130003)', 1000),
#  ('settlement in Galicia, Spain (Q20541692)', 992),
#  ('theatre (Q24354) & movie theater (Q41253)', 990),
#  ('shipwreck (Q852190) & fishing vessel (Q1420024)', 983),
#  ('Public institution of intermunicipal cooperation with own taxation (Q18706073)',
#   972),
#  ('township of Indiana (Q17201685)', 969),
#  ('coal-fired power station (Q6558431)', 966),
#  ('Commonwealth War Graves Commission maintained cemetery (Q14750991)', 955),
#  ('human settlement (Q486972) & Ortsteil (Q253019)', 955),
#  ('district of Iran (Q11353)', 951),
#  ('tehsil (Q817477)', 942),
#  ('county seat (Q62049) & city of the United States (Q1093829)', 936),
#  ('cadastral municipality of Austria (Q17376095)', 923),
#  ('district of China (Q1065118)', 914),
#  ('Special Protection Area (Q2463705)', 912),
#  ('sabkha (Q637600)', 911),
#  ('headland (Q191992)', 905),
#  ('estuary (Q47053)', 905),
#  ('smack (Q382586) & shipwreck (Q852190)', 901),
#  ('sub-county of Uganda (Q7630601)', 898),
#  ('district (Q149621)', 896),
#  ('socken (Q1523821)', 892),
#  ('underground irrigation canal (Q55468440)', 887),
#  ('fourth-level administrative division in Indonesia (Q2225692) & hamlet (Q5084)',
#   884),
#  ('lugger (Q783186) & shipwreck (Q852190)', 884),
#  ('census town of India (Q16830604)', 882),
#  ('municipality of Catalonia (Q33146843)', 881),
#  ('urban municipality of Germany (Q42744322)', 877),
#  ('Q2592651', 871),
#  ('bodendenkmal (Q22969563) & open air site (Q17540983) & Freilandstation des Mesolithikums (Q106491386)',
#   869),
#  ('Q695793', 867),
#  ('amusement park (Q194195)', 865),
#  ('Commonwealth War Graves Commission maintained cemetery (Q14750991) & cemetery (Q39614)',
#   863),
#  ('borough of Pennsylvania (Q777120)', 856),
#  ('village (Q532) & mahalle (Q17051044)', 849),
#  ('walled garden (Q7963015)', 848),
#  ('school district in the United States (Q15726209)', 847),
#  ('body of water (Q15324)', 843),
#  ('village in Armenia (Q28328984)', 843),
#  ('neighborhood of Brazil (Q19658107)', 838),
#  ('bodendenkmal (Q22969563) & abandoned village (Q350895)', 837),
#  ('Landschaftsschutzgebiet (Q21503788)', 836),
#  ('playground (Q11875349)', 833),
#  ('Scottish civil parish (Q5124673)', 833),
#  ('village or neigbourhood (Q103910453)', 829),
#  ('homestead (Q5890494)', 825),
#  ('grape variety (Q958314)', 822),
#  ('town of the United States (Q15127012) & town of New York (Q106071004)',
#   809),
#  ('bog (Q1681353)', 801),
#  ('amphoe (Q475061)', 797),
#  ('cromlech (Q935773)', 790),
#  ('parish of Asturias (Q55102916) & collective population entity of Spain (Q8776398)',
#   789),
#  ('commune of Morocco (Q2989400) & rural commune of Morocco (Q17318027)', 787),
#  ('Natura 2000 protected area (Q15069452)', 782),
#  ('barrio of Puerto Rico (Q3677932)', 780),
#  ('Chitalishte (Q1638962)', 772),
#  ('Ortsteil (Q253019) & municipality of Germany (Q262166)', 772),
#  ('fish pond (Q1265665)', 771),
#  ('river island (Q162602)', 771),
#  ('municipality of the Netherlands (Q2039348)', 770),
#  ('district of Ethiopia (Q690840)', 765),
#  ('protected area (Q473972) & nature reserve in the Czech Republic (Q21101734)',
#   764),
#  ('village (Q532) & desa (Q26211545)', 761),
#  ('village (Q532) & populated place in the Netherlands (Q1852859)', 756),
#  ('shipyard (Q190928)', 756),
#  ('Q55463449', 756),
#  ('bodendenkmal (Q22969563) & Siedlung der Linearbandkeramik (Q106505045) & human settlement (Q486972)',
#   727),
#  ('Q882149 & fourth-level administrative division in Indonesia (Q2225692)',
#   718),
#  ('hillfort (Q744099)', 711),
#  ('district of Indonesia (Q4200298)', 710),
#  ('tehsil of India (Q7694920)', 710),
#  ('district of India (Q1149652)', 709),
#  ('average size village in Latvia (Q16355778) & village in Latvia (Q22580836)',
#   709),
#  ('local government area of Nigeria (Q1639634)', 705),
#  ('Q1329623', 702),
#  ('federal electoral district of Canada (Q17202187)', 701),
#  ('station building (Q1339195)', 679),
#  ('community college (Q1336920)', 673),
#  ('commune of Ivory Coast (Q2679157)', 672),
#  ('market municipality (Q562061) & municipality of Austria (Q667509)', 665),
#  ('human settlement (Q486972) & Siedlung der Urnenfelderzeit (Q106504960) & bodendenkmal (Q22969563)',
#   661),
#  ('wind farm (Q194356)', 661),
#  ('nature area (Q10594991)', 650),
#  ('Lok Sabha constituency (Q47481352)', 645),
#  ('pekon (Q19944049) & fourth-level administrative division in Indonesia (Q2225692)',
#   643),
#  ('heath (Q27590)', 642),
#  ('community development block in India (Q2775236)', 639),
#  ('archipelago (Q33837)', 638),
#  ('commune of Mali (Q1758856)', 635),
#  ('motorsport racing track (Q2338524)', 635),
#  ('locality (Q3257686) & town (Q3957)', 635),
#  ('United States congressional district (Q17166756)', 634),
#  ('coastal water body (Q16615865)', 628),
#  ('moated site (Q107413232)', 627),
#  ('subdistrict administrative organization (Q15140073)', 625),
#  ('municipality of Croatia (Q57058)', 622),
#  ('village (Q532) & village of Ukraine (Q21672098)', 619),
#  ('municipality of Japan (Q1054813) & town of Japan (Q1059478)', 616),
#  ('village in Belarus (Q65661087) & former populated place (Q22674925)', 613),
#  ('national park (Q46169) & national park of Australia (Q18618819)', 609),
#  ('garden square (Q2026833)', 599),
#  ('neighborhoods in Japan (Q65948724)', 599),
#  ('biological reserve (Q445467)', 593),
#  ('urban-rural municipality of Poland (Q3491915)', 591),
#  ('small village in Latvia (Q16363214) & village in Latvia (Q22580836)', 590),
#  ('municipality (Q27676428)', 585),
#  ('former district of Japan (Q46426234)', 579),
#  ('constituency of the French Fifth Republic (Q15620943)', 577),
#  ('gorge (Q55462851)', 576),
#  ('aqueduct (Q474)', 575),
#  ('protected area of Ukraine (Q10977433)', 570),
#  ('urban area in Sweden (Q12813115) & minor locality in Sweden (Q14839548)',
#   570),
#  ('human settlement (Q486972) & urban area in Norway (Q15092344)', 569),
#  ('wilderness area (Q27995042)', 564),
#  ('civil parish (Q1115575) & town (Q3957)', 562),
#  ('Q1147395', 562),
#  ('judicial district of Austria (Q15687338)', 562),
#  ('power station (Q159719)', 555),
#  ('ecclesiastical province (Q625160)', 551),
#  ('rural district of Vietnam (Q2582669)', 549),
#  ('drainage basin (Q166620)', 543),
#  ('convention center (Q1378975)', 540),
#  ('urban area in Norway (Q15092344)', 539),
#  ('WWF ecoregion (Q6617741)', 537),
#  ('National Wildlife Refuge (Q1410668)', 536),
#  ('commune-level town of Vietnam (Q1070942)', 534),
#  ('glacial lake (Q211302)', 534),
#  ('associated commune (Q666943) & commune of France (Q484170)', 534),
#  ('tourist destination (Q1200957)', 532),
#  ('district of Algeria (Q2614970)', 531),
#  ('raion of Ukraine (Q1267632)', 525),
#  ('hermitage (Q1138414) & Ortsteil (Q253019)', 523),
#  ('shipwreck (Q852190) & barque (Q1092993)', 520),
#  ('constituency of the National Assembly of Pakistan (Q33513247)', 519),
#  ('city/town (Q7930989)', 518),
#  ('civil town of Wisconsin (Q15219655)', 514),
#  ('arrondissement of Benin (Q3623867)', 511),
#  ('botanical natural monument (Q20071150)', 507),
#  ('Communities of Cyprus Republic (Q29414133)', 502),
#  ('municipality of Poland (Q15334) & Q515', 499),
#  ('corregimiento (Q3685463)', 498),
#  ('market hall (Q2080521)', 497),
#  ('constituency of the Uttar Pradesh Legislative Assembly (Q26685543)', 497),
#  ('clubhouse (Q1103285)', 496),
#  ('former municipality of Switzerland (Q685309) & municipality of Switzerland (Q70208)',
#   495),
#  ('bodendenkmal (Q22969563) & Bronze Age settlement (Q106491277) & human settlement (Q486972)',
#   489),
#  ('village (Q532) & former municipality of Switzerland (Q685309) & municipality of Switzerland (Q70208)',
#   488),
#  ('theatre (Q24354) & destroyed building or structure (Q19860854)', 487),
#  ('parish of Latvia (Q2577184)', 482),
#  ('human settlement (Q486972) & populated place in the Netherlands (Q1852859)',
#   481),
#  ('fjard (Q9258947)', 481),
#  ('human settlement (Q486972) & urban-type settlement in Ukraine (Q7216840)',
#   480),
#  ('historical region (Q1620908)', 478),
#  ('bodendenkmal (Q22969563) & Q106504986 & human settlement (Q486972)', 476),
#  ('cascina a corte (Q1169748)', 475),
#  ('village (Q532) & commune of Moldova (Q4229812)', 473),
#  ('house (Q3947) & historic site (Q1081138)', 472),
#  ('villa (Q3558430)', 472),
#  ('upazila of Bangladesh (Q620471)', 471),
#  ('First Nation band (Q2882257)', 470),
#  ('golf club (Q2022036)', 469),
#  ('human settlement (Q486972) & bodendenkmal (Q22969563) & open air site (Q17540983) & Freilandstation des Mesolithikums (Q106491386)',
#   469),
#  ('brigantine (Q189418) & shipwreck (Q852190)', 469),
#  ('churchyard (Q2749813)', 468),
#  ('harbor (Q283202)', 467),
#  ('Q105390172', 464),
#  ('human settlement (Q486972) & village in Turkey (Q1529096)', 462),
#  ('biosphere reserve (Q158454)', 459),
#  ('sanjak (Q330425)', 459),
#  ('han system (Q841985)', 458),
#  ('hamlet (Q5084) & Ortsteil (Q253019)', 455),
#  ('ethnic township (Q582525)', 455),
#  ('constituent locality (Q15921247)', 452),
#  ('city of Japan (Q494721)', 452),
#  ('dwelling place (Q4632675)', 451),
#  ('territorial entity (Q1496967)', 449),
#  ('scattered village in Latvia (Q16352482) & village in Latvia (Q22580836)',
#   449),
#  ('rancho of California (Q2679045)', 449),
#  ('former municipality of Norway (Q18663579)', 448),
#  ('rural municipality of Canada (Q3327874)', 442),
#  ('cadastral area in the Czech Republic (Q20871353) & core municipal part with the same name as the municipality in the Czech Republic (Q56398194) & part of municipality in the Czech Republic (Q61089180)',
#   441),
#  ('New England town (Q2154459)', 439),
#  ('intermittent river (Q21079327)', 438),
#  ('cove (Q31615)', 437),
#  ('Q4897108', 437),
#  ('manor (Q2066754)', 436),
#  ('terrace of houses (Q18814858)', 431),
#  ('township of Nebraska (Q64138263)', 430),
#  ('uyezd of the Russian Empire (Q18867465)', 427),
#  ('institutional complex (Q19691007)', 425),
#  ('Q2755753', 422),
#  ('part of city or town or population centre (Q103910131)', 420),
#  ('human settlement (Q486972) & quarter (Q2983893)', 419),
#  ('rural commune of Morocco (Q17318027)', 418),
#  ('rural district of England, Wales, and Ireland (Q1754946)', 417),
#  ('pasiolak (Q65665664)', 417),
#  ('skerry (Q216851)', 414),
#  ('community garden (Q251958)', 414),
#  ('subdistrict municipality (Q15141625) & Sukhaphiban (Q7635776)', 412),
#  ('ancient Roman structure (Q14752696)', 411),
#  ('anchorage (Q10952797)', 410),
#  ('designated place of Canada (Q956318)', 410),
#  ('Q493522', 408),
#  ('locality (Q3257686) & suburb/locality of Tasmania (Q98433835)', 408),
#  ('county of Iran (Q137535)', 407),
#  ('district of Costa Rica (Q2292572)', 407),
#  ('field (Q188869)', 406),
#  ('golf course (Q1048525)', 405),
#  ('masonic temple (Q1454583)', 403),
#  ('village (Q532) & community (Q2630741)', 402),
#  ('crash site (Q15921563)', 401),
#  ('Cemetery cross (Q98141330)', 401),
#  ('neighborhood (Q123705) & historic district (Q15243209)', 399),
#  ('municipality of Venezuela (Q3327920)', 399),
#  ('IANA time zone (Q17272692)', 398),
#  ('electoral district (Q192611) & United States of America State-level electoral district (Q104146934)',
#   396),
#  ('regency of Indonesia (Q3191695)', 395),
#  ('commune of Moldova (Q4229812)', 393),
#  ('district of Afghanistan (Q496825)', 393),
#  ('art gallery (Q1007870) & business (Q4830453)', 390),
#  ('golf club (Q2022036) & golf course (Q1048525)', 386),
#  ('horse racing venue (Q11822917)', 385),
#  ('former local government area of Australia (Q30129411)', 385),
#  ('village (Q532) & desa (Q26211545) & fourth-level administrative division in Indonesia (Q2225692)',
#   383),
#  ('collective population entity of Spain (Q8776398)', 383),
#  ('deanery (Q385337)', 382),
#  ('pastoral lease (Q13411064)', 381),
#  ('sector of Rwanda (Q3058029)', 375),
#  ('religious institute (Q5135744)', 375),
#  ('town of Portugal (Q19833170) & freguesia of Portugal (Q1131296)', 374),
#  ('settlement site (Q1708422)', 372),
#  ('Hofmauer (Q98141352)', 371),
#  ('open-air museum (Q756102)', 369),
#  ('hillslope fort (Q31028695)', 368),
#  ('zone (Q55135234)', 368),
#  ('big city (Q1549591) & Q515', 366),
#  ('district of Japan (Q1122846)', 364),
#  ('wharf (Q828909)', 363),
#  ('urban okrug in Russia (Q13626398)', 363),
#  ('monastery (Q44613) & bodendenkmal (Q22969563)', 363),
#  ('resort (Q875157)', 358),
#  ('midden (Q1152199)', 358),
#  ('village of Wisconsin (Q15221242)', 358),
#  ('bodendenkmal (Q22969563) & grave field (Q2593777)', 358),
#  ('town (Q3957) & Q1147395', 355),
#  ('stations of the cross (Q231685)', 354),
#  ('chutar (Q65660829)', 354),
#  ('housing estate (Q12104567)', 353),
#  ('city district of Brazil (Q3624938)', 353),
#  ('village of New York (Q55237813) & village in the United States (Q751708)',
#   353),
#  ('roadside rest area (Q785979)', 353),
#  ('lugar (Q13526752)', 352),
#  ('cricket field (Q682943)', 349),
#  ('rural council of Ukraine (Q4414033)', 348),
#  ('nuclear power plant (Q134447)', 347),
#  ('federal constituency of Nigeria (Q59680832)', 346),
#  ('diocese (Q665487)', 346),
#  ('Q9309832', 346),
#  ('arrondissement of France (Q194203)', 340),
#  ('electoral district of New South Wales (Q3032154)', 340),
#  ('human settlement (Q486972) & census-designated place (Q498162)', 340),
#  ('Pennsylvania State Game Lands (Q7164192)', 340),
#  ('human settlement (Q486972) & town (Q3957)', 339),
#  ('municipality of Norway (Q755707)', 339),
#  ('Q2298305', 337),
#  ('Q100341898', 336),
#  ('department of Burkina Faso (Q2566190)', 336),
#  ('federal electoral district of Germany (Q11703715)', 335),
#  ('constituency of the Parliament of the Republic of Ghana (Q41760643)', 335),
#  ('constituency of the West Bengal Legislative Assembly (Q47490604)', 335),
#  ('bodendenkmal (Q22969563) & cemetery (Q39614) & human settlement (Q486972)',
#   333),
#  ('commune of Angola (Q1841580)', 332),
#  ('ancient city (Q15661340) & polis (Q148837)', 331),
#  ('former municipality (Q19730508)', 331),
#  ('municipality of Greece (Q1349648)', 328),
#  ('village of Brunei (Q48731335)', 328),
#  ('old town (Q676050)', 326),
#  ('barony (Q853565)', 325),
#  ('run-of-the-river power station (Q1411996)', 324),
#  ('subprefecture of Guinea (Q1853398)', 324),
#  ('human settlement (Q486972) & municipality section (Q2785216)', 324),
#  ('polder (Q106259)', 323),
#  ('municipality of Georgia (Q76514543) & city of the United States (Q1093829)',
#   323),
#  ('ōaza (Q424857)', 323),
#  ('myeon (Q483515)', 323),
#  ('Ortsbezirk of Germany (Q163301) & Gemarkung (Q1499928)', 321),
#  ('war cemetery (Q1707610)', 321),
#  ('Lost Roman Catholic diocese (Q27780831)', 319),
#  ('bight (Q17018380) & bay (Q39594)', 318),
#  ('village (Q532) & municipality section (Q2785216)', 318),
#  ('human settlement (Q486972) & moshav (Q917146)', 316),
#  ('department of Argentina (Q952274)', 316),
#  ('junior college (Q370258)', 315),
#  ('regional nature reserve (Q3936950) & protected area (Q473972)', 315),
#  ('building (Q41176) & historic site (Q1081138)', 313),
#  ('powiat of Poland (Q247073)', 310),
#  ('district of Yemen (Q6617100)', 310),
#  ('music venue (Q8719053)', 310),
#  ('district of Mongolia (Q1518096)', 308),
#  ('district of the House of Representatives of Japan (Q23983335)', 307),
#  ('concert hall (Q1060829)', 306),
#  ('General Service Area (Q5532181)', 306),
#  ('community development block in Odisha (Q61863384)', 306),
#  ('human settlement (Q486972) & town of the United States (Q15127012)', 305),
#  ('partial contour fort (Q31028314)', 305),
#  ('photovoltaic power station (Q1003207)', 304),
#  ('hundred (Q313354)', 304),
#  ('village (Q532) & populated place in the Netherlands (Q1852859) & municipality of the Netherlands (Q2039348)',
#   303),
#  ('marketplace (Q330284)', 302),
#  ('Ortsteil (Q253019) & village with a church (Q378636)', 302),
#  ('constituency of the Jatiyo Sangsad (Q47468610)', 302),
#  ('federal electoral district of Mexico (Q1154445)', 301),
#  ('house of culture (Q5061188)', 301),
#  ('state forest (Q2324919)', 300),
#  ('Eastern Orthodox eparchy (Q60176300)', 300),
#  ('municipality of Guatemala (Q1872284)', 299),
#  ('ancient Roman structure (Q14752696) & castrum (Q88205)', 298),
#  ('community center (Q77115)', 298),
#  ('garden gate (Q98141338)', 298),
#  ('community council (Q3403338)', 297),
#  ('Amt (Q478847)', 297),
#  ('civil parish (Q1115575) & hamlet (Q5084)', 292),
#  ('township in the United States (Q28111) & township of Illinois (Q17198545)',
#   292),
#  ('work settlement of Russia (Q20019082)', 291),
#  ('constituency of the Maharashtra Legislative Assembly (Q54375467)', 288),
#  ('council of Araba (Q16543169)', 287),
#  ('designed landscape (Q5264414)', 287),
#  ('cist (Q1399576)', 286),
#  ('rest area (Q786014)', 286),
#  ('town in Hungary (Q13218690)', 284),
#  ('county-level city (Q1070990)', 283),
#  ('unorganized territory (Q1550680)', 282),
#  ('hut circle (Q16942515)', 282),
#  ('district of Prussia (Q5283531)', 282),
#  ('constituency of the Tamil Nadu Legislative Assembly (Q54375510)', 282),
#  ('constituency of the provincial assembly of Punjab Province (Q59147545)',
#   282),
#  ('natural region (Q1970725)', 281),
#  ('reservoir (Q131681) & lake (Q23397)', 280),
#  ('Q1394476 & township of Iowa (Q17205621)', 279),
#  ('parish village (Q1493533) & Ortsteil (Q253019)', 279),
#  ('residential area (Q674950)', 279),
#  ('municipality of Sweden (Q127448)', 278),
#  ('grave field (Q2593777)', 277),
#  ('Roman villa (Q918230) & human settlement (Q486972)', 276),
#  ('military cemetery (Q1241568)', 274),
#  ('tehsil of Pakistan (Q18670606)', 273),
#  ('chambered cairn (Q585490)', 273),
#  ('heritage railway (Q420962)', 272),
#  ('ecoregion (Q295469) & WWF ecoregion (Q6617741)', 271),
#  ('commune of Cameroon (Q3076994)', 271),
#  ('performing arts center (Q3469910)', 269),
#  ('big city (Q1549591) & Q3184121', 267),
#  ('city/town (Q7930989) & subdivisions of Russia (Q192287)', 267),
#  ('subdistrict municipality (Q15141625) & subdistrict administrative organization (Q15140073)',
#   266),
#  ('opera house (Q153562)', 266),
#  ('Constituency of the Parliament of England (Q27990982)', 266),
#  ('precinct (Q3301455)', 266),
#  ('municipality of Tunisia (Q41067667)', 266),
#  ('human settlement (Q486972) & Q515', 264),
#  ('constituency of the Bihar Legislative Assembly (Q54375424)', 264),
#  ('human settlement (Q486972) & posyolok (Q2514025)', 263),
#  ('water park (Q740326)', 262),
#  ('urban-type settlement in Ukraine (Q7216840)', 262),
#  ('township of Myanmar (Q7830262)', 262),
#  ('сhurch college (Q1743327)', 261),
#  ('open-air theatre (Q11183017)', 260),
#  ('town (Q44529188)', 260),
#  ('delegation (Q1184072)', 259),
#  ('commune of Chile (Q1840161)', 259),
#  ('nightclub (Q622425)', 259),
#  ('stone circle (Q1935728)', 257),
#  ('bodendenkmal (Q22969563) & Settlement of the La Tene period (Q106505016) & human settlement (Q486972)',
#   255),
#  ('gymnasium (Q14092)', 254),
#  ('municipality of Bulgaria (Q1906268)', 253),
#  ('human settlement (Q486972) & border town (Q902814)', 252),
#  ('locality (Q3257686) & municipality (Q15284)', 251),
#  ('multi-purpose hall (Q1763828)', 251),
#  ('district of Ghana (Q545769)', 251),
#  ('castle park (Q2244647)', 250),
#  ('open air site (Q17540983) & Freilandstation des Mesolithikums (Q106491386) & human settlement (Q486972) & Neolithic settlement (Q106491339) & bodendenkmal (Q22969563)',
#   250),
#  ('burnt mound (Q1016853)', 249),
#  ('event venue (Q18674739)', 249),
#  ('landscape reserve (Q20081524)', 249),
#  ('township of New Jersey (Q7830213)', 248),
#  ('human settlement (Q486972) & village development committee of Nepal (Q1530705)',
#   247),
#  ('metropolitan area (Q1907114)', 246),
#  ('village in Saskatchewan (Q20538317)', 246),
#  ('tea garden (Q1827414) & village in India (Q56436498)', 245),
#  ('Massachusetts House of Representatives electoral district (Q91638539)',
#   244),
#  ('municipalities and cities of Serbia (Q783930)', 243),
#  ('green space (Q22652)', 242),
#  ('remarkable tree (Q811534) & grove (Q1510380)', 242),
#  ('village/town/city in Lebanon (Q23828039)', 242),
#  ('Q11774097', 240),
#  ('community (Q2630741)', 240),
#  ('municipality of El Salvador (Q3556889)', 240),
#  ('whisky distillery (Q10373548)', 239),
#  ('municipality of Bolivia (Q1062710)', 239),
#  ('necropolis (Q200141)', 239),
#  ('unincorporated area in Germany (Q15974311)', 237),
#  ('municipality of Niger (Q605291)', 237),
#  ('Q12131624', 236),
#  ('local municipality (Q1500352)', 235),
#  ('human settlement (Q486972) & minor locality in Sweden (Q14839548)', 232),
#  ('congressional district of the Philippines (Q96020121)', 232),
#  ('regional park (Q6063204)', 231),
#  ('neighbourhood of São Paulo (Q19886692)', 231),
#  ('sculpture garden (Q1759852)', 230),
#  ('ancient city (Q15661340) & archaeological site (Q839954)', 230),
#  ('municipal corporation in India (Q6936225)', 230),
#  ('megalithic tomb (Q10521078)', 229),
#  ('ghost town (Q74047) & unincorporated community in the United States (Q17343829)',
#   229),
#  ('Monumento natural de España (Q26939879) & protected area (Q473972)', 228),
#  ('long barrow (Q1652352)', 228),
#  ('hacienda (Q917730)', 228),
#  ('village (Q532) & archaeological site (Q839954)', 227),
#  ('municipal unit of Albania (Q28017630)', 227),
#  ('mint (Q464780)', 227),
#  ('Microregion of Brazil (Q682944)', 227),
#  ('architectural heritage monument (Q811165)', 226),
#  ('former municipality of Denmark (Q23036513)', 226),
#  ('bullring (Q1193438)', 225),
#  ('million city (Q1637706) & prefecture-level city (Q748149) & big city (Q1549591)',
#   225),
#  ('cortijo (Q12161100)', 224),
#  ('constituency of the Madhya Pradesh Legislative Assembly (Q54375465)', 224),
#  ('polttokenttäkalmisto (Q11888579)', 223),
#  ('neighborhood (Q123705) & unincorporated community in the United States (Q17343829)',
#   223),
#  ('princely state (Q1336152)', 223),
#  ('theatre (Q24354) & destroyed building or structure (Q19860854) & movie theater (Q41253)',
#   223),
#  ('residential college (Q2680291)', 223),
#  ('Ogham Site (Q72617071)', 222),
#  ('MEOW marine ecoregion (Q107539356)', 221),
#  ('neighborhood (Q123705) & human settlement (Q486972)', 221),
#  ('subprefecture in France (Q16481846)', 221),
#  ('American Viticultural Area (Q166247)', 221),
#  ('botanical reserve (Q20071151)', 221),
#  ('division of the Australian House of Representatives (Q2713747)', 220),
#  ('small river (Q3529419)', 220),
#  ('watercourse (Q355304) & stream (Q47521)', 220),
#  ('uninominal constituency of the Italian Chamber of Deputies (Q48075035)',
#   219),
#  ('Saxon post milestone (Q896635)', 219),
#  ('parish of Venezuela (Q6063801)', 218),
#  ('Royal Saxon milestone (Q84163056)', 218),
#  ('bodendenkmal (Q22969563) & Stone Age settlement (Q106504971) & human settlement (Q486972)',
#   217),
#  ('electoral district of Queensland (Q5356184)', 217),
#  ('electoral district of Victoria (Q5356187)', 217),
#  ('constituency of the Karnataka Legislative Assembly (Q54375457)', 217),
#  ('Electoral district of Ukraine (Q63084210)', 217),
#  ('cultural heritage monument in Germany (Q11691318)', 216),
#  ('urban settlement in Russia (Q2661988)', 216),
#  ('shipwreck (Q852190)', 216),
#  ('městys (Q16155707) & municipality of the Czech Republic (Q5153359)', 214),
#  ('suco of East Timor (Q22044663)', 214),
#  ('bus terminus (Q2920759)', 213),
#  ('shieling (Q2082774)', 213),
#  ('hundred in Sweden (Q26678373)', 213),
#  ('administrative region (Q3455524)', 212),
#  ('suburb (Q188509) & gazetted locality of Victoria (Q45242174)', 212),
#  ('creek (Q1437299)', 211),
#  ('historic grouping (Q3317612)', 211),
#  ('municipality of Finland (Q856076) & Q17468533', 211),
#  ('lembang (Q12494403) & fourth-level administrative division in Indonesia (Q2225692)',
#   210),
#  ('former New Zealand electorate (Q26714837)', 210),
#  ('industrial zone (Q329683)', 210),
#  ('kampung of Papua (Q12488913) & kampung of East Kalimantan Province (Q24659756)',
#   209),
#  ('arrondissement of France (Q194203) & former administrative territorial entity (Q19953632)',
#   209),
#  ('former municipality (Q19730508) & Q1985797', 209),
#  ('golden sand beach (Q28060956) & urban beach (Q7900097)', 209),
#  ('Roman villa (Q918230) & ancient Roman structure (Q14752696)', 208),
#  ('large village in Latvia (Q16362394) & village in Latvia (Q22580836)', 208),
#  ('former municipality of Estonia (Q26742250) & Q28122896', 208),
#  ('chiefdom of Sierra Leone (Q5097104)', 208),
#  ('thermal power station (Q200297)', 207),
#  ('eup of South Korea (Q24024848)', 207),
#  ('borough of New Jersey (Q2911266)', 207),
#  ('provincial electoral district of Quebec (Q2973931)', 207),
#  ('cultural landscape (Q1129474)', 206),
#  ('arts centre (Q2190251)', 206),
#  ('township seat (Q34842263) & constituent locality (Q15921247)', 205),
#  ('canton of Ecuador (Q1724017)', 205),
#  ('state park (Q1761072)', 205),
#  ('Q1352019', 204),
#  ('municipality with town privileges in the Czech Republic (Q15978299) & municipality of the Czech Republic (Q5153359)',
#   204),
#  ('former village (Q21507948)', 204),
#  ('casería (Q5756064)', 204),
#  ('Listed Building in Acre (Q81274644)', 204),
#  ('urban-type settlement in Russia (Q15078955)', 203),
#  ('wildlife management area (Q8001309)', 203),
#  ('baseball venue (Q595452)', 202),
#  ('dock (Q124282)', 201),
#  ('long-distance trail (Q13405588)', 201),
#  ('ghetto in Nazi-occupied Europe (Q2583015) & ghetto (Q152018)', 201),
#  ('group of houses (Q2282602)', 201),
#  ('district of Hungary (Q1162835)', 200),
#  ('human settlement (Q486972) & commune of Ivory Coast (Q2679157)', 200),
#  ('art gallery (Q1007870) & Q207694', 199),
#  ('water board in the Netherlands (Q702081)', 198),
#  ('arboretum (Q272231)', 198),
#  ('Q3154693', 198),
#  ('long-distance trail (Q13405588) & hiking trail (Q2143825)', 196),
#  ('non-metropolitan district council (Q21561306)', 196),
#  ('constituency of the Rajasthan Legislative Assembly (Q54375498)', 195),
#  ('peninsula (Q34763) & headland (Q191992)', 194),
#  ('vallis (Q2249285)', 193),
#  ('Oregon state park (Q37899979)', 193),
#  ('river (Q4022) & natural watercourse (Q55659167)', 193),
#  ('city of Oregon (Q63440326)', 193),
#  ('Q2989470', 192),
#  ('electoral ward of the Bruhat Bengaluru Mahanagara Palike (Q58232822)', 192),
#  ('constituency of the European Parliament (Q2631496)', 191),
#  ('village of Taiwan (Q7930614) & human settlement (Q486972)', 191),
#  ('human settlement (Q486972) & town municipality of Turkey (Q815324)', 191),
#  ('district of Paraguay (Q917092)', 190),
#  ('suffragan diocese (Q373074) & Roman Catholic diocese (Q105388829)', 189),
#  ('Q16858213', 189),
#  ('Q2616791', 189),
#  ('United States National Forest (Q612741)', 189),
#  ('provincial electoral district of Alberta (Q4711861)', 189),
#  ('local government area of Australia (Q1867183)', 188),
#  ('municipality of Spain (Q2074737) & municipality of Galicia (Q2276925)',
#   188),
#  ('province of Peru (Q509686)', 187),
#  ('Q54375413', 187),
#  ('foundry (Q13883136)', 186),
#  ('populated place in the Netherlands (Q1852859)', 186),
#  ('townland (Q2151232) & human settlement (Q486972)', 186),
#  ('district of Tanzania (Q2409750)', 186),
#  ('countship (Q353344)', 185),
#  ('district of Cambodia (Q14846918)', 184),
#  ('subdivisions of Russia (Q192287) & urban-type settlement in Russia (Q15078955)',
#   184),
#  ('village (Q532) & former municipality (Q19730508) & Ortsteil (Q253019)',
#   184),
#  ('drainage system (Q285451) & drainage basin (Q166620)', 183),
#  ('hydrological reserve (Q20071160)', 183),
#  ('level terrain fort (Q31028835)', 183),
#  ('township (Q3744870)', 183),
#  ('intermittent lake (Q10313934)', 182),
#  ('distillery (Q1251750)', 182),
#  ('okrug of the Soviet Union (Q18071983)', 181),
#  ('former administrative territorial entity (Q19953632)', 180),
#  ('bodendenkmal (Q22969563) & open air site (Q17540983)', 179),
#  ('Stadtbezirk (Q2740635)', 179),
#  ('basic unit of settlement in the Czech Republic (Q329245)', 179),
#  ('pumped-storage power station (Q339353)', 179),
#  ('constituency of the provincial assembly of Khyber Pakhtunkhwa (Q59147732)',
#   179),
#  ('municipality seat (Q15303838) & city of Bulgaria (Q89487741)', 179),
#  ('protected area of Russia (Q1959314)', 178),
#  ('hiking trail (Q2143825) & sender local (Q11948177)', 178),
#  ('Verbandsgemeinde (Q23006)', 178),
#  ('gas-fired power station (Q2944640)', 178),
#  ('cave with prehistoric art (Q11269813)', 177),
#  ('hot spring (Q177380)', 177),
#  ('sports venue (Q1076486) & stadium (Q483110)', 176),
#  ('Q4286337', 176),
#  ('constituency of the National Assembly of Kenya (Q47461453) & Constituency of Kenya (Q55193935)',
#   176),
#  ('assembly plant (Q47509284)', 176),
#  ('maarekisterikylä (Q18691318) & village (Q532)', 175),
#  ('Q456876', 175),
#  ('municipal corporation area (Q58953536)', 175),
#  ('masonic lodge (Q1454597)', 174),
#  ('city or town (Q27676416)', 174),
#  ("administrative territorial entity of the People's Republic of China (Q50231)",
#   174),
#  ('municipality of Finland (Q856076)', 174),
#  ('principality (Q208500)', 173),
#  ('deserted medieval village (Q21751582)', 173),
#  ('ski jumping hill (Q1109069)', 172),
#  ('hundred of South Australia (Q28942331)', 172),
#  ('town (Q3957) & urban municipality of Germany (Q42744322)', 172),
#  ('constituency of the Gujarat Legislative Assembly (Q54375438)', 172),
#  ('religious congregation (Q1384677)', 171),
#  ('village (Q532) & khutor (Q2023000)', 171),
#  ('district of Kazakhstan (Q2643128)', 171),
#  ('abolished municipality in Italy (Q3685476)', 171),
#  ('township-level division similar to townships (Q12809484)', 170),
#  ('ward of Japan (Q137773)', 170),
#  ('village of Japan (Q4174776)', 170),
#  ('khlong (Q1740654)', 169),
#  ('enclosure (Q5375483)', 169),
#  ('constituency of the Odisha Legislative Assembly (Q54375487)', 169),
#  ('pasiolak (Q65665664) & former populated place (Q22674925)', 169),
#  ('town municipality of Turkey (Q815324)', 169),
#  ('airport terminal (Q849706)', 169),
#  ('markaz of Egypt (Q10577534)', 168),
#  ('Indian reservation of the United States (Q5398059)', 168),
#  ('area (Q1414991)', 168),
#  ('municipality of Spain (Q2074737) & town (Q3957)', 168),
#  ('human settlement (Q486972) & municipality of Lebanon (Q6936383) & village/town/city in Lebanon (Q23828039)',
#   168),
#  ('church congregation (Q2638480)', 168),
#  ('Q374614', 168),
#  ('village in the United States (Q751708) & unincorporated community in the United States (Q17343829)',
#   168),
#  ('Q3126170', 167),
#  ('abolished municipality in Italy (Q3685476) & frazione (Q1134686)', 166),
#  ('oil refinery (Q12353044)', 166),
#  ('tributary (Q159675)', 166),
#  ('Anglican diocese (Q18917976)', 166),
#  ('forest managed biological reserve (Q65953608) & protected area (Q473972)',
#   166),
#  ('constituency of the Kerala Legislative Assembly (Q54375461)', 166),
#  ('Q7362268 & ancient Roman structure (Q14752696)', 165),
#  ('mahalle (Q17051044) & town municipality of Turkey (Q815324)', 165),
#  ('monastery (Q44613) & abbey (Q160742)', 163),
#  ('national necropolis in France (Q19951362)', 163),
#  ('quinta (Q25339974)', 163),
#  ('town (Q3957) & unparished area (Q7897276)', 163),
#  ('wildlife refuge (Q1377575)', 162),
#  ('multiplex (Q1153108)', 162),
#  ('religious order (Q2061186)', 162),
#  ('locality (Q3257686) & village (Q532)', 162),
#  ('national nature reserve (Q18379650) & protected area (Q473972)', 161),
#  ('shipwreck (Q852190) & ketch (Q753784)', 161),
#  ('wine-producing region (Q2140699)', 160),
#  ('protected area (Q473972) & regional nature reserve (Q15089606)', 159),
#  ('Q2579179', 159),
#  ('theatre (Q24354) & opera house (Q153562)', 158),
#  ('town council of Uganda (Q110977342)', 157),
#  ('protected area (Q473972) & protected area of Russia (Q1959314)', 157),
#  ('county park (Q5177940)', 156),
#  ('sports field (Q1202618)', 156),
#  ('waterfowl production area (Q7974063)', 156),
#  ('group of protected areas (Q28777651)', 155),
#  ('inlet (Q1172599)', 155),
#  ('national park of Australia (Q18618819)', 155),
#  ('county of Georgia (Q13410428)', 154),
#  ('municipality with town privileges in the Czech Republic (Q15978299) & municipality with authorized municipal office (Q7841907) & municipality of the Czech Republic (Q5153359)',
#   154),
#  ('swimming center (Q200023)', 154),
#  ('protected area of Brazil (Q2919841)', 154),
#  ('gracht (Q523166)', 154),
#  ('erg (Q319120)', 153),
#  ('district (Q106658)', 152),
#  ('ranch (Q509028)', 152),
#  ('city district in Russia (Q15195406)', 152),
#  ('atoll (Q42523)', 152),
#  ('hromada (Q104841013)', 151),
#  ('human settlement (Q486972) & Divisional Secretariat of Sri Lanka (Q1990968)',
#   151),
#  ('municipality of Angola (Q378508)', 151),
#  ('kouiki chimei (Q11484330)', 150),
#  ('Q14723701', 150),
#  ('unincorporated community in the United States (Q17343829) & human-geographic territorial entity (Q15642541)',
#   150),
#  ('auditorium (Q230752) & event venue (Q18674739)', 150),
#  ('urban zone of Rome (Q21011129)', 150),
#  ('business park (Q338313)', 150),
#  ('Q5177124', 150),
#  ('central business district (Q738570)', 150),
#  ('subprefecture of Chad (Q7630629)', 150),
#  ('Zhou (Q1070912)', 149),
#  ('church building (Q16970) & historic site (Q1081138)', 149),
#  ('district of Mozambique (Q2068214)', 149),
#  ('agreed administrative community in Baden-Württemberg, Germany (Q1561418)',
#   148),
#  ('artificial lake (Q3215290)', 148),
#  ('ab anbar (Q303874)', 148),
#  ('unparished area (Q7897276)', 148),
#  ('velodrome (Q830528)', 148),
#  ('alfarería (lugar de fabricación) (Q97457858)', 148),
#  ('New York state park (Q37995709)', 147),
#  ('town of Portugal (Q19833170) & municipality of Portugal (Q13217644)', 147),
#  ('armory (Q1412205)', 147),
#  ('urban township of Minnesota (Q15063142)', 147),
#  ('constituency of the Parliament of Ireland (Q21815201)', 147),
#  ('protected site (Q13402998) & protected area (Q473972)', 146),
#  ('Q2631599', 146),
#  ('onsen (Q655311)', 146),
#  ('Metropolitan Statistical Area (Q1768043)', 145),
#  ('horse stud farm (Q108696)', 145),
#  ('FFH-Habitat (Q60029820)', 145),
#  ('department of France (Q6465)', 145),
#  ('subregion of Hungary (Q715398)', 145),
#  ('esplanade (Q88372)', 145),
#  ('ice rink (Q1282870)', 144),
#  ('town of the United States (Q15127012) & county seat (Q62049)', 144),
#  ('natural gas-fired power station (Q3498533)', 144),
#  ('Municipal District (Q6664352)', 144),
#  ('calvary hill (Q11331347)', 143),
#  ('national nature reserve (Q19656847) & protected area (Q473972)', 143),
#  ('ford (Q12743)', 143),
#  ("forester's lodge (Q1425352)", 143),
#  ('commandry (Q1434544)', 143),
#  ('Home Ownership Scheme housing estate (Q19754218)', 143),
#  ('municipality of Albania (Q2008050)', 143),
#  ('fare zone (Q25377652)', 143),
#  ('town (Q3957) & suburb/locality of Tasmania (Q98433835)', 143),
#  ('archaeological site (Q839954) & historic district (Q15243209)', 142),
#  ('township of Taiwan (Q2367508)', 142),
#  ('district of Pakistan (Q2379075)', 142),
#  ('stanitsa (Q748331)', 142),
#  ('hromada (Q104841013) & amalgamated hromada (Q4291381)', 141),
#  ('landscape (Q107425)', 141),
#  ('sports park (Q16363669)', 141),
#  ('Q1322134', 141),
#  ('place with town rights and privileges (Q13539802) & municipality of Austria (Q667509)',
#   141),
#  ('ulus (Q18632459)', 141),
#  ('village (Q532) & posyolok (Q2514025)', 141),
#  ('Samtgemeinde (Q447523)', 141),
#  ('Block Panchayat (Q4927168)', 141),
#  ('sawmill (Q505213)', 141),
#  ('Antarctic research station (Q749622)', 141),
#  ('ancient Roman structure (Q14752696) & archaeological site (Q839954) & castrum (Q88205)',
#   140),
#  ('town (Q3957) & small burgh (Q7543008)', 140),
#  ('district of Laos (Q5283521)', 140),
#  ('public water well (Q53628296)', 140),
#  ('federally recognized Native American tribe in the United States (Q7840353)',
#   140),
#  ('vice-county (Q7925010)', 140),
#  ('meadow (Q7777019)', 139),
#  ('former parish of Latvia (Q110835114)', 139),
#  ('school district of Canada (Q15726214)', 139),
#  ('desa (Q26211545) & kelurahan (Q965568)', 139),
#  ('burial island (Q64521891)', 139),
#  ('nature park (Q728904)', 138),
#  ('tied island (Q1226252)', 138),
#  ('kampung (Q12488911) & fourth-level administrative division in Indonesia (Q2225692)',
#   138),
#  ('Gemarkung (Q1499928)', 138),
#  ('human settlement (Q486972) & kibbutz (Q161387)', 138),
#  ('rose garden (Q291177)', 138),
#  ('forest reserve (Q7315273)', 138),
#  ('réserve naturelle reconnue (Q104804750)', 137),
#  ('municipality of the Dominican Republic (Q6005581)', 137),
#  ('deme (Q672490)', 137),
#  ('district of Taiwan (Q705296)', 137),
#  ('national park of Thailand (Q95080679)', 137),
#  ('massif (Q1061151)', 136),
#  ('Catholic parish (Q17143723)', 136),
#  ('subsectors of Puerto Rico (Q18654693)', 136),
#  ('bodendenkmal (Q22969563) & grave field (Q2593777) & human settlement (Q486972)',
#   136),
#  ('research station (Q195339)', 136),
#  ('theatre (Q24354) & theatrical troupe (Q742421)', 136),
#  ('irrigation canal (Q2935978)', 136),
#  ('proposed site of community importance (Q60534895) & site of community importance (Q796174)',
#   136),
#  ...]

# %% [markdown]
# ### Examples of inheritance hierarchy

# %% [markdown]
# #### River

# %%
# %%bash
# rg "Q4022" /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl | head -n 1 | jq
# Out:
# {
#   "wikidata_id": "Q584",
#   "name": "Rhine",
#   "type": "LOC",
#   "instance_of": [
#     "Q1009249",
#     "Q573344",
#     "Q4022",
#     "Q1267889"
#   ]
# }

# %%
why_loc_human_readable["Q584"]
# Out:
# {('Q1009249', 'national waterways in Germany'),
#  ('Q1267889', 'waterway'),
#  ('Q4022', 'river'),
#  ('Q573344', 'main stream')}

# %% [markdown]
# [`Rhine`](https://www.wikidata.org/wiki/Q584) is an instance of [`waterway`](https://www.wikidata.org/wiki/Q1267889) which is a subclass of [`body of water`](https://www.wikidata.org/wiki/Q15324) which is a subclass of [`geographic region`](https://www.wikidata.org/wiki/Q82794). Thus `Rhine` is LOC.

# %% [markdown]
# #### Anglican diocese

# %%
# %%bash
# rg "Q18917976" /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/LOC.jsonl | head -n 1 | jq
# Out:
# {
#   "wikidata_id": "Q375891",
#   "name": "Diocese of Southwell and Nottingham",
#   "type": "LOC",
#   "instance_of": [
#     "Q18917976"
#   ]
# }

# %%
why_loc_human_readable["Q375891"]
# Out:
# {('Q18917976', 'Anglican diocese')}

# %% [markdown]
# [`Diocese of Southwell and Nottingham`](https://www.wikidata.org/wiki/Q375891) is an instance of [`Anglican diocese`](https://www.wikidata.org/wiki/Q18917976) which is a subclass of [`diocese`](https://www.wikidata.org/wiki/Q665487). Diocese is a subclass of [`religious administrative territorial entity`](https://www.wikidata.org/wiki/Q20926517) which is a subclass of [`human-geographic territorial entity`](https://www.wikidata.org/wiki/Q15642541) which is a subclass of [`territory`](https://www.wikidata.org/wiki/Q4835091) which is a subclass of [`geographic region`](https://www.wikidata.org/wiki/Q82794).

# %% [markdown]
# ### ORG

# %%
# %%bash
# wc -l /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/ORG.jsonl
# Out:
# 2196303 /home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/ORG.jsonl

# %%
org_entities_jsonl_path = Path("/home/jonne/datasets/paranames/analyze-instance-ofs-withsubclassing-3col/ORG.jsonl")
subclass_of_organization = get_subclasses_of_item("Q43229")

# %%
why_org = {}
with open(org_entities_jsonl_path, 'r', encoding="utf-8") as fin:
    look_up_these_org = set()
    for ix, line in track(enumerate(fin), total=2196302, description="Checking what makes ORG entities ORG..."):
        row = orjson.loads(line)
        wid = row['wikidata_id']
        name = row['name']
        instance_of = set(row['instance_of'])
        if "Q43229" in instance_of:
            continue
        common = instance_of.intersection(subclass_of_geographic_region)
        why_org_value = common if len(common) > 0 else instance_of
        assert all(type(thing) == str for thing in why_org_value), row
        look_up_these_org.update(why_org_value)
        why_org[wid] = why_org_value
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# Make the instance-of names human readable
looked_up_org = {
    r['id']: r['name']
    if r['name'] 
    else grab_first_available(r['labels']) 
    for r in coll.find(
        {"id": {"$in": list(look_up_these_org)}}
    )
}

# %%
why_org_human_readable = {}
for wid, inst_of_set in track(why_org.items(), description="Making the IDs human readable..."):
    why_org_human_readable[wid] = {
        (qid, looked_up_org.get(qid))
        for qid in inst_of_set
    }
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
why_org_counts = Counter()
for _, inst_of in why_org_human_readable.items():
    string_labels =  " & ".join([f"{name} ({qid})" or qid for qid, name in inst_of])
    why_org_counts[string_labels] += 1

# %%
why_org_counts.most_common()
# Out:
# [('clinical trial (Q30612)', 341753),
#  ('business (Q4830453)', 101372),
#  ('musical group (Q215380)', 71787),
#  ('rural school (Q19855165) & co-educational school (Q67383935) & primary school (Q9842)',
#   53663),
#  ('primary school (Q9842)', 49341),
#  ('commune of France (Q484170)', 39855),
#  ('business (Q4830453) & None (Q6881511)', 29996),
#  ('newspaper (Q11032)', 29836),
#  ('State Bank of India branch (Q65954115)', 25261),
#  ("Government Boys' Primary School (Q67015940)", 25058),
#  ('association football club (Q476028)', 24459),
#  ('kindergarten (Q126807)', 24186),
#  ('college (Q189004)', 23997),
#  ('radio station (Q14350)', 22823),
#  ('high school (Q9826)', 20351),
#  ('school (Q3914)', 19785),
#  ('None (Q33506)', 16895),
#  ('nonprofit organization (Q163740)', 15434),
#  ('hotel (Q27686)', 15317),
#  ('political party (Q7278)', 14411),
#  ('Gram panchayat (Q2732840)', 14019),
#  ('academic department (Q2467461)', 13258),
#  ('military unit (Q176799)', 12949),
#  ('dissolved municipality of Japan (Q18663566)', 12764),
#  ('pub (Q212198)', 12235),
#  ('health sub-centre (Q61278455)', 10891),
#  ('public library (Q28564)', 10538),
#  ('government agency (Q327333)', 9599),
#  ('university (Q3918)', 9081),
#  ('hospital (Q16917)', 9073),
#  ('library network (Q26271642)', 8880),
#  ('middle school (Q149566)', 8741),
#  ('official journal (Q2065227)', 8325),
#  ('record label (Q18127)', 7987),
#  ('secondary school (Q159334)', 7767),
#  ('municipality of Germany (Q262166)', 7666),
#  ('research institute (Q31855)', 7580),
#  ('company (Q783794)', 7460),
#  ('city of the United States (Q1093829)', 7415),
#  ('commune of Italy (Q747074)', 7391),
#  ('lower secondary school (Q57775518)', 7373),
#  ('public library (Q28564) & library branch (Q11396180)', 7078),
#  ('embassy (Q3917681)', 7065),
#  ('sports club (Q847017)', 7015),
#  ('project (Q170584)', 6679),
#  ('public library (Q28564) & main library (Q12317349)', 6607),
#  ('archive (Q166118)', 6385),
#  ('None (Q2085381)', 6272),
#  ('municipality of Spain (Q2074737)', 6115),
#  ('school district (Q398141)', 6080),
#  ('urban school (Q67388747) & co-educational school (Q67383935) & primary school (Q9842)',
#   6055),
#  ('academic institution (Q4671277)', 5988),
#  ('Canara Bank branch (Q65954144)', 5914),
#  ('primary school (Q9842) & community school (Q5155053)', 5843),
#  ('monastery (Q44613)', 5729),
#  ('television station (Q1616075)', 5184),
#  ('ICICI Bank branch (Q65954135)', 5170),
#  ('academy school (Q4671329) & primary school (Q9842)', 5165),
#  ('municipality of the Czech Republic (Q5153359)', 5146),
#  ("Government Girls' Primary School (Q67015944)", 5059),
#  ('Bank of Baroda branch (Q65954142)', 5050),
#  ('None (Q3184121)', 5009),
#  ('HDFC Bank branch (Q66619497)', 4894),
#  ('istituto comprensivo (Q56177191)', 4791),
#  ('town of the United States (Q15127012)', 4708),
#  ('rural school (Q19855165) & co-educational school (Q67383935) & upper primary school (Q64063386)',
#   4663),
#  ('faculty (Q180958)', 4608),
#  ('Central Bank of India branch (Q73580208)', 4546),
#  ('public company (Q891723) & business (Q4830453)', 4402),
#  ('airline (Q46970)', 4390),
#  ('Olympic delegation (Q26213387)', 4362),
#  ('political coalition (Q6138528)', 4347),
#  ('lower primary school (Q64063317)', 4209),
#  ('educational institution (Q2385804)', 4105),
#  ('noble family (Q13417114)', 4071),
#  ('Axis Bank branch (Q65954138)', 4058),
#  ('scientific conference series (Q47258130)', 4012),
#  ('hydroelectric power station (Q15911738)', 3840),
#  ('medical organization (Q4287745)', 3788),
#  ('digital collection (Q60474998)', 3720),
#  ('wat (Q427287)', 3681),
#  ('library (Q7075)', 3560),
#  ('research project (Q1298668) & research grant (Q54875403)', 3554),
#  ('Buddhist temple (Q5393308)', 3520),
#  ('co-educational school (Q67383935) & higher secondary school (Q64062731) & rural school (Q19855165)',
#   3509),
#  ('medical organization (Q4287745) & hospital (Q16917)', 3481),
#  ('rural settlement of Russia (Q634099)', 3312),
#  ('Indian Overseas Bank branch (Q73839412)', 3205),
#  ('restaurant (Q11707)', 3200),
#  ('open-access publisher (Q45400320)', 3159),
#  ('video game developer (Q210167)', 3156),
#  ('Yes Bank branch (Q65954125)', 3080),
#  ('foundation (Q157031)', 3079),
#  ('sports league (Q623109)', 3023),
#  ('Allahabad Bank branch (Q69529214)', 3004),
#  ('ice hockey team (Q4498974)', 2997),
#  ('concentration camp (Q152081)', 2968),
#  ('Tibetan Buddhist monastery (Q54074585)', 2952),
#  ('Shinto shrine (Q845945)', 2951),
#  ('WikiProject (Q16695773)', 2895),
#  ('national sports team (Q1194951)', 2852),
#  ('high school (Q9826) & state school (Q1080794)', 2849),
#  ('basketball team (Q13393265)', 2843),
#  ('Union Bank of India branch (Q71713967)', 2818),
#  ('musical ensemble (Q2088357)', 2797),
#  ('elite national cycling team (Q23726798)', 2772),
#  ('bookstore (Q200764)', 2749),
#  ('parish (Q102496)', 2734),
#  ('Andhra Bank branch (Q66496996)', 2703),
#  ('Indian Bank branch (Q73986959)', 2678),
#  ('freguesia of Portugal (Q1131296)', 2671),
#  ('municipality of Hungary (Q2590631)', 2668),
#  ('None (Q207694)', 2659),
#  ('None (Q6881511)', 2656),
#  ('Industrial Development Bank of India branch (Q73717181)', 2643),
#  ('municipality of Slovakia (Q6784672)', 2614),
#  ('istituto tecnico (Q3803834)', 2613),
#  ('voluntary association (Q48204)', 2609),
#  ('association (Q15911314)', 2599),
#  ('voluntary aided school (Q7940971) & primary school (Q9842)', 2573),
#  ('political organization (Q7210356)', 2517),
#  ('UCO Bank branch (Q66877717)', 2507),
#  ('automobile manufacturer (Q786820)', 2466),
#  ('synagogue (Q34627)', 2457),
#  ('parish council (Q7137435)', 2389),
#  ('architectural firm (Q4387609)', 2366),
#  ('Corporation Bank branch (Q66768699)', 2349),
#  ('upper primary school (Q64063386)', 2340),
#  ('village in the United States (Q751708)', 2332),
#  ('sports team (Q12973014)', 2317),
#  ('labor union (Q178790)', 2316),
#  ('film production company (Q1762059)', 2315),
#  ('baseball team (Q13027888)', 2277),
#  ('Bank of India branch (Q66576265)', 2272),
#  ('engineering school (Q1663017)', 2250),
#  ('delegated commune (Q21869758) & commune of France (Q484170)', 2250),
#  ('prison (Q40357)', 2227),
#  ('rock group (Q5741069)', 2178),
#  ('business school (Q1143635)', 2142),
#  ('public company (Q891723)', 2107),
#  ('sports governing body (Q2485448)', 2086),
#  ('municipality of Mexico (Q1952852)', 2058),
#  ('factory (Q83405)', 2039),
#  ('parish of Denmark (Q814648)', 2039),
#  ('inn (Q256020)', 2038),
#  ('professional institute (Q3803808)', 2035),
#  ('preschool (Q1076052)', 2019),
#  ('theatre troupe (Q2416217)', 1998),
#  ('campus (Q209465)', 1993),
#  ('destroyer (Q174736)', 1979),
#  ('Paralympics delegation (Q46195901)', 1885),
#  ('lower primary school (Q64063317) & aided school (Q86989588)', 1873),
#  ('United Bank of India branch (Q71574305)', 1855),
#  ('municipality of Switzerland (Q70208)', 1854),
#  ('Syndicate Bank branch (Q73865589)', 1851),
#  ('secondary school (Q159334) & co-educational school (Q67383935) & rural school (Q19855165)',
#   1849),
#  ('diocese of the Catholic Church (Q3146899)', 1808),
#  ('plantation (Q188913)', 1799),
#  ('Bank of Maharashtra branch (Q70081950)', 1782),
#  ('brewery (Q131734)', 1779),
#  ('botanical garden (Q167346)', 1759),
#  ('nation at the World Championships in Athletics (Q35823051)', 1753),
#  ('public company (Q891723) & business (Q4830453) & None (Q6881511)', 1740),
#  ('None (Q5526694)', 1716),
#  ('bodendenkmal (Q22969563)', 1708),
#  ('locality (Q3257686) & freguesia of Portugal (Q1131296)', 1693),
#  ('musical duo (Q9212979)', 1681),
#  ('voluntary controlled school (Q7940973) & primary school (Q9842)', 1666),
#  ('Kotak Mahindra Bank branch (Q74539826)', 1638),
#  ('Dena Bank branch (Q66771621)', 1622),
#  ('theatre company (Q11812394)', 1590),
#  ('convent (Q1128397)', 1579),
#  ('Dutch municipal council (Q17014622)', 1566),
#  ('abbey (Q160742)', 1564),
#  ('Candomblé terreiro (Q3208559)', 1561),
#  ('bus company (Q10438042)', 1558),
#  ('Indian reservation of Canada (Q155239)', 1534),
#  ('lower primary school (Q64063317) & state school (Q1080794)', 1532),
#  ('container ship (Q17210)', 1496),
#  ('zoo (Q43501)', 1490),
#  ('historical society (Q5774403)', 1482),
#  ('geographic township of Quebec (Q23019040)', 1475),
#  ('municipal archive (Q604177)', 1475),
#  ('transport company (Q740752)', 1474),
#  ('rural municipality of Poland (Q3504085)', 1468),
#  ('secondary school (Q159334) & academy school (Q4671329)', 1457),
#  ('university and college sports club (Q2367225)', 1454),
#  ('municipality of the Philippines (Q24764)', 1434),
#  ('railway company (Q249556)', 1425),
#  ('None (Q53534649) & UCI Continental Team (Q1756006)', 1417),
#  ('commune of Algeria (Q2989398)', 1409),
#  ('U-boat (Q428661)', 1378),
#  ('Oriental Bank of Commerce branch (Q73887153)', 1365),
#  ('orchestra (Q42998)', 1359),
#  ('squadron (Q679165)', 1353),
#  ('sports tour (Q50846468)', 1323),
#  ('None (Q7315155)', 1323),
#  ('municipality (Q15284)', 1321),
#  ('Welsh-medium school (Q13132631)', 1318),
#  ('bulk carrier (Q15276)', 1314),
#  ('academic library (Q856234)', 1277),
#  ('non-governmental organization (Q79913)', 1269),
#  ('None (Q10648343)', 1267),
#  ('titular see (Q15217609)', 1258),
#  ('daily newspaper (Q1110794)', 1231),
#  ('Federal Bank branch (Q72984778)', 1229),
#  ('theatrical troupe (Q742421)', 1229),
#  ('pub (Q212198) & inn (Q256020)', 1226),
#  ('kindergarten (Q126807) & primary school (Q9842)', 1211),
#  ('learned society (Q955824)', 1191),
#  ('filial church (Q1129743)', 1186),
#  ('municipality of Austria (Q667509) & rural municipality of Austria (Q1802801)',
#   1181),
#  ('laboratory (Q483242)', 1178),
#  ('subcommittee of a technical committee (Q55454947)', 1148),
#  ('rugby union team (Q14645593)', 1145),
#  ('Vijaya Bank branch (Q66538936)', 1144),
#  ('independent school (Q2418495)', 1128),
#  ('Narrenzunft (Q1965390)', 1122),
#  ('privately held company (Q1589009)', 1119),
#  ('institute (Q1664720)', 1113),
#  ('medical school (Q494230)', 1113),
#  ('government organization (Q2659904)', 1112),
#  ('Pragathi Krishna Gramin Bank branch (Q75804428)', 1097),
#  ('historical country (Q3024240)', 1081),
#  ('art gallery (Q1007870)', 1080),
#  ('None (Q1187691)', 1070),
#  ('None (Q615980)', 1065),
#  ('aircraft fleet (Q1875630)', 1061),
#  ('priory (Q2750108)', 1051),
#  ('charitable organization (Q708676)', 1050),
#  ('higher secondary school (Q64062731)', 1049),
#  ('American football team (Q17156793)', 1042),
#  ('hospital (Q16917) & former hospital (Q64578911)', 1039),
#  ('municipality of Colombia (Q2555896)', 1021),
#  ('historical society (Q5774403) & nonprofit organization (Q163740)', 1020),
#  ("Government Boys' High School (Q67015947)", 1007),
#  ('None (Q3831968)', 1006),
#  ('None (Q6979593)', 1006),
#  ('ski resort (Q130003)', 1000),
#  ('order (Q193622)', 990),
#  ('choir (Q131186)', 988),
#  ('Public institution of intermunicipal cooperation with own taxation (Q18706073)',
#   972),
#  ('coal-fired power station (Q6558431)', 966),
#  ('college sports team (Q18558301) & basketball team (Q13393265)', 965),
#  ('association football league (Q15991303)', 963),
#  ('primary health centre (Q7243073)', 955),
#  ('Jammu & Kashmir Bank branch (Q75543355)', 953),
#  ('higher education institution (Q38723)', 946),
#  ('aided school (Q86989588) & upper primary school (Q64063386)', 943),
#  ('county seat (Q62049) & city of the United States (Q1093829)', 936),
#  ('broadcaster (Q15265344)', 929),
#  ('regiment (Q52371)', 928),
#  ('division (Q169534)', 923),
#  ('Punjab and Sind Bank branch (Q75151507)', 923),
#  ('vocational school in Indonesia (Q12513144)', 905),
#  ('smack (Q382586) & shipwreck (Q852190)', 901),
#  ('cultural institution (Q3152824)', 899),
#  ('South Indian Bank branch (Q67646671)', 894),
#  ('municipality of Catalonia (Q33146843)', 881),
#  ('urban municipality of Germany (Q42744322)', 877),
#  ('preschool (Q1076052) & primary school (Q9842)', 870),
#  ('secondary school (Q159334) & high school (Q9826)', 868),
#  ('amusement park (Q194195)', 865),
#  ('historical motorcycle manufacturer (Q15081032)', 861),
#  ('borough of Pennsylvania (Q777120)', 856),
#  ('school district in the United States (Q15726209)', 847),
#  ('primary school (Q9842) & state school (Q1080794)', 838),
#  ("Government Boys' Lower Secondary School (Q67015942)", 817),
#  ('town of the United States (Q15127012) & town of New York (Q106071004)',
#   809),
#  ('cricket team (Q17376093)', 809),
#  ('law enforcement agency (Q732717)', 808),
#  ('research project (Q1298668)', 798),
#  ('Karnataka Bank Limited branch (Q66789788)', 798),
#  ('stock exchange (Q11691)', 791),
#  ('commune of Morocco (Q2989400) & rural commune of Morocco (Q17318027)', 787),
#  ('law school (Q1321960)', 781),
#  ('winery (Q156362)', 773),
#  ('Chitalishte (Q1638962)', 772),
#  ('Ortsteil (Q253019) & municipality of Germany (Q262166)', 772),
#  ('municipality of the Netherlands (Q2039348)', 770),
#  ('Christian denomination (Q879146)', 755),
#  ('shipyard (Q190928)', 752),
#  ('cabinet (Q640506)', 745),
#  ('elementary school in Japan (Q5358913)', 737),
#  ('advisory group (Q23722468)', 736),
#  ('None (Q10517054)', 734),
#  ('Andhra Pradesh Grameena Vikas Bank branch (Q69981114)', 733),
#  ('school (Q3914) & primary school (Q9842) & state school (Q1080794)', 727),
#  ('Karur Vysya Bank branch (Q67994584)', 719),
#  ('None (Q1329623)', 702),
#  ('federal electoral district of Canada (Q17202187)', 701),
#  ('public library (Q28564) & library (Q7075)', 701),
#  ('cargo ship (Q105999)', 696),
#  ('auto racing team (Q20074337)', 693),
#  ('school for special needs education (Q28935764)', 690),
#  ('tram system (Q15640053)', 682),
#  ('frigate (Q161705)', 680),
#  ('Rajasthan Marudhara Gramin Bank branch (Q75793280)', 679),
#  ('bank (Q22687)', 675),
#  ('photographic studio (Q672070)', 674),
#  ('community college (Q1336920)', 672),
#  ('book publisher (Q1320047) & None (Q2085381)', 667),
#  ('market municipality (Q562061) & municipality of Austria (Q667509)', 665),
#  ('astronomical observatory (Q1254933)', 663),
#  ('artist collective (Q1400264)', 661),
#  ('wind farm (Q194356)', 661),
#  ('town council (Q3507268)', 660),
#  ('tenement (Q1078374) & shop (Q213441)', 657),
#  ('ministry (Q192350)', 653),
#  ('Japanese upper secondary school (Q56351315)', 652),
#  ('gymnasium (Q55043)', 649),
#  ('municipal library (Q2326815)', 644),
#  ('scientific society (Q748019)', 642),
#  ('private university (Q902104)', 642),
#  ('commune of Mali (Q1758856)', 635),
#  ('rowing club (Q7372078)', 632),
#  ('subdistrict administrative organization (Q15140073)', 625),
#  ('local museum (Q1595639)', 624),
#  ('municipality of Croatia (Q57058)', 622),
#  ('Kerala Gramin Bank branch (Q68000128)', 622),
#  ('City Union Bank Limited branch (Q73634133)', 622),
#  ('sports organization (Q4438121)', 619),
#  ('municipality of Japan (Q1054813) & town of Japan (Q1059478)', 616),
#  ('boarding school (Q269770)', 613),
#  ('public library (Q28564) & library building (Q856584)', 607),
#  ("women's association football team (Q28140340)", 604),
#  ('pressure group (Q1666019)', 602),
#  ('Bandhan Bank branch (Q69739777)', 599),
#  ('club cycling team (Q20639848)', 598),
#  ('None (Q133311)', 596),
#  ('club (Q988108)', 593),
#  ('urban-rural municipality of Poland (Q3491915)', 591),
#  ('theatrical troupe (Q742421) & theatre company (Q11812394)', 589),
#  ('under-23 national cycling team (Q20738667)', 588),
#  ('municipality (Q27676428)', 585),
#  ('volleyball team (Q15720476)', 584),
#  ('trade association (Q2178147)', 575),
#  ('consulate general (Q372690)', 566),
#  ('Permanent Territorial Center (Q52017007)', 564),
#  ('military decoration (Q1788716)', 563),
#  ('shop (Q213441)', 563),
#  ('printer (Q6500733)', 560),
#  ('nursing school (Q446901)', 556),
#  ('power station (Q159719)', 555),
#  ('ecclesiastical province (Q625160)', 551),
#  ('NHS trust (Q6954197)', 550),
#  ('Lakshmi Vilas Bank branch (Q74784444)', 550),
#  ('unicameral legislature (Q37002670)', 545),
#  ('art school (Q383092)', 541),
#  ('international organization (Q484652)', 539),
#  ('Ujjivan Small Finance Bank branch (Q75694364)', 538),
#  ('Formula One team (Q10497835)', 537),
#  ('seminary (Q233324)', 535),
#  ('college sports team (Q18558301) & baseball team (Q13027888)', 534),
#  ('associated commune (Q666943) & commune of France (Q484170)', 534),
#  ('foundation school (Q5474524) & primary school (Q9842)', 534),
#  ('tanker ship (Q14970)', 532),
#  ('Gymnasium in Germany (Q1542966)', 528),
#  ('advocacy group (Q431603)', 525),
#  ('urban school (Q67388747) & co-educational school (Q67383935) & higher secondary school (Q64062731)',
#   523),
#  ('law firm (Q613142)', 520),
#  ('Andhra Pragathi Grameena Bank branch (Q66495884)', 520),
#  ('tank landing ship (Q11229656)', 515),
#  ('broadcast network (Q141683)', 515),
#  ('sibling duo (Q14073567)', 514),
#  ('business (Q4830453) & bank (Q22687)', 512),
#  ('German noble family (Q61881926) & family (Q8436)', 512),
#  ('book publisher (Q1320047)', 508),
#  ('dynasty (Q164950)', 506),
#  ('school building (Q1244442) & school (Q3914)', 506),
#  ('order of battle (Q11167066)', 501),
#  ('Tamilnad Mercantile Bank branch (Q75095923)', 500),
#  ('municipality of Poland (Q15334) & None (Q515)', 499),
#  ('clubhouse (Q1103285)', 496),
#  ('medical facility (Q4260475) & hospital (Q16917)', 496),
#  ('former municipality of Switzerland (Q685309) & municipality of Switzerland (Q70208)',
#   495),
#  ('college sports team (Q18558301) & association football team (Q15944511)',
#   488),
#  ('public library (Q28564) & bookmobile (Q720920)', 488),
#  ('village (Q532) & former municipality of Switzerland (Q685309) & municipality of Switzerland (Q70208)',
#   488),
#  ("Government Girls' High School (Q67015950)", 486),
#  ('aided school (Q86989588) & high school (Q9826)', 485),
#  ('corporation (Q167037)', 477),
#  ('college sports team (Q18558301) & American football team (Q17156793)', 475),
#  ('liceo classico (Q5518)', 474),
#  ('restaurant chain (Q18534542)', 473),
#  ('First Nation band (Q2882257)', 470),
#  ('brigantine (Q189418) & shipwreck (Q852190)', 469),
#  ('golf club (Q2022036)', 469),
#  ('business (Q4830453) & tradesperson (Q2588761)', 469),
#  ('association football team (Q15944511)', 466),
#  ('legislature (Q11204)', 465),
#  ('athletic conference (Q2992826)', 465),
#  ('None (Q105390172)', 464),
#  ('state school (Q1080794)', 462),
#  ('clinic (Q1774898)', 458),
#  ('punk band (Q25391823)', 458),
#  ('archaeological museum (Q3329412)', 458),
#  ('destroyer escort (Q1499623)', 457),
#  ('Karnataka Vikas Grameena Bank branch (Q74511437)', 457),
#  ('han system (Q841985)', 457),
#  ('historic house museum (Q2087181)', 455),
#  ('retail chain (Q507619)', 455),
#  ('urban school (Q67388747) & None (Q22713629) & higher secondary school (Q64062731)',
#   454),
#  ('film studio (Q375336)', 452),
#  ('university (Q3918) & open-access publisher (Q45400320)', 452),
#  ('city of Japan (Q494721)', 452),
#  ('None (Q1002697) & newspaper (Q11032)', 448),
#  ('former municipality of Norway (Q18663579)', 448),
#  ('student society (Q1685451)', 447),
#  ('dot-com company (Q1194970)', 443),
#  ('rural municipality of Canada (Q3327874)', 442),
#  ('Kaveri Grameena Bank branch (Q67990452)', 440),
#  ('New England town (Q2154459)', 439),
#  ('Indian Postal division (Q63676827)', 439),
#  ('rural library (Q30032094)', 438),
#  ('state school (Q1080794) & upper primary school (Q64063386)', 435),
#  ('mixed research unit (Q3550864)', 435),
#  ('committee (Q865588)', 434),
#  ('department store (Q216107)', 433),
#  ('military museum (Q2772772)', 432),
#  ('religious organization (Q1530022)', 431),
#  ("None (Q53534649) & UCI Women's Team (Q2466826)", 429),
#  ('Linux distribution (Q131669)', 427),
#  ('Catholic Syrian Bank branch (Q74666911)', 426),
#  ('summary court (Q11603901)', 424),
#  ('cruise ship (Q39804)', 423),
#  ('library branch (Q11396180)', 419),
#  ('junior national cycling team (Q54555994)', 419),
#  ('rural commune of Morocco (Q17318027)', 418),
#  ('None (Q22713629) & secondary school (Q159334) & rural school (Q19855165)',
#   413),
#  ('subdistrict municipality (Q15141625) & Sukhaphiban (Q7635776)', 412),
#  ('girl group (Q641066)', 411),
#  ('designated place of Canada (Q956318)', 410),
#  ('None (Q829080)', 409),
#  ('video game publisher (Q1137109) & video game developer (Q210167)', 408),
#  ('None (Q493522)', 408),
#  ('art collection (Q7328910)', 408),
#  ('regulatory college (Q1110684)', 407),
#  ('None (Q69398687)', 407),
#  ('junta de freguesia (Q10313003)', 406),
#  ('ship (Q11446) & mixed cargo ship (Q1752434)', 406),
#  ("Government Girls' Lower Secondary School (Q67015949)", 406),
#  ('performing arts group (Q105815710)', 404),
#  ('market (Q132510)', 404),
#  ('masonic temple (Q1454583)', 403),
#  ('fire department (Q6498663)', 403),
#  ('independent record label (Q1542343)', 402),
#  ('municipality of Venezuela (Q3327920)', 399),
#  ('civic society (Q5124370)', 399),
#  ('day care (Q364005)', 398),
#  ('business (Q4830453) & brand (Q431289)', 394),
#  ('executive branch (Q35798)', 392),
#  ('art gallery (Q1007870) & business (Q4830453)', 390),
#  ('corvette (Q170013)', 390),
#  ('weekly newspaper (Q2305295)', 388),
#  ('ferry route (Q18984099)', 387),
#  ('The Andhra Pradesh State Cooperative Bank Limited branch (Q74503693)', 387),
#  ('golf club (Q2022036) & golf course (Q1048525)', 386),
#  ('None (Q22713629) & higher secondary school (Q64062731) & rural school (Q19855165)',
#   382),
#  ('deanery (Q385337)', 382),
#  ('business (Q4830453) & colonial society (Q1700154)', 381),
#  ('Utkarsh Small Finance Bank branch (Q66497314)', 381),
#  ('Australian rules football club (Q17374546)', 380),
#  ('national basketball team (Q46351685)', 378),
#  ('town of Portugal (Q19833170) & freguesia of Portugal (Q1131296)', 374),
#  ('None (Q2738074)', 373),
#  ('infantry regiment (Q10358588)', 372),
#  ('religious institute (Q5135744)', 371),
#  ('academy school (Q4671329)', 370),
#  ('open-air museum (Q756102)', 369),
#  ('facility (Q13226383) & research institute (Q31855)', 369),
#  ('recording studio (Q746369)', 369),
#  ('bakehouse (Q798436)', 369),
#  ('primary art school (Q10861807)', 367),
#  ('IDFC FIRST Bank branch (Q75676665)', 366),
#  ('monastery (Q44613) & bodendenkmal (Q22969563)', 363),
#  ('urban okrug in Russia (Q13626398)', 363),
#  ('think tank (Q155271)', 362),
#  ('rural school (Q19855165) & None (Q22713629) & upper primary school (Q64063386)',
#   362),
#  ('government (Q7188)', 361),
#  ("urban school (Q67388747) & boys' school (Q1713379) & higher secondary school (Q64062731)",
#   359),
#  ('resort (Q875157)', 358),
#  ('village of Wisconsin (Q15221242)', 358),
#  ('clan (Q211503)', 358),
#  ('aerospace manufacturer (Q936518)', 358),
#  ('coffeehouse (Q30022)', 356),
#  ('UCI Continental Team (Q1756006)', 355),
#  ('village of New York (Q55237813) & village in the United States (Q751708)',
#   353),
#  ('roadside rest area (Q785979)', 353),
#  ('daily newspaper (Q1110794) & newspaper (Q11032)', 352),
#  ('departmental unit (Q105536562)', 350),
#  ('cooperative bank (Q3277997)', 349),
#  ('Roman Catholic Maintained school (Q105416219) & primary school (Q9842)',
#   348),
#  ('rural council of Ukraine (Q4414033)', 348),
#  ('Controlled School (Q105416218) & primary school (Q9842)', 347),
#  ('nuclear power plant (Q134447)', 347),
#  ('commercial organization (Q21980538)', 347),
#  ('animation studio (Q1107679)', 346),
#  ('online newspaper (Q1153191)', 346),
#  ('diocese (Q665487)', 346),
#  ('pub (Q212198) & hotel (Q27686)', 345),
#  ('television production company (Q10689397)', 344),
#  ('rugby league team (Q15221215)', 344),
#  ('specialty channel (Q561068)', 343),
#  ('municipality of Norway (Q755707)', 339),
#  ('combined school (Q5150914) & primary school (Q9842)', 338),
#  ('None (Q100341898)', 336),
#  ('attack submarine (Q4818021)', 333),
#  ('ancient city (Q15661340) & polis (Q148837)', 331),
#  ('supermarket chain (Q18043413)', 331),
#  ('former municipality (Q19730508)', 331),
#  ('building (Q41176) & None (Q33506)', 331),
#  ('college sports team (Q18558301)', 330),
#  ('RBL Bank Limited branch (Q74983768)', 329),
#  ('municipality of Greece (Q1349648)', 328),
#  ('public educational institution of the United States (Q23002039) & university (Q3918)',
#   326),
#  ('imprint (Q2608849)', 325),
#  ('run-of-the-river power station (Q1411996)', 324),
#  ('lycée (Q2511322)', 324),
#  ('municipality of Georgia (Q76514543) & city of the United States (Q1093829)',
#   323),
#  ('research group (Q1241025)', 322),
#  ('Lost Roman Catholic diocese (Q27780831)', 319),
#  ('video game publisher (Q1137109)', 318),
#  ('urban school (Q67388747) & None (Q22713629) & secondary school (Q159334)',
#   318),
#  ('police (Q35535)', 318),
#  ('DCB Bank branch (Q76513673)', 317),
#  ('TEDx talk (Q23058953)', 316),
#  ('human settlement (Q486972) & moshav (Q917146)', 316),
#  ('junior college (Q370258)', 315),
#  ('association football club (Q476028) & association football team (Q15944511)',
#   315),
#  ('battalion (Q6382533)', 315),
#  ('None (Q875538)', 315),
#  ('Cooperative Science and Research Body (Q11507944)', 314),
#  ('art group (Q4502119)', 313),
#  ('software company (Q1058914)', 311),
#  ('multi-sport club (Q13580678)', 310),
#  ('dance troupe (Q2393314)', 310),
#  ('motorcycle racing team (Q20784907)', 309),
#  ('association under the French law of 1901 (Q11513034)', 306),
#  ('General Service Area (Q5532181)', 306),
#  ('human settlement (Q486972) & town of the United States (Q15127012)', 305),
#  ('working group (Q27493)', 305),
#  ("Government Boys' Elementary School (Q67015946)", 305),
#  ('photovoltaic power station (Q1003207)', 304),
#  ('The West Bengal State Cooperative Bank Limited branch (Q68004858)', 304),
#  ('production company (Q11396960)', 303),
#  ('village (Q532) & populated place in the Netherlands (Q1852859) & municipality of the Netherlands (Q2039348)',
#   303),
#  ('private not-for-profit educational institution (Q23002054) & university (Q3918)',
#   303),
#  ('brigade (Q102356)', 302),
#  ('None (Q53534649) & None (Q20639847)', 301),
#  ('house of culture (Q5061188)', 301),
#  ('subsidiary (Q658255)', 301),
#  ('high commission (Q18414273)', 300),
#  ('state forest (Q2324919)', 300),
#  ('Eastern Orthodox eparchy (Q60176300)', 300),
#  ('None (Q14752149)', 299),
#  ('municipality of Guatemala (Q1872284)', 299),
#  ('community center (Q77115)', 298),
#  ('community council (Q3403338)', 297),
#  ('Amt (Q478847)', 297),
#  ('secondary school (Q159334) & community school (Q5155053)', 292),
#  ('faculty of pharmacy (Q62129701)', 292),
#  ('court (Q41487)', 291),
#  ('municipal council in Finland (Q191893)', 288),
#  ('military academy (Q917182)', 288),
#  ('motorcycle manufacturer (Q15081030)', 287),
#  ('rest area (Q786014)', 285),
#  ('town in Hungary (Q13218690)', 284),
#  ('bar association (Q1865205)', 284),
#  ('county-level city (Q1070990)', 283),
#  ('None (Q51792175)', 281),
#  ('Wehrmacht infantry division (Q828569)', 281),
#  ('higher secondary school (Q64062731) & state school (Q1080794)', 279),
#  ('Wikipedia language edition (Q10876391)', 279),
#  ('municipality of Sweden (Q127448)', 278),
#  ('business (Q4830453) & company (Q783794)', 278),
#  ('business (Q4830453) & photographic studio (Q672070)', 276),
#  ('public hospital (Q7257872)', 276),
#  ("doctor's office (Q718966)", 275),
#  ('double act (Q1141470)', 274),
#  ('urban school (Q67388747) & secondary school (Q159334) & co-educational school (Q67383935)',
#   274),
#  ('boarding school (Q269770) & independent school (Q2418495)', 274),
#  ('vocational school (Q322563)', 274),
#  ('heritage railway (Q420962)', 271),
#  ('Jana Small Finance Bank branch (Q75109089)', 270),
#  ('boy band (Q216337)', 269),
#  ('business (Q4830453) & None (Q2085381)', 268),
#  ('string quartet (Q207338)', 267),
#  ('big city (Q1549591) & None (Q3184121)', 267),
#  ('subdistrict municipality (Q15141625) & subdistrict administrative organization (Q15140073)',
#   266),
#  ('municipality of Tunisia (Q41067667)', 266),
#  ('Local court (Q480477)', 266),
#  ('umbrella organization (Q1156831)', 265),
#  ('environmental organization (Q1785733)', 265),
#  ('Wikimedia multilingual project main page (Q21450877)', 265),
#  ('public company (Q891723) & company (Q783794)', 264),
#  ('history museum (Q16735822)', 263),
#  ('water park (Q740326)', 262),
#  ('None (Q53534649) & UCI Professional Continental Team (Q382927)', 262),
#  ('сhurch college (Q1743327)', 260),
#  ('town (Q44529188)', 260),
#  ('commune of Chile (Q1840161)', 259),
#  ('None (Q20639847)', 259),
#  ('nightclub (Q622425)', 259),
#  ('public library (Q28564) & library network (Q26271642)', 257),
#  ('medical facility (Q4260475)', 257),
#  ('tag team (Q1066670)', 253),
#  ('municipality of Bulgaria (Q1906268)', 253),
#  ('passenger ship (Q2055880)', 253),
#  ('state-owned enterprise (Q270791)', 253),
#  ('transit district (Q7835189)', 253),
#  ('youth wing (Q8059357)', 253),
#  ('psychiatric hospital (Q210999)', 252),
#  ('Communal Council (Q29385989)', 252),
#  ('television network (Q1254874)', 251),
#  ('locality (Q3257686) & municipality (Q15284)', 251),
#  ('NHS primary care trust (Q6954191)', 250),
#  ('scholarly article (Q13442814) & clinical trial (Q30612)', 248),
#  ('township of New Jersey (Q7830213)', 248),
#  ('village in Saskatchewan (Q20538317)', 246),
#  ('community health center (Q569500)', 246),
#  ('schooner (Q204577) & merchant vessel (Q848944)', 244),
#  ('holding company (Q219577)', 243),
#  ('municipality of El Salvador (Q3556889)', 240),
#  ('commission (Q55657615)', 240),
#  ('whisky distillery (Q10373548)', 239),
#  ('municipality of Bolivia (Q1062710)', 239),
#  ('charitable organization (Q708676) & nonprofit organization (Q163740)', 239),
#  ('conservatory (Q184644)', 239),
#  ('consumer cooperative (Q614084)', 237),
#  ('local municipality (Q1500352)', 235),
#  ('minesweeper (Q202527)', 235),
#  ('corps (Q188497)', 234),
#  ('building (Q41176) & hotel (Q27686)', 233),
#  ('business (Q4830453) & retail chain (Q507619)', 232),
#  ('lower secondary school in Japan (Q55521176)', 232),
#  ('Bon-gwan (Q846706)', 232),
#  ('regional park (Q6063204)', 231),
#  ('fraternity (Q18811582)', 231),
#  ('business (Q4830453) & website (Q35127)', 231),
#  ('armed forces (Q772547)', 231),
#  ('sculpture garden (Q1759852)', 230),
#  ('shipping line (Q1807108)', 229),
#  ('railway museum (Q18704634)', 229),
#  ('army (Q37726)', 229),
#  ('Sparkasse (Q13601825)', 228),
#  ('university (Q3918) & educational institution (Q2385804)', 228),
#  ('mint (Q464780)', 226),
#  ('yacht club (Q1855011)', 226),
#  ('shop (Q213441) & house (Q3947)', 226),
#  ('former municipality of Denmark (Q23036513)', 226),
#  ('university press (Q479716)', 225),
#  ('Gurgaon Gramin Bank Limited branch (Q70178190)', 225),
#  ('division (Q334453)', 224),
#  ('private hospital (Q4284971)', 224),
#  ('confraternity (Q992253)', 224),
#  ('princely state (Q1336152)', 223),
#  ('nation at the Mediterranean Games (Q26279994)', 223),
#  ('artistic duo (Q85942930)', 223),
#  ('research expedition (Q366301)', 222),
#  ('municipal corporation in India (Q6936225)', 221),
#  ('subprefecture in France (Q16481846)', 221),
#  ('amateur cycling team (Q26849121)', 221),
#  ('residential college (Q2680291)', 219),
#  ('student newspaper (Q738377) & newspaper (Q11032)', 218),
#  ('IndusInd Bank branch (Q68064251)', 218),
#  ('North Malabar Gramin Bank branch (Q75798241)', 218),
#  ('secondary school (Q159334) & state school (Q1080794)', 217),
#  ('former hospital (Q64578911)', 217),
#  ('urban settlement in Russia (Q2661988)', 216),
#  ('aviation museum (Q4828724)', 216),
#  ('bakery (Q274393)', 215),
#  ('městys (Q16155707) & municipality of the Czech Republic (Q5153359)', 214),
#  ('cinema chain (Q20679540)', 214),
#  ('None (Q33506) & real property (Q684740)', 214),
#  ('None (Q33506) & None (Q207694)', 213),
#  ('record company (Q2442401)', 213),
#  ('samba school (Q2641403)', 213),
#  ("girls' high school (Q17683170)", 212),
#  ('ayuntamiento (Spain) (Q22996476)', 212),
#  ('administrative region (Q3455524)', 212),
#  ('None (Q15734684)', 211),
#  ('municipality of Finland (Q856076) & None (Q17468533)', 211),
#  ('Himachal Pradesh State Cooperative Bank Limited branch (Q70188143)', 211),
#  ('light cruiser (Q778129)', 211),
#  ('electoral alliance (Q388602)', 210),
#  ('aided school (Q86989588) & higher secondary school (Q64062731)', 210),
#  ('former municipality (Q19730508) & None (Q1985797)', 209),
#  ('national cycling team (Q54660600)', 209),
#  ('main library (Q12317349)', 208),
#  ('municipal police (Q1758690)', 208),
#  ('former municipality of Estonia (Q26742250) & None (Q28122896)', 208),
#  ('morgue (Q6451172)', 208),
#  ('pharmacy (Q13107184)', 207),
#  ('thermal power station (Q200297)', 207),
#  ('herbarium (Q181916)', 207),
#  ('borough of New Jersey (Q2911266)', 207),
#  ('provincial electoral district of Quebec (Q2973931)', 207),
#  ('digital library (Q212805)', 206),
#  ('arts centre (Q2190251)', 206),
#  ('football club (Q17270000)', 205),
#  ('None (Q192283)', 205),
#  ('municipality with town privileges in the Czech Republic (Q15978299) & municipality of the Czech Republic (Q5153359)',
#   204),
#  ('observatory (Q62832)', 204),
#  ('Pupil Referral Unit (Q7260658)', 204),
#  ('architectural ensemble (Q1497375)', 203),
#  ('air force (Q61883)', 203),
#  ('National Olympic Committee (Q183288)', 202),
#  ('urban school (Q67388747) & None (Q22713629) & primary school (Q9842)', 201),
#  ('art gallery (Q1007870) & None (Q207694)', 199),
#  ('national library (Q22806)', 199),
#  ('council (Q4358176)', 199),
#  ('Clinical commissioning group (Q5133821)', 199),
#  ('postcard publisher (Q81529763)', 199),
#  ('arboretum (Q272231)', 198),
#  ('national museum (Q17431399)', 198),
#  ('water board in the Netherlands (Q702081)', 198),
#  ('national badminton team (Q29292775)', 198),
#  ('patrol vessel (Q331795)', 198),
#  ('None (Q3154693)', 197),
#  ('command (Q2008856)', 197),
#  ('musical ensemble (Q2088357) & musical group (Q215380)', 197),
#  ("women's national association football team (Q23905105)", 197),
#  ('photo agency (Q860572)', 197),
#  ('non-metropolitan district council (Q21561306)', 196),
#  ('professional society (Q1391145)', 196),
#  ('institution (Q178706)', 196),
#  ("women's association football club (Q51481377)", 196),
#  ('student newspaper (Q738377)', 196),
#  ('task force (Q1637368)', 195),
#  ('bar (Q187456)', 195),
#  ('one-room school (Q1308121)', 194),
#  ('political party in Spain (Q6065085)', 194),
#  ('cycling team (Q1785271)', 193),
#  ('private school (Q423208)', 193),
#  ('business (Q4830453) & brick and mortar (Q726870)', 193),
#  ('city of Oregon (Q63440326)', 193),
#  ('academy (Q162633)', 192),
#  ('rural hospital (Q61451856)', 192),
#  ('District health authority (Q16988796)', 191),
#  ('public educational institution of the United States (Q23002039)', 191),
#  ('business (Q4830453) & automobile manufacturer (Q786820)', 190),
#  ('suffragan diocese (Q373074) & Roman Catholic diocese (Q105388829)', 189),
#  ('middle school (Q149566) & school (Q3914)', 189),
#  ('None (Q16858213)', 189),
#  ('military unit (Q176799) & rifle division (Q4443691)', 189),
#  ('None (Q2616791)', 189),
#  ('provincial electoral district of Alberta (Q4711861)', 189),
#  ('college sports team (Q18558301) & tennis team (Q23900202)', 188),
#  ('municipality of Spain (Q2074737) & municipality of Galicia (Q2276925)',
#   188),
#  ('navy (Q4508)', 188),
#  ('apostolic nunciature (Q620045)', 188),
#  ('youth organization (Q1572070)', 187),
#  ('dental school (Q5259432)', 187),
#  ('rapid transit (Q5503)', 187),
#  ('None (Q78458396) & Passport to Your National Parks cancellation location (Q35989030)',
#   187),
#  ('polytechnic (Q845392)', 187),
#  ('infantry battalion (Q15704239)', 186),
#  ('maritime museum (Q1863818)', 186),
#  ('national archives (Q2122214)', 186),
#  ('foundry (Q13883136)', 185),
#  ('state agency of the United States (Q20857085) & government agency (Q327333)',
#   185),
#  ('village (Q532) & former municipality (Q19730508) & Ortsteil (Q253019)',
#   184),
#  ('symphony orchestra (Q239582)', 183),
#  ('consulate (Q7843791)', 182),
#  ('international sport governing body (Q11422536)', 181),
#  ('distillery (Q1251750)', 181),
#  ('pumped-storage power station (Q339353)', 179),
#  ('ocean liner (Q697196)', 179),
#  ('secondary school (Q159334) & school (Q3914) & academy school (Q4671329)',
#   178),
#  ('Verbandsgemeinde (Q23006)', 178),
#  ('department (Q2366457)', 178),
#  ('gas-fired power station (Q2944640)', 178),
#  ('infantry division (Q9248092)', 177),
#  ('business (Q4830453) & record label (Q18127)', 176),
#  ('assembly plant (Q47509284)', 176),
#  ('sports club (Q847017) & association football club (Q476028)', 176),
#  ('Scottish clan (Q499247)', 176),
#  ('liceo artistico (Q3831895)', 175),
#  ('Swedish noble family (Q61881575)', 175),
#  ('masonic lodge (Q1454597)', 174),
#  ('city or town (Q27676416)', 174),
#  ('institute of the Russian Academy of Sciences (Q4201890)', 174),
#  ('municipality of Finland (Q856076)', 174),
#  ('principality (Q208500)', 173),
#  ('battery (Q240313)', 173),
#  ('central bank (Q66344)', 173),
#  ('medical association (Q10729872)', 172),
#  ('expedition (Q2401485)', 172),
#  ('professional wrestling stable (Q25178247)', 172),
#  ('town (Q3957) & urban municipality of Germany (Q42744322)', 172),
#  ('open-access publisher (Q45400320) & None (Q875538)', 172),
#  ('bicycle-sharing system (Q1358919)', 171),
#  ('natural history museum (Q1970365)', 171),
#  ('abolished municipality in Italy (Q3685476)', 171),
#  ('school (Q3914) & high school (Q9826)', 171),
#  ('educational organization (Q5341295)', 171),
#  ('ward of Japan (Q137773)', 170),
#  ('religious congregation (Q1384677)', 170),
#  ('None (Q53534649) & UCI ProTeam (Q20638319)', 170),
#  ('village of Japan (Q4174776)', 170),
#  ('car carrier (Q356847)', 169),
#  ('replenishment oiler (Q162986)', 168),
#  ('municipality of Spain (Q2074737) & town (Q3957)', 168),
#  ('torpedo boat (Q324233)', 168),
#  ('human settlement (Q486972) & municipality of Lebanon (Q6936383) & village/town/city in Lebanon (Q23828039)',
#   168),
#  ('village in the United States (Q751708) & unincorporated community in the United States (Q17343829)',
#   168),
#  ('synod (Q111161)', 167),
#  ('media company (Q1331793)', 167),
#  ("college sports team (Q18558301) & basketball team (Q13393265) & NCAA Division I women's basketball team (Q54190181)",
#   167),
#  ('church congregation (Q2638480)', 167),
#  ("Government Boys' Higher Secondary School (Q67015952)", 167),
#  ('oil refinery (Q12353044)', 166),
#  ('Anglican diocese (Q18917976)', 166),
#  ('abolished municipality in Italy (Q3685476) & frazione (Q1134686)', 166),
#  ('statistical service (Q480242)', 166),
#  ('stirps (Q104258569)', 165),
#  ('archaeological site (Q839954)', 165),
#  ('Green party (Q3778417)', 165),
#  ('mixed cargo ship (Q1752434)', 164),
#  ('retail store (Q57334497)', 164),
#  ('grammar school (Q967098)', 164),
#  ('monastery (Q44613) & abbey (Q160742)', 163),
#  ('registered association (Q9299236)', 163),
#  ('college sports team (Q18558301) & softball team (Q82969709)', 161),
#  ('Wiktionary language edition (Q22001389)', 161),
#  ('container feeder ship (Q353699)', 161),
#  ('talent agency (Q5354754)', 161),
#  ('marching band (Q1426710)', 160),
#  ('biographical museum (Q10624527)', 159),
#  ('political faction (Q1393724)', 159),
#  ('None (Q5500295) & primary school (Q9842)', 159),
#  ('guided missile destroyer (Q2607934)', 158),
#  ('technical committee (Q55454831)', 158),
#  ('esports team (Q61974339)', 158),
#  ("students' union (Q877998)", 158),
#  ('religious order (Q2061186)', 157),
#  ('garrison (Q88556)', 157),
#  ('county park (Q5177940)', 156),
#  ('German Student Corps (Q14515311)', 156),
#  ('national statistical system (Q55456485)', 156),
#  ('financial institution (Q650241)', 156),
#  ('library consortium (Q6542557)', 156),
#  ('national futsal team (Q94696559)', 156),
#  ('working life museum (Q10416961)', 155),
#  ('research vessel (Q391022)', 155),
#  ('Davis Cup team (Q66817784)', 155),
#  ('municipality with town privileges in the Czech Republic (Q15978299) & municipality with authorized municipal office (Q7841907) & municipality of the Czech Republic (Q5153359)',
#   154),
#  ('swimming center (Q200023)', 154),
#  ('None (Q33506) & house (Q3947)', 154),
#  ('music school (Q1021290)', 153),
#  ('Carnegie library (Q1043939)', 153),
#  ('military school (Q1935049)', 153),
#  ('lower primary school (Q64063317) & unaided school (Q86991207)', 153),
#  ("Government Girls' Elementary School (Q67015953)", 153),
#  ('madrasa (Q132834)', 152),
#  ('terrorist organization (Q17127659)', 152),
#  ('supreme court (Q190752)', 152),
#  ("NCAA Division I women's basketball team (Q54190181)", 152),
#  ('None (Q588140)', 152),
#  ('honor society (Q9078534)', 152),
#  ('hromada (Q104841013)', 151),
#  ('middle school (Q149566) & state school (Q1080794)', 151),
#  ('hotel chain (Q1631129)', 151),
#  ('human settlement (Q486972) & Divisional Secretariat of Sri Lanka (Q1990968)',
#   151),
#  ('municipality of Angola (Q378508)', 151),
#  ('ministry (Q6866562)', 151),
#  ('pension (Q1065252)', 150),
#  ('magnetic observatory (Q1503257)', 150),
#  ('Canadian Indian residential school system (Q945507)', 150),
#  ('Catholic seminary (Q14911880)', 149),
#  ('Christian Church (Q34651)', 149),
#  ('intelligence agency (Q47913)', 149),
#  ('religious denomination (Q13414953)', 148),
#  ('agreed administrative community in Baden-Württemberg, Germany (Q1561418)',
#   148),
#  ('parliamentary group (Q848197)', 148),
#  ('school building (Q1244442) & high school (Q9826)', 148),
#  ('bodendenkmal (Q22969563) & cemetery (Q39614)', 147),
#  ('town of Portugal (Q19833170) & municipality of Portugal (Q13217644)', 147),
#  ('urban township of Minnesota (Q15063142)', 147),
#  ("urban school (Q67388747) & secondary school (Q159334) & boys' school (Q1713379)",
#   147),
#  ('juvenile political organization (Q2493450)', 147),
#  ('multi-level marketing company (Q29643579)', 147),
#  ('board of education (Q399541)', 147),
#  ('wing (Q45364)', 147),
#  ('onsen (Q655311)', 146),
#  ('armory (Q1412205)', 146),
#  ('rugby union club (Q43009164)', 146),
#  ('None (Q61451817)', 145),
#  ('local government (Q6501447)', 145),
#  ('town of the United States (Q15127012) & county seat (Q62049)', 144),
#  ('natural gas-fired power station (Q3498533)', 144),
#  ('Capital Small Finance Bank Limited branch (Q76383732)', 144),
#  ('specialty channel (Q561068) & television station (Q1616075)', 143),
#  ('university-preparatory school (Q428602)', 143),
#  ('Registration court (Q2138576) & Local court (Q480477)', 142),
#  ('unaided school (Q86991207) & high school (Q9826)', 142),
#  ('hall of fame (Q1046088)', 141),
#  ('hromada (Q104841013) & amalgamated hromada (Q4291381)', 141),
#  ('place with town rights and privileges (Q13539802) & municipality of Austria (Q667509)',
#   141),
#  ('sawmill (Q505213)', 141),
#  ('ulus (Q18632459)', 141),
#  ('ship of the line (Q207452)', 141),
#  ('private not-for-profit educational institution (Q23002054)', 141),
#  ("attempted coup d'état (Q25906438)", 141),
#  ('cultural organization (Q29918292)', 141),
#  ('Samtgemeinde (Q447523)', 141),
#  ('radio network (Q1061197)', 140),
#  ('consortium (Q194166)', 140),
#  ('Local Safeguarding Children Board (Q104605989)', 139),
#  ('landmark (Q2319498)', 139),
#  ('chamber of commerce (Q1123526)', 139),
#  ('school district of Canada (Q15726214)', 139),
#  ('school of education (Q2120173)', 139),
#  ('None (Q275186)', 139),
#  ('human settlement (Q486972) & kibbutz (Q161387)', 138),
#  ('battleship (Q182531)', 138),
#  ('federally recognized Native American tribe in the United States (Q7840353)',
#   137),
#  ('imprint (Q2608849) & record label (Q18127)', 137),
#  ('historic house museum (Q2087181) & English country house (Q1343246)', 137),
#  ('municipality of the Dominican Republic (Q6005581)', 137),
#  ('political campaign (Q847301)', 137),
#  ('Catholic parish (Q17143723)', 136),
#  ('musical group (Q215380) & rock group (Q5741069)', 136),
#  ('field army (Q51977)', 136),
#  ('theatre (Q24354) & theatrical troupe (Q742421)', 136),
#  ('parish municipality (Q27676524)', 135),
#  ('archive (Q166118) & library (Q7075)', 135),
#  ('parish in New Brunswick (Q3252927)', 135),
#  ('souq (Q510177)', 135),
#  ('None (Q53534649) & UCI WorldTeam (Q6154783)', 135),
#  ('not-for-profit arts organization (Q7062022)', 135),
#  ('Klostergebäude (Q98094402)', 135),
#  ('building complex (Q1497364)', 134),
#  ('natural gas-fired power station (Q3498533) & combined cycle power station (Q900729)',
#   134),
#  ('Club UNESCO (Q2467465)', 134),
#  ('rural municipality of Nepal (Q29467088)', 134),
#  ('Monastery wall (Q98141386)', 134),
#  ('Câmara (Q10262888)', 133),
#  ("women's association (Q1451906)", 133),
#  ('business (Q4830453) & nonprofit organization (Q163740)', 133),
#  ('Nainital Bank Branch (Q74497833)', 133),
#  ('business (Q4830453) & venture capital firm (Q3487908)', 132),
#  ('vocal group (Q120544)', 131),
#  ('book publisher (Q1320047) & business (Q4830453)', 131),
#  ('sports hall of fame (Q42245028)', 131),
#  ('joint-stock company (Q134161)', 130),
#  ('state-integrated school (Q15134891) & primary school (Q9842)', 130),
#  ('The Cosmos Co Operative Bank branch (Q75539190)', 130),
#  ('TJSB Sahakari Bank branch (Q75713787)', 130),
#  ('sports club (Q847017) & basketball team (Q13393265)', 129),
#  ('offshore wind farm (Q1357601)', 129),
#  ('musical group (Q215380) & musical duo (Q9212979)', 129),
#  ('unaided school (Q86991207) & upper primary school (Q64063386)', 129),
#  ('cultural property (Q2065736) & caravanserai (Q186347)', 128),
#  ('floorball club (Q26156208)', 128),
#  ('Local Healthwatch (Q104605647)', 127),
#  ('dairy (Q637776)', 127),
#  ('municipality (Q15284) & None (Q515)', 127),
#  ('insurance company (Q2143354)', 127),
#  ('academic archive (Q27032435)', 127),
#  ('hotel (Q27686) & hotel building (Q63099748)', 127),
#  ('electoral district of Canada (Q2973938)', 127),
#  ('community organization (Q3269648)', 127),
#  ('cancelled/unreleased video game (Q61475894)', 127),
#  ('university campus (Q30785519)', 126),
#  ('tourism office (Q1587716)', 126),
#  ("urban school (Q67388747) & boys' school (Q1713379) & primary school (Q9842)",
#   125),
#  ('academy of sciences (Q414147)', 125),
#  ('cooperative (Q4539)', 125),
#  ('Buitenpolikliniek (Q97376996)', 125),
#  ('university hospital (Q1059324)', 124),
#  ('orphanage (Q160645)', 124),
#  ('sorority (Q18811583)', 124),
#  ('paramilitary (Q207320)', 124),
#  ('None (Q22713629) & independent school (Q2418495)', 124),
#  ('Carthusian monastery (Q15823129)', 123),
#  ('community library (Q21716051)', 123),
#  ('ironworks (Q10832530)', 122),
#  ('research institute (Q31855) & university institute (Q11946645)', 122),
#  ('institute of technology (Q1371037)', 122),
#  ('None (Q28938152)', 122),
#  ('subdistrict municipality (Q15141625)', 122),
#  ('government commission (Q17456916)', 122),
#  ('business (Q4830453) & trademark (Q167270)', 122),
#  ('chocolaterie (Q762548)', 122),
#  ('association footbputall federation (Q1478443)', 121),
#  ('armed organization (Q17149090)', 121),
#  ('badminton association (Q29592127) & sports governing body (Q2485448)', 121),
#  ('building (Q41176) & school (Q3914)', 121),
#  ('partido of Buenos Aires (Q13997861) & municipality (Q15284)', 120),
#  ('drama school (Q2143781)', 120),
#  ('Mixed brigade (Q4890673)', 120),
#  ('urban school (Q67388747) & co-educational school (Q67383935) & upper primary school (Q64063386)',
#   120),
#  ('None (Q69526350)', 120),
#  ('research unit (Q99642674)', 120),
#  ('provincial electoral district of Ontario (Q6593033) & electoral district (Q192611)',
#   119),
#  ('campaign medal (Q973011)', 119),
#  ('business (Q4830453) & restaurant chain (Q18534542)', 118),
#  ('state agency of the United States (Q20857085)', 118),
#  ...]
